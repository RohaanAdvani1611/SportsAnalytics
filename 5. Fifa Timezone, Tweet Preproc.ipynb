# %% [markdown]
# # PROJECT TITLE: FINDING THE MOST INTERESTING TWEETS AND FAN SENTIMENT DURING A GAME TELECAST IN REALTIME

# %% [markdown]
# # PART 5: TIMEZONE AND TWEET PREPROCESSING:

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from nltk.stem.snowball import SnowballStemmer
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Rohaan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('tweets_proc.csv')
df.drop(['Unnamed: 0'], axis = 1, inplace = True)
df
# Out:
#                                                     Tweet  weight  \
# 0       Want to make this summer football that little ...     543
# 1       Didier Deschamps has confirmed Benjamin Mendy ...      23
# 2       Please play Power by EXO EXO also performed du...    1300
# 3       weeks teams games goals The group stage was ev...    1259
# 4       Please play Power by EXO EXO also performed du...    1300
# ...                                                   ...     ...
# 529995  Please guys please please help me ouuttt Pleas...      87
# 529996  Dear France Congratulations on winning the of ...   96217
# 529997                 France have won the FIFA in Moscow   63116
# 529998  Islamophobia Xenophobia and racism are global ...       1
# 529999          The first player to find the net in final    3228
#
#                                                    HTs  \
# 0                                  ['Win', 'WorldCup']
# 1                                       ['FRA', 'ARG']
# 2                                                 ['']
# 3                                         ['WorldCup']
# 4                                                 ['']
# ...                                                ...
# 529995                                            ['']
# 529996                                    ['WorldCup']
# 529997  ['FRA', 'WorldCup', 'FRACRO', 'WorldCupFinal']
# 529998                                            ['']
# 529999                            ['MUFC', 'WorldCup']
#
#                                                       UMN  \
# 0                                       ['Bargain Booze']
# 1                                          ['City Watch']
# 2                       ['Aeri Days', 'FIFA World Cup ?']
# 3                                        ['B/R Football']
# 4                       ['Aeri Days', 'FIFA World Cup ?']
# ...                                                   ...
# 529995  ['ShakaZuluOnTheBeats', '#RecognizeMeEp - 10 A...
# 529996                                 ['Khaled Beydoun']
# 529997                                 ['FIFA World Cup']
# 529998                                   ['Alex Florack']
# 529999                              ['Manchester United']
#
#                                 UMID  \
# 0                   ['BargainBooze']
# 1                     ['City_Watch']
# 2       ['aeridays', 'FIFAWorldCup']
# 3                     ['brfootball']
# 4       ['aeridays', 'FIFAWorldCup']
# ...                              ...
# 529995    ['K_SUPREME_ZA', 'TBanSA']
# 529996             ['KhaledBeydoun']
# 529997              ['FIFAWorldCup']
# 529998            ['crimsonsith720']
# 529999                    ['ManUtd']
#
#                                               Tweet_Extra  day  mon  hr  mnt
# 0       ['win', 'worldcup', 'bargain booze', 'bargainb...   29    6  23   56
# 1              ['fra', 'arg', 'city watch', 'city_watch']   29    6  23   56
# 2       ['', 'aeri days', 'fifa world cup ?', 'aeriday...   29    6  23   56
# 3              ['worldcup', 'b/r football', 'brfootball']   29    6  23   56
# 4       ['', 'aeri days', 'fifa world cup ?', 'aeriday...   29    6  23   56
# ...                                                   ...  ...  ...  ..  ...
# 529995  ['', 'shakazuluonthebeats', '#recognizemeep - ...   15    7  23   14
# 529996    ['worldcup', 'khaled beydoun', 'khaledbeydoun']   15    7  23   14
# 529997  ['fra', 'worldcup', 'fracro', 'worldcupfinal',...   15    7  23   14
# 529998             ['', 'alex florack', 'crimsonsith720']   15    7  23   14
# 529999  ['mufc', 'worldcup', 'manchester united', 'man...   15    7  23   14
#
# [530000 rows x 10 columns]

# %% [markdown]
# ## 1. Change Timezone:

# %%
temp = []
for i in range(530000):
    temp.append([df['day'][i], df['mon'][i], df['hr'][i], df['mnt'][i]])

# Convert UTC to Russian Local Time (+3 hrs)
for i in temp:
    i[2] += 3
    if i[2] > 23:
        i[2] -= 24
        i[0] += 1
        if i[0] > 30:
            i[0] -= 30
            i[1] += 1

# %%
day_arr = []
mon_arr = []
hr_arr = []
mnt_arr = []
for i in temp:
    day_arr.append(i[0])
    mon_arr.append(i[1])
    hr_arr.append(i[2])
    mnt_arr.append(i[3])
df['Day'] = day_arr
df['Mon'] = mon_arr
df['Hr'] = hr_arr
df['Mnt'] = mnt_arr
df.drop(['day', 'mon', 'hr', 'mnt'], axis = 1, inplace = True)
df
# Out:
#                                                     Tweet  weight  \
# 0       Want to make this summer football that little ...     543
# 1       Didier Deschamps has confirmed Benjamin Mendy ...      23
# 2       Please play Power by EXO EXO also performed du...    1300
# 3       weeks teams games goals The group stage was ev...    1259
# 4       Please play Power by EXO EXO also performed du...    1300
# ...                                                   ...     ...
# 529995  Please guys please please help me ouuttt Pleas...      87
# 529996  Dear France Congratulations on winning the of ...   96217
# 529997                 France have won the FIFA in Moscow   63116
# 529998  Islamophobia Xenophobia and racism are global ...       1
# 529999          The first player to find the net in final    3228
#
#                                                    HTs  \
# 0                                  ['Win', 'WorldCup']
# 1                                       ['FRA', 'ARG']
# 2                                                 ['']
# 3                                         ['WorldCup']
# 4                                                 ['']
# ...                                                ...
# 529995                                            ['']
# 529996                                    ['WorldCup']
# 529997  ['FRA', 'WorldCup', 'FRACRO', 'WorldCupFinal']
# 529998                                            ['']
# 529999                            ['MUFC', 'WorldCup']
#
#                                                       UMN  \
# 0                                       ['Bargain Booze']
# 1                                          ['City Watch']
# 2                       ['Aeri Days', 'FIFA World Cup ?']
# 3                                        ['B/R Football']
# 4                       ['Aeri Days', 'FIFA World Cup ?']
# ...                                                   ...
# 529995  ['ShakaZuluOnTheBeats', '#RecognizeMeEp - 10 A...
# 529996                                 ['Khaled Beydoun']
# 529997                                 ['FIFA World Cup']
# 529998                                   ['Alex Florack']
# 529999                              ['Manchester United']
#
#                                 UMID  \
# 0                   ['BargainBooze']
# 1                     ['City_Watch']
# 2       ['aeridays', 'FIFAWorldCup']
# 3                     ['brfootball']
# 4       ['aeridays', 'FIFAWorldCup']
# ...                              ...
# 529995    ['K_SUPREME_ZA', 'TBanSA']
# 529996             ['KhaledBeydoun']
# 529997              ['FIFAWorldCup']
# 529998            ['crimsonsith720']
# 529999                    ['ManUtd']
#
#                                               Tweet_Extra  Day  Mon  Hr  Mnt
# 0       ['win', 'worldcup', 'bargain booze', 'bargainb...   30    6   2   56
# 1              ['fra', 'arg', 'city watch', 'city_watch']   30    6   2   56
# 2       ['', 'aeri days', 'fifa world cup ?', 'aeriday...   30    6   2   56
# 3              ['worldcup', 'b/r football', 'brfootball']   30    6   2   56
# 4       ['', 'aeri days', 'fifa world cup ?', 'aeriday...   30    6   2   56
# ...                                                   ...  ...  ...  ..  ...
# 529995  ['', 'shakazuluonthebeats', '#recognizemeep - ...   16    7   2   14
# 529996    ['worldcup', 'khaled beydoun', 'khaledbeydoun']   16    7   2   14
# 529997  ['fra', 'worldcup', 'fracro', 'worldcupfinal',...   16    7   2   14
# 529998             ['', 'alex florack', 'crimsonsith720']   16    7   2   14
# 529999  ['mufc', 'worldcup', 'manchester united', 'man...   16    7   2   14
#
# [530000 rows x 10 columns]

# %% [markdown]
# ## 2. Preprocess Tweet:

# %%
df1 = df['Tweet']
df.Tweet = df.Tweet.fillna('')
tweet_arr = []
for i in df1:
    x = i.split(' ')
    tweet_arr.append(x)

# %% [markdown]
# ## 2a. Perform Stemming / Lemmetization:

# %%
stemmer = SnowballStemmer(language='english')
tweets_stemmed = []
for i in tweet_arr:
    stemmed_list = [stemmer.stem(token) for token in i]
    tweets_stemmed.append(stemmed_list)
tweets_stemmed
# Out:
# [['want',
#   'to',
#   'make',
#   'this',
#   'summer',
#   'footbal',
#   'that',
#   'littl',
#   'bit',
#   'hotter',
#   'rt',
#   'follow',
#   'to'],
#  ['didier',
#   'deschamp',
#   'has',
#   'confirm',
#   'benjamin',
#   'mendi',
#   'will',
#   'miss',
#   'tomorrow',
#   'game',
#   'for',
#   'against',
#   'due',
#   'to',
#   'muscular',
#   'problem'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['week',
#   'team',
#   'game',
#   'goal',
#   'the',
#   'group',
#   'stage',
#   'was',
#   'everyth',
#   'we',
#   'hope',
#   'for'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['hi',
#   'everyon',
#   'let',
#   'get',
#   'start',
#   'round',
#   'am',
#   'so',
#   'excit',
#   'but',
#   'miss',
#   'everi',
#   'footbal',
#   'leagu',
#   'that',
#   'will',
#   'come',
#   'after',
#   'world',
#   'cup',
#   'as',
#   'well'],
#  ['first',
#   'night',
#   'with',
#   'no',
#   'world',
#   'cup',
#   'game',
#   'have',
#   'had',
#   'chat',
#   'with',
#   'my',
#   'missus',
#   'she',
#   'seem',
#   'nice',
#   'girl',
#   'to',
#   'be',
#   'fair'],
#  ['batshuayi', 'with', 'arguabl', 'the', 'funniest', 'moment', 'of', 'this'],
#  ['global',
#   'festiv',
#   'with',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheer',
#   'thank',
#   'to',
#   'the',
#   'foreign',
#   'support',
#   'from',
#   'differ',
#   'co'],
#  ['watch',
#   'budweis',
#   'yerri',
#   'mina',
#   'talk',
#   'about',
#   'his',
#   'squad',
#   'danc',
#   'what',
#   'should',
#   'they',
#   'do',
#   'next',
#   'https'],
#  ['power', 'de', 'exo', 'pleas', 'play', 'of', 'https'],
#  ['the',
#   'round',
#   'of',
#   'is',
#   'confirm',
#   'tin',
#   'jedvaj',
#   'and',
#   'croatia',
#   'will',
#   'take',
#   'on',
#   'denmark',
#   'on',
#   'sunday'],
#  ['power', 'pleas', 'play', 'of'],
#  ['charg', 'the', 'world', 'wait', 'for', 'leo', 'messi', 'tomorrow'],
#  ['exo',
#   'let',
#   'repli',
#   'this',
#   'tweet',
#   'and',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'be',
#   'play',
#   'in',
#   'do',
#   'it',
#   'polit',
#   'mention',
#   'abou'],
#  ['global',
#   'festiv',
#   'with',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheer',
#   'thank',
#   'to',
#   'the',
#   'foreign',
#   'support',
#   'from',
#   'differ',
#   'co'],
#  ['there',
#   'you',
#   'have',
#   'it',
#   'the',
#   'last',
#   'have',
#   'been',
#   'confirm',
#   'catch',
#   'up',
#   'on',
#   'all',
#   'the',
#   'highlight',
#   'here',
#   'ht'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen'],
#  ['soccer',
#   'theme',
#   'nest',
#   'doll',
#   'score',
#   'point',
#   'with',
#   'fan',
#   'see',
#   'more'],
#  ['recommend',
#   'lo',
#   'siento',
#   'by',
#   'super',
#   'junior',
#   'ft',
#   'lesli',
#   'grace',
#   'and',
#   'playnskillz',
#   'it',
#   'veri',
#   'nice',
#   'trilingu',
#   'song',
#   'english',
#   'spanish'],
#  ['pleas', 'play', 'of'],
#  ['mexican',
#   'pop',
#   'fan',
#   'celebr',
#   'south',
#   'korea',
#   'win',
#   'in',
#   'their',
#   'own',
#   'way',
#   'mass',
#   'stream',
#   'hit',
#   'singl',
#   'fake'],
#  ['when',
#   'you',
#   'have',
#   'almost',
#   'made',
#   'it',
#   'through',
#   'whole',
#   'day',
#   'with',
#   'no',
#   'action'],
#  ['second', 'half', 'surg', 'see', 'tunisia', 'bow', 'out', 'in', 'style'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark',
#   'croatia'],
#  ['global',
#   'festiv',
#   'with',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheer',
#   'thank',
#   'to',
#   'the',
#   'foreign',
#   'support',
#   'from',
#   'differ',
#   'co'],
#  ['pleas', 'play', 'of'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['the', 'seneg', 'defend', 'watch', 'colombia', 'score'],
#  ['pleas', 'play', 'of'],
#  ['cameraman',
#   'fc',
#   'has',
#   'been',
#   'the',
#   'real',
#   'mvp',
#   'of',
#   'the',
#   'so',
#   'far'],
#  ['you',
#   'should',
#   'play',
#   'it',
#   'was',
#   'perform',
#   'at',
#   'the',
#   'olymp',
#   'and',
#   'play',
#   'in',
#   'dubai',
#   'fountain',
#   'show',
#   'as',
#   'well',
#   'it'],
#  ['exo',
#   'let',
#   'repli',
#   'this',
#   'tweet',
#   'and',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'be',
#   'play',
#   'in',
#   'do',
#   'it',
#   'polit',
#   'mention',
#   'abou'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['you',
#   'should',
#   'play',
#   'it',
#   'was',
#   'perform',
#   'at',
#   'the',
#   'olymp',
#   'and',
#   'play',
#   'in',
#   'dubai',
#   'fountain',
#   'show',
#   'as',
#   'well',
#   'it'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['exol',
#   'pleas',
#   'repli',
#   'quot',
#   'tweet',
#   'below',
#   'with',
#   'request',
#   'exo',
#   'power',
#   'as',
#   'favourit',
#   'song',
#   'it',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadi'],
#  ['power', 'by'],
#  ['all', 'you', 'need', 'in', 'is', 'power'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['my', 'favourit', 'song', 'is', 'fake', 'love', 'by', 'thank', 'you'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['wake',
#   'up',
#   'this',
#   'morn',
#   'and',
#   'realiz',
#   'that',
#   'there',
#   'are',
#   'no',
#   'game',
#   'today'],
#  ['rt', 'and', 'comment', 'pleas', 'play', 'of'],
#  ['power',
#   'by',
#   'exo',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas'],
#  ['pleas', 'play', 'of'],
#  ['guardiola',
#   'win',
#   'the',
#   'leagu',
#   'in',
#   'spain',
#   'spain',
#   'win',
#   'the',
#   'world',
#   'cup',
#   'guardiola',
#   'win',
#   'the',
#   'leagu',
#   'in',
#   'germani'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['of', 'po', 'favor'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['vote',
#   'exo',
#   'power',
#   'to',
#   'be',
#   'play',
#   'in',
#   'stadium',
#   'the',
#   'song',
#   'is',
#   'so',
#   'amaz',
#   'and',
#   'lit',
#   'and'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['power',
#   'by',
#   'this',
#   'song',
#   'is',
#   'so',
#   'energet',
#   'realli',
#   'suitabl',
#   'for',
#   'worldcup',
#   'also',
#   'perform',
#   'on'],
#  ['pleas', 'play', 'of'],
#  ['pleas', 'play', 'of'],
#  ['vote',
#   'exo',
#   'power',
#   'to',
#   'be',
#   'play',
#   'in',
#   'stadium',
#   'the',
#   'song',
#   'is',
#   'so',
#   'amaz',
#   'and',
#   'lit',
#   'and',
#   'en'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['pleas',
#   'play',
#   'of',
#   'we',
#   'got',
#   'the',
#   'power',
#   'everi',
#   'time',
#   'https'],
#  ['pleas', 'play', 'of'],
#  ['tub',
#   'of',
#   'haribo',
#   'of',
#   'your',
#   'choic',
#   'simpli',
#   'predict',
#   'the',
#   'st',
#   'goalscor',
#   'of',
#   'tomorrow',
#   'night',
#   'crunch',
#   'last',
#   'tie',
#   'betwe'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['pleas', 'play', 'of'],
#  ['got',
#   'the',
#   'new',
#   'era',
#   'at',
#   'no',
#   'on',
#   'billboard',
#   'japan',
#   'as',
#   'the',
#   'boost',
#   'suchmo'],
#  ['when', 'two', 'meme', 'meet'],
#  ['of', 'power', 'power'],
#  ['my', 'favorit', 'song', 'is', 'by'],
#  ['veri',
#   'proud',
#   'moment',
#   'to',
#   'lead',
#   'out',
#   'my',
#   'countri',
#   'at',
#   'the',
#   'last',
#   'night',
#   'seen',
#   'some',
#   'celebr',
#   'video',
#   'from',
#   'back',
#   'home',
#   'love',
#   'them'],
#  ['of', 'po', 'favor'],
#  ['anoth', 'cheer', 'colombian', 'celebr'],
#  ['so', 'exci'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['it', 'there', 'for', 'the', 'take'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark'],
#  ['recommend',
#   'lo',
#   'siento',
#   'by',
#   'super',
#   'junior',
#   'ft',
#   'lesli',
#   'grace',
#   'and',
#   'playnskillz',
#   'it',
#   'veri',
#   'nice',
#   'trilingu',
#   'song',
#   'english',
#   'spanish'],
#  ['am', 'choos'],
#  ['this'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen',
#   'to'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongo',
#   'arsenal',
#   'hope',
#   'of',
#   'agreement',
#   'with',
#   'sampdoria',
#   'for',
#   'torreira',
#   'but',
#   'noth',
#   'sign',
#   'no',
#   'player'],
#  ['your', 'mother', 'come', 'first', 'chat', 'about', 'jesus'],
#  ['exo', 'power', 'vamo', 'pleas', 'play', 'of'],
#  ['recommend',
#   'go',
#   'higher',
#   'by',
#   'it',
#   'the',
#   'perfect',
#   'song',
#   'to',
#   'energ',
#   'all',
#   'the',
#   'player',
#   'in',
#   'the'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'it',
#   'bop',
#   'plus',
#   'it',
#   'about',
#   'hope',
#   'and',
#   'empower',
#   'thank',
#   'much'],
#  ['found', 'the', 'video', 'hahaha', 'play', 'blackpink', 'forev', 'young'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['fake', 'love'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['knockout',
#   'bracket',
#   'is',
#   'here',
#   'sad',
#   'germani',
#   'is',
#   'out',
#   'the',
#   'joachim',
#   'w',
#   'hail',
#   'cab',
#   'meme',
#   'is',
#   'go',
#   'to',
#   'wast',
#   'still',
#   'laugh',
#   'at',
#   'this',
#   'germani',
#   'they',
#   'have',
#   'manag',
#   'coach',
#   'who',
#   'alway',
#   'look',
#   'like',
#   'an',
#   'age',
#   'beatl',
#   'tri',
#   'to',
#   'hail',
#   'cab'],
#  ['mic', 'drop', 'by', 'ft'],
#  ['exo', 'power', 'everyon', 'will', 'be', 'happi', 'to', 'hear', 'it'],
#  ['you',
#   'know',
#   'ronaldo',
#   'you',
#   'know',
#   'messi',
#   'you',
#   'know',
#   'neymar',
#   'do',
#   'you',
#   'know',
#   'who',
#   'score',
#   'more',
#   'goal',
#   'but',
#   'got',
#   'paid',
#   'much',
#   'much',
#   'less',
#   'abbi',
#   'wam'],
#  ['qatar',
#   'lawyer',
#   'tri',
#   'desper',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communic',
#   'out',
#   'of',
#   'fe'],
#  ['conclus',
#   'power',
#   'fit',
#   'perfect',
#   'with',
#   'the',
#   'energi',
#   'of',
#   'championship',
#   'as',
#   'it',
#   'is',
#   'the',
#   'world',
#   'cup',
#   'we',
#   'got',
#   'that',
#   'power'],
#  ['so',
#   'who',
#   'go',
#   'through',
#   'to',
#   'the',
#   'semi',
#   'final',
#   'between',
#   'brazil',
#   'and',
#   'belgium',
#   'sol',
#   'campbel',
#   'think',
#   'franc'],
#  ['airplan', 'pt', 'by', 'bts', 'thankyou'],
#  ['femal',
#   'report',
#   'have',
#   'face',
#   'sexism',
#   'in',
#   'sport',
#   'for',
#   'decad',
#   'but',
#   'at',
#   'this',
#   'year',
#   'some',
#   'are',
#   'speak',
#   'out'],
#  ['power', 'exo'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['as', 'they', 'say', 'this', 'is', 'footbal', 'anyth', 'can', 'happen'],
#  ['got',
#   'the',
#   'new',
#   'era',
#   'at',
#   'no',
#   'on',
#   'billboard',
#   'japan',
#   'as',
#   'the',
#   'boost',
#   'suchmo'],
#  ['recommend',
#   'lo',
#   'siento',
#   'by',
#   'super',
#   'junior',
#   'ft',
#   'lesli',
#   'grace',
#   'and',
#   'playnskillz',
#   'it',
#   'veri',
#   'nice',
#   'trilingu',
#   'song',
#   'english',
#   'spanish'],
#  ['you',
#   'can',
#   'still',
#   'particip',
#   'in',
#   'our',
#   'competit',
#   'what',
#   'are',
#   'you',
#   'wait',
#   'for',
#   'win',
#   'valuabl',
#   'electron'],
#  ['exo', 'power', 'pleas', 'play', 'of'],
#  ['huge', 'day', 'in', 'group', 'team', 'news'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['just',
#   'remind',
#   'as',
#   'there',
#   'are',
#   'no',
#   'game',
#   'on',
#   'today',
#   'air',
#   'bud',
#   'world',
#   'pup',
#   'is',
#   'on',
#   'netflix'],
#  ['power', 'by'],
#  ['my',
#   'postcard',
#   'to',
#   'jennif',
#   'salk',
#   'at',
#   'am',
#   'from',
#   'the',
#   'futur',
#   'after',
#   'all',
#   's',
#   'would',
#   'tell',
#   'you',
#   'who',
#   'won'],
#  ['becaus', 'we', 'got', 'that', 'power', 'power'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['last',
#   'day',
#   'of',
#   'round',
#   'one',
#   'make',
#   'you',
#   'pick',
#   'for',
#   'the',
#   'round',
#   'of',
#   'to',
#   'start',
#   'earn',
#   'mvu'],
#  ['iceland', 'head', 'coach', 'day', 'after', 'elimin', 'reddit'],
#  ['o', 'e', 'p', 'w', 'r', 'o', 'e', 'by', 'exo'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['retweet',
#   'if',
#   'you',
#   'think',
#   'cristiano',
#   'ronaldo',
#   'will',
#   'score',
#   'against',
#   'uruguay'],
#  ['power', 'by'],
#  ['power', 'exo', 'it', 'veri', 'suitabl', 'for', 'worldcup', 'think'],
#  ['no',
#   'fixtur',
#   'today',
#   'but',
#   'this',
#   'gif',
#   'should',
#   'help',
#   'pass',
#   'the',
#   'time',
#   'until',
#   'the',
#   'tournament',
#   'resum'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['the', 'seneg', 'defend', 'watch', 'colombia', 'score'],
#  ['mexico',
#   'fan',
#   'go',
#   'through',
#   'secur',
#   'in',
#   'russia',
#   'wait',
#   'for',
#   'it'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['vamo', 'exo', 'rt', 'rt', 'pleas', 'play', 'of'],
#  ['exo', 'olymp', 'exo', 'nation', 'pick', 'power'],
#  ['there',
#   'more',
#   'to',
#   'than',
#   'be',
#   'the',
#   'smallest',
#   'nation',
#   'to',
#   'ever',
#   'qualifi',
#   'for',
#   'the',
#   'it',
#   'also',
#   'global',
#   'lead'],
#  ['power', 'by'],
#  ['pleas', 'play', 'of'],
#  ['hugo',
#   'llori',
#   'franc',
#   'we',
#   'have',
#   'studi',
#   'argenina',
#   'group',
#   'game',
#   'which',
#   'give',
#   'us',
#   'an',
#   'indic',
#   'but',
#   'we',
#   'know',
#   'player',
#   'like',
#   'messi',
#   'can',
#   'step',
#   'up',
#   'his',
#   'own',
#   'level',
#   'and',
#   'decid',
#   'the',
#   'fate',
#   'of',
#   'the',
#   'match',
#   'as',
#   'he',
#   'doe',
#   'with',
#   'argentina',
#   'and',
#   'barcelona'],
#  ['airplan', 'pt', 'by', 'bts', 'thankyou'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['exo',
#   'let',
#   'repli',
#   'this',
#   'tweet',
#   'and',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'be',
#   'play',
#   'in',
#   'do',
#   'it',
#   'polit',
#   'mention',
#   'abou'],
#  ['probabl', 'line', 'up', 'for'],
#  ['if',
#   'you',
#   'onli',
#   'read',
#   'one',
#   'germani',
#   'world',
#   'cup',
#   'post',
#   'mortem',
#   'make',
#   'it',
#   'this',
#   'one'],
#  ['never',
#   'do',
#   'this',
#   'again',
#   'when',
#   'man',
#   'tri',
#   'kiss',
#   'her',
#   'while',
#   'she',
#   'was',
#   'report',
#   'at',
#   'the',
#   'brazilian',
#   'journalist',
#   'foug'],
#  ['can',
#   'you',
#   'predict',
#   'the',
#   'result',
#   'of',
#   'who',
#   'will',
#   'score',
#   'first',
#   'when',
#   'face',
#   'how',
#   'will',
#   'finish',
#   'join',
#   'in'],
#  ['japanes',
#   'cartoonist',
#   'latest',
#   'cartoon',
#   'show',
#   'the',
#   'team',
#   'left',
#   'in',
#   'the',
#   'after',
#   'the',
#   'group',
#   'stage'],
#  ['power',
#   'by',
#   'exo',
#   'is',
#   'suitabl',
#   'and',
#   'energet',
#   'song',
#   'which',
#   'can',
#   'be',
#   'play',
#   'at',
#   'the',
#   'world',
#   'cup',
#   'believ',
#   'peopl',
#   'from'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['everyth',
#   'point',
#   'to',
#   'win',
#   'tomorrow',
#   'but',
#   'becaus',
#   'the',
#   'is',
#   'mad',
#   'think',
#   'will',
#   'do',
#   'it'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen',
#   'to'],
#  ['with',
#   'the',
#   'knockout',
#   'round',
#   'bracket',
#   'set',
#   'take',
#   'look',
#   'at',
#   'the',
#   'spi',
#   'chanc',
#   'to',
#   'advanc',
#   'to',
#   'each',
#   'round',
#   'and',
#   'win',
#   'it',
#   'all',
#   'fr'],
#  ['egg',
#   'were',
#   'thrown',
#   'at',
#   'the',
#   'korean',
#   'nation',
#   'team',
#   'after',
#   'defeat',
#   'germani',
#   'at',
#   'the',
#   'spur',
#   'forward',
#   'son',
#   'heung'],
#  ['got',
#   'the',
#   'new',
#   'era',
#   'at',
#   'no',
#   'on',
#   'billboard',
#   'japan',
#   'as',
#   'the',
#   'boost',
#   'suchmo'],
#  ['when',
#   'you',
#   'have',
#   'almost',
#   'made',
#   'it',
#   'through',
#   'whole',
#   'day',
#   'with',
#   'no',
#   'action'],
#  ['pleas', 'play', 'of'],
#  ['type', 'of', 'peopl', 'watch', 'the', 'world', 'cup', 'full', 'vid'],
#  ['exo', 'power', 'pleas', 'play', 'of', 'http'],
#  ['power', 'by'],
#  ['it',
#   'realli',
#   'is',
#   'the',
#   'global',
#   'game',
#   'where',
#   'have',
#   'you',
#   'been',
#   'watch',
#   'the',
#   'from'],
#  ['entrenamiento',
#   'previo',
#   'al',
#   'partido',
#   'de',
#   'octavo',
#   'de',
#   'final',
#   'vs',
#   'last',
#   'train',
#   'session',
#   'befor',
#   'next',
#   'rou'],
#  ['who',
#   'is',
#   'face',
#   'who',
#   'in',
#   'the',
#   'last',
#   'of',
#   'the',
#   'and',
#   'one',
#   'side',
#   'of',
#   'the',
#   'draw',
#   'is',
#   'load',
#   'with',
#   'former',
#   'winner',
#   'http'],
#  ['exo', 'power', 'pleas', 'play', 'of', 'htt'],
#  ['fake', 'love', 'and', 'airplan', 'pt', 'by'],
#  ['pleas', 'play', 'of'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['airplan', 'pt', 'by', 'bts', 'thankyou'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'the',
#   'song',
#   'is',
#   'about',
#   'the',
#   'power',
#   'of',
#   'music',
#   'and',
#   'how',
#   'it',
#   'bring',
#   'peopl',
#   'togeth',
#   'and',
#   'togeth',
#   'we',
#   'have'],
#  ['pleas', 'play', 'of'],
#  ['power', 'by'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['power',
#   'by',
#   'exo',
#   'is',
#   'your',
#   'song',
#   'fifa',
#   'it',
#   'go',
#   'to',
#   'turn',
#   'up',
#   'the',
#   'mood',
#   'even',
#   'more',
#   'will',
#   'bring',
#   'the',
#   'festiv',
#   'atmospher'],
#  ['fake', 'love', 'by'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['matchday',
#   'round',
#   'of',
#   'tsn',
#   'am',
#   'et',
#   'intern',
#   'play',
#   'for',
#   'juventus',
#   'intern',
#   'play',
#   'for',
#   'juventus',
#   'good',
#   'luck',
#   'to'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['my', 'favorit', 'song', 'is', 'by'],
#  ['internet', 'is', 'beauti', 'place'],
#  ['break',
#   'diego',
#   'maradona',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'paid',
#   'fifa',
#   'ambassador',
#   'after',
#   'his',
#   'embarrass',
#   'and',
#   'provocot',
#   'behaviour',
#   'dure'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['global',
#   'festiv',
#   'with',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheer',
#   'thank',
#   'to',
#   'the',
#   'foreign',
#   'support',
#   'from',
#   'differ',
#   'co'],
#  ['pleas', 'play', 'of'],
#  ['last', 'fixtur', 'saturday', 'vs', 'vs', 'sunday', 'vs', 'vs'],
#  ['these',
#   'brazil',
#   'fan',
#   'had',
#   'funer',
#   'process',
#   'through',
#   'the',
#   'street',
#   'when',
#   'germani',
#   'got',
#   'knock',
#   'out',
#   'of',
#   'the'],
#  ['power', 'by', 'would', 'be', 'great', 'choic'],
#  ['o', 'e', 'p', 'w', 'r', 'o', 'e', 'by', 'exo'],
#  ['most',
#   'chanc',
#   'creat',
#   'in',
#   'the',
#   'group',
#   'stage',
#   'neymar',
#   'joshua',
#   'kimmich',
#   'mesut',
#   'zil',
#   'salman',
#   'al',
#   'faraj'],
#  ['growl', 'pleas', 'play', 'of'],
#  ['just',
#   'remind',
#   'as',
#   'there',
#   'are',
#   'no',
#   'game',
#   'on',
#   'today',
#   'air',
#   'bud',
#   'world',
#   'pup',
#   'is',
#   'on',
#   'netflix'],
#  ['our',
#   'fashion',
#   'art',
#   'icon',
#   'of',
#   'the',
#   'week',
#   'for',
#   'the',
#   'tool',
#   'fest',
#   'goe',
#   'to',
#   'curat',
#   'by'],
#  ['power', 'pleas', 'play', 'of'],
#  ['as',
#   'the',
#   'group',
#   'stage',
#   'end',
#   'we',
#   'say',
#   'farewel',
#   'to',
#   'team',
#   'from',
#   'this',
#   'year',
#   'fifa',
#   'thank',
#   'for',
#   'the',
#   'memori'],
#  ['pleas', 'play', 'such', 'great', 'song', 'to', 'cheer', 'everyon', 'up'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['coutinho', 'dure', 'train', 'with', 'brazil', 'on', 'friday', 'getti'],
#  ['icon', 'celebr', 'of', 'the', 'so', 'far', 'who', 'will'],
#  ['power',
#   'by',
#   'exo',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas',
#   'pleas'],
#  ['good', 'luck', 'for', 'the', 'at'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen'],
#  ['rt', 'and', 'comment', 'pleas', 'play', 'of'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['power', 'by'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'it',
#   'was',
#   'perform',
#   'in',
#   'the',
#   'olymp',
#   'and',
#   'it',
#   'was',
#   'the',
#   'first',
#   'song',
#   'play',
#   'in',
#   'th'],
#  ['new',
#   'pod',
#   'we',
#   'are',
#   'join',
#   'by',
#   'to',
#   'preview',
#   'what',
#   'look',
#   'to',
#   'be',
#   'wild',
#   'entertain',
#   'round',
#   'of'],
#  ['zhou',
#   'mi',
#   'weibo',
#   'updat',
#   'as',
#   'footbal',
#   'fan',
#   'can',
#   'not',
#   'miss',
#   'out',
#   'have',
#   'shirt'],
#  ['found', 'the', 'video', 'hahaha', 'play', 'blackpink', 'forev', 'young'],
#  ['the', 'lack', 'of', 'ani', 'match', 'today'],
#  ['it',
#   'time',
#   'to',
#   'give',
#   'the',
#   'superior',
#   'song',
#   'the',
#   'recognit',
#   'it',
#   'deserv',
#   'request',
#   'nct',
#   'dream',
#   'trigger',
#   'the',
#   'fever',
#   'on',
#   'their'],
#  ['vote',
#   'exo',
#   'power',
#   'to',
#   'be',
#   'play',
#   'in',
#   'stadium',
#   'the',
#   'song',
#   'is',
#   'so',
#   'amaz',
#   'and',
#   'lit',
#   'and',
#   'energ'],
#  ['oasi', 'champagn', 'supernova', 'kid', 'cudi'],
#  ['exo',
#   'energet',
#   'song',
#   'power',
#   'would',
#   'be',
#   'so',
#   'suitabl',
#   'to',
#   'be',
#   'play',
#   'the',
#   'song',
#   'have',
#   'be',
#   'perform',
#   'at',
#   'the',
#   'closin'],
#  ['fake', 'love', 'by'],
#  ['pleas', 'play', 'of'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['my', 'favorit', 'song', 'is', 'by'],
#  ['power', 'by'],
#  ['wait', 'what'],
#  ['my', 'favorit', 'song', 'is', 'by'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark'],
#  ['for',
#   'nigeria',
#   'at',
#   'the',
#   'most',
#   'take',
#   'on',
#   'complet',
#   'most',
#   'foul',
#   'won',
#   'most',
#   'shot',
#   'joint',
#   'most'],
#  ['rihanna',
#   'this',
#   'is',
#   'what',
#   'you',
#   'came',
#   'for',
#   'taylor',
#   'swift',
#   'readi',
#   'for',
#   'it'],
#  ['qatar',
#   'lawyer',
#   'tri',
#   'desper',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communic',
#   'out',
#   'of',
#   'fe'],
#  ['exo', 'power', 'is', 'the', 'perfect', 'song', 'plea', 'give', 'it', 'tri'],
#  ['wake',
#   'up',
#   'this',
#   'morn',
#   'and',
#   'realiz',
#   'that',
#   'there',
#   'are',
#   'no',
#   'game',
#   'today'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['someth', 'veri', 'sooth', 'about', 'this', 'kit', 'imag'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['cameraman',
#   'fc',
#   'has',
#   'been',
#   'the',
#   'real',
#   'mvp',
#   'of',
#   'the',
#   'so',
#   'far'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark',
#   'croatia'],
#  ['qatar',
#   'lawyer',
#   'tri',
#   'desper',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communic',
#   'out',
#   'of',
#   'fe'],
#  ['pleas', 'play', 'by', 'thankyou', 'so', 'much'],
#  ['look',
#   'for',
#   'some',
#   'entertain',
#   'on',
#   'the',
#   'first',
#   'rest',
#   'day',
#   'you',
#   'are',
#   'in',
#   'safe',
#   'hand',
#   'with',
#   'at',
#   'our',
#   'exhibit'],
#  ['vote',
#   'exo',
#   'power',
#   'to',
#   'be',
#   'play',
#   'in',
#   'stadium',
#   'the',
#   'song',
#   'is',
#   'so',
#   'amaz',
#   'and',
#   'lit',
#   'and',
#   'energ'],
#  ['voten', 'por', 'power', 'de', 'exo', 'pleas', 'play', 'of'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongo',
#   'arsenal',
#   'hope',
#   'of',
#   'agreement',
#   'with',
#   'sampdoria',
#   'for',
#   'torreira',
#   'but',
#   'noth',
#   'sign',
#   'no',
#   'player'],
#  ['this',
#   'is',
#   'what',
#   'the',
#   'and',
#   'have',
#   'in',
#   'common',
#   'peopl',
#   'from',
#   'differ',
#   'countri',
#   'and',
#   'cultur',
#   'can',
#   'bond',
#   'over',
#   'good'],
#  ['exo',
#   'let',
#   'repli',
#   'this',
#   'tweet',
#   'and',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'be',
#   'play',
#   'in',
#   'do',
#   'it',
#   'polit',
#   'mention',
#   'abou'],
#  ['global',
#   'festiv',
#   'with',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheer',
#   'thank',
#   'to',
#   'the',
#   'foreign',
#   'support',
#   'from',
#   'differ',
#   'co'],
#  ['colombian',
#   'man',
#   'help',
#   'his',
#   'deaf',
#   'and',
#   'blind',
#   'friend',
#   'experi',
#   'the',
#   'joy',
#   'of',
#   'their',
#   'team',
#   'campaign'],
#  ['power', 'de', 'exo', 'pleas', 'play', 'of'],
#  ['i',
#   'pick',
#   'argentina',
#   'to',
#   'win',
#   'the',
#   'play',
#   'world',
#   'cup',
#   'knockout',
#   'bracket',
#   'on',
#   'for',
#   'chanc',
#   'to',
#   'win',
#   'cash',
#   'prize'],
#  ['we', 'know', 'who', 'this', 'guy', 'is', 'root', 'for', 'tomorrow'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen'],
#  ['exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'olymp',
#   'power',
#   'is',
#   'about',
#   'over',
#   'come',
#   'challeng',
#   'with'],
#  ['would',
#   'you',
#   'believ',
#   'after',
#   'mexico',
#   'got',
#   'through',
#   'the',
#   'top',
#   'bts',
#   'rose',
#   'to',
#   'spot',
#   'on',
#   'the',
#   'mexican',
#   'itun',
#   'lmao',
#   'ya',
#   'will',
#   'the',
#   'hype',
#   'is',
#   'real'],
#  ['when', 'you', 'realis', 'there', 'are', 'no', 'game', 'on', 'today'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['bts',
#   'obviusli',
#   'these',
#   'song',
#   'fake',
#   'love',
#   'it',
#   'veri',
#   'belov',
#   'song',
#   'it',
#   'liter',
#   'perfect',
#   'and',
#   'of',
#   'co'],
#  ['top',
#   'goalscor',
#   'by',
#   'leagu',
#   'la',
#   'liga',
#   'premier',
#   'leagu',
#   'bundesliga',
#   'ligu'],
#  ['this', 'absolut', 'got', 'to', 'me', 'what', 'man'],
#  ['exo', 'power', 'pleas', 'we', 'have', 'got', 'that', 'power', 'power'],
#  ['exol',
#   'pleas',
#   'repli',
#   'quot',
#   'tweet',
#   'below',
#   'with',
#   'request',
#   'exo',
#   'power',
#   'as',
#   'favourit',
#   'song',
#   'it',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadi'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['airplan', 'pt'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongo',
#   'arsenal',
#   'hope',
#   'of',
#   'agreement',
#   'with',
#   'sampdoria',
#   'for',
#   'torreira',
#   'but',
#   'noth',
#   'sign',
#   'no',
#   'player'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['exo', 'power'],
#  ['pleas', 'play', 'of'],
#  ['back', 'to', 'the', 'futur'],
#  ['england',
#   'vs',
#   'england',
#   'one',
#   'is',
#   'reflect',
#   'of',
#   'an',
#   'england',
#   'which',
#   'still',
#   'had',
#   'an',
#   'ident',
#   'repres',
#   'of',
#   'the',
#   'english'],
#  ['the', 'round', 'of'],
#  ['face', 'in', 'tuesday', 'last', 'at', 'stadium', 'what', 'your', 'predict'],
#  ['my', 'favourit', 'is'],
#  ['we',
#   'will',
#   'have',
#   'twelv',
#   'madridista',
#   'involv',
#   'in',
#   'the',
#   'last',
#   'of',
#   'the',
#   'find',
#   'out',
#   'who'],
#  ['it',
#   'realli',
#   'is',
#   'the',
#   'global',
#   'game',
#   'where',
#   'have',
#   'you',
#   'been',
#   'watch',
#   'the',
#   'from'],
#  ['fake', 'love', 'bts', 'airplan', 'pt', 'bts'],
#  ['fever', 'warm', 'up', 'today', 'via'],
#  ['exo',
#   'energet',
#   'song',
#   'power',
#   'would',
#   'be',
#   'so',
#   'suitabl',
#   'to',
#   'be',
#   'play',
#   'the',
#   'song',
#   'have',
#   'be',
#   'perform',
#   'at',
#   'the',
#   'closin'],
#  ['news', 'game', 'congrat', 'yoshi'],
#  ['global',
#   'festiv',
#   'with',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheer',
#   'thank',
#   'to',
#   'the',
#   'foreign',
#   'support',
#   'from',
#   'differ',
#   'co'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['exo', 'olymp', 'exo', 'nation', 'pick', 'power'],
#  ['here',
#   'is',
#   'the',
#   'link',
#   'of',
#   'their',
#   'perform',
#   'olymp',
#   'acc',
#   'still',
#   'love',
#   'our',
#   'nation',
#   'pick'],
#  ['fake', 'love', 'is', 'amaz'],
#  ['no', 'game', 'today', 'got', 'us', 'feel', 'like'],
#  ['symphon', 'narcotix', 'by', 'artist', 'prod', 'mix', 'master'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark',
#   'croatia'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['power', 'de', 'exo', 'pleas', 'play', 'of'],
#  ['best',
#   'moment',
#   'of',
#   'the',
#   'you',
#   'can',
#   'not',
#   'rank',
#   'world',
#   'cup',
#   'moment',
#   'everyth',
#   'matter'],
#  ['hi',
#   'our',
#   'favorit',
#   'song',
#   'is',
#   'fake',
#   'love',
#   'by',
#   'they',
#   'also',
#   'have',
#   'latin',
#   'inspir',
#   'one',
#   'call',
#   'airplan',
#   'pt'],
#  ['when',
#   'you',
#   'have',
#   'almost',
#   'made',
#   'it',
#   'through',
#   'whole',
#   'day',
#   'with',
#   'no',
#   'action'],
#  ['pre',
#   'tournament',
#   'predict',
#   'germani',
#   'to',
#   'win',
#   'the',
#   'that',
#   'hasn',
#   'gone',
#   'well',
#   'so',
#   'm',
#   'give',
#   'myself',
#   'anoth',
#   'go',
#   'at'],
#  ['can',
#   'not',
#   'get',
#   'enough',
#   'of',
#   'the',
#   'fifa',
#   'right',
#   'now',
#   'like',
#   'or',
#   'retweet',
#   'this',
#   'to',
#   'subscrib',
#   'to',
#   'the',
#   'match',
#   'day',
#   'programm'],
#  ['pleas', 'play', 'of'],
#  ['pleas', 'play'],
#  ['found', 'the', 'video', 'hahaha', 'play', 'blackpink', 'forev', 'young'],
#  ['pleas', 'play', 'of'],
#  ['with', 'the', 'inappropri', 'korea', 'joke'],
#  ['land',
#   'transact',
#   'approv',
#   'transfer',
#   'respons',
#   'regul',
#   'you',
#   'just',
#   'don',
#   'like',
#   'to',
#   'paus',
#   'for',
#   'breath',
#   'no',
#   'wonder',
#   'you',
#   're',
#   'out',
#   'of',
#   'the'],
#  ['power',
#   'by',
#   'exo',
#   'is',
#   'suitabl',
#   'and',
#   'energet',
#   'song',
#   'which',
#   'can',
#   'be',
#   'play',
#   'at',
#   'the',
#   'world',
#   'cup',
#   'believ',
#   'peopl',
#   'from'],
#  ['exo',
#   'power',
#   'the',
#   'best',
#   'song',
#   'sound',
#   'in',
#   'olymp',
#   'game',
#   'and',
#   'in',
#   'dubai'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['mexican',
#   'pop',
#   'fan',
#   'celebr',
#   'south',
#   'korea',
#   'win',
#   'in',
#   'their',
#   'own',
#   'way',
#   'mass',
#   'stream',
#   'hit',
#   'singl',
#   'fake'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['fake', 'love', 'is', 'amaz'],
#  ['it',
#   'good',
#   'song',
#   'with',
#   'rhythm',
#   'that',
#   'can',
#   'burn',
#   'your',
#   'spirit'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen'],
#  ['the', 'seneg', 'defend', 'watch', 'colombia', 'score'],
#  ['the', 'round', 'of'],
#  ['new', 'funni', 'fortnit', 'clip'],
#  ['airplan',
#   'pt',
#   'of',
#   'bts',
#   'it',
#   'great',
#   'song',
#   'to',
#   'danc',
#   'the',
#   'latin',
#   'peopl',
#   'would',
#   'enjoy',
#   'it'],
#  ['charg', 'the', 'world', 'wait', 'for', 'leo', 'messi', 'tomorrow'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark',
#   'croatia'],
#  ['pleas', 'play', 'of'],
#  ['recommend',
#   'go',
#   'higher',
#   'by',
#   'it',
#   'the',
#   'perfect',
#   'song',
#   'to',
#   'energ',
#   'all',
#   'the',
#   'player',
#   'in',
#   'the'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen',
#   'to'],
#  ['hi',
#   'our',
#   'favorit',
#   'song',
#   'is',
#   'fake',
#   'love',
#   'by',
#   'they',
#   'also',
#   'have',
#   'latin',
#   'inspir',
#   'one',
#   'call',
#   'airplan',
#   'pt'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['exo',
#   'let',
#   'repli',
#   'this',
#   'tweet',
#   'and',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'be',
#   'play',
#   'in',
#   'do',
#   'it',
#   'polit',
#   'mention',
#   'abou'],
#  ['pleas', 'play', 'of'],
#  ['predict',
#   'in',
#   'the',
#   'nobl',
#   'quran',
#   'modern',
#   'mean',
#   'of',
#   'transport',
#   'chat',
#   'now'],
#  ['probabl', 'line', 'up', 'for'],
#  ['exol',
#   'pleas',
#   'repli',
#   'quot',
#   'tweet',
#   'below',
#   'with',
#   'request',
#   'exo',
#   'power',
#   'as',
#   'favourit',
#   'song',
#   'it',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadi'],
#  ['there',
#   'are',
#   'some',
#   'big',
#   'clash',
#   'to',
#   'look',
#   'forward',
#   'to',
#   'in',
#   'the',
#   'round',
#   'of',
#   'are',
#   'we',
#   'in',
#   'for',
#   'ani',
#   'shock'],
#  ['pleas', 'play', 'of'],
#  ['got',
#   'the',
#   'new',
#   'era',
#   'at',
#   'no',
#   'on',
#   'billboard',
#   'japan',
#   'as',
#   'the',
#   'boost',
#   'suchmo'],
#  ['pleas', 'play', 'of'],
#  ['the',
#   'last',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark',
#   'croatia',
#   'argentina',
#   'sweden'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark',
#   'croatia'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongo',
#   'arsenal',
#   'hope',
#   'of',
#   'agreement',
#   'with',
#   'sampdoria',
#   'for',
#   'torreira',
#   'but',
#   'noth',
#   'sign',
#   'no',
#   'player'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['pleas',
#   'play',
#   'of',
#   'this',
#   'song',
#   'is',
#   'so',
#   'energet',
#   'amd',
#   'powerful',
#   'fit',
#   'perfect',
#   'wit',
#   'the'],
#  ['on',
#   'june',
#   'from',
#   'to',
#   'pm',
#   'victori',
#   'museum',
#   'invit',
#   'footbal',
#   'fan',
#   'of',
#   'to',
#   'visit',
#   'it',
#   'open',
#   'air',
#   'exposit',
#   'of',
#   'militar'],
#  ['best', 'prom', 'tabl', 'plan', 'ever', 'thank', 'you', 'ms', 'cuddi'],
#  ['power', 'by', 'nation', 'pick'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['jess',
#   'lingard',
#   'curler',
#   'is',
#   'up',
#   'with',
#   'one',
#   'of',
#   'the',
#   'great',
#   'goal',
#   'of',
#   'this',
#   'year',
#   'fifa',
#   'do',
#   'you',
#   'agre',
#   'watch',
#   'him',
#   'and',
#   'engla'],
#  ['it',
#   'realli',
#   'is',
#   'the',
#   'global',
#   'game',
#   'where',
#   'have',
#   'you',
#   'been',
#   'watch',
#   'the',
#   'from'],
#  ['the', 'best', 'fan', 'at', 'the', 'are'],
#  ['my', 'favorit', 'song', 'is'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen',
#   'to'],
#  ['fake', 'love', 'by'],
#  ['catch',
#   'up',
#   'on',
#   'featur',
#   'three',
#   'current',
#   'red',
#   'and',
#   'winner',
#   'from',
#   'former',
#   'player'],
#  ['citi',
#   'countri',
#   'name',
#   'in',
#   'airplain',
#   'part',
#   'particip',
#   'in',
#   'the',
#   'worldcup',
#   'london',
#   'pari',
#   'tokyo',
#   'mexico',
#   'citi',
#   'brazil',
#   'all',
#   'these',
#   'countri'],
#  ['exol',
#   'pleas',
#   'repli',
#   'quot',
#   'tweet',
#   'below',
#   'with',
#   'request',
#   'exo',
#   'power',
#   'as',
#   'favourit',
#   'song',
#   'it',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadi'],
#  ['it', 'now', 'or', 'never', 'for', 'england'],
#  ['pleas', 'play', 'of'],
#  ['exo', 'power'],
#  ['as',
#   'the',
#   'group',
#   'stage',
#   'end',
#   'we',
#   'say',
#   'farewel',
#   'to',
#   'team',
#   'from',
#   'this',
#   'year',
#   'fifa',
#   'thank',
#   'for',
#   'the',
#   'memori'],
#  ['the',
#   'eca',
#   'campaign',
#   'has',
#   'launch',
#   'to',
#   'acceler',
#   'the',
#   'mass',
#   'adopt',
#   'of',
#   'and',
#   'we',
#   'are',
#   'goi'],
#  ['who', 'go', 'to', 'win'],
#  ['fun',
#   'fact',
#   'at',
#   'least',
#   'nation',
#   'team',
#   'arriv',
#   'in',
#   'style',
#   'for',
#   'the',
#   'fifa',
#   'check',
#   'out',
#   'few',
#   'of',
#   'their'],
#  ['diego',
#   'maradona',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'paid',
#   'fifa',
#   'ambassador',
#   'after',
#   'his',
#   'embarrass',
#   'and',
#   'provocot',
#   'behaviour',
#   'dure'],
#  ['fake', 'love', 'is', 'amaz'],
#  ['transform', 'pleas', 'play', 'of'],
#  ['my',
#   'postcard',
#   'to',
#   'jennif',
#   'salk',
#   'at',
#   'am',
#   'from',
#   'the',
#   'futur',
#   'after',
#   'all',
#   's',
#   'would',
#   'tell',
#   'you',
#   'who',
#   'won'],
#  ['the',
#   'last',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark',
#   'croatia',
#   'argentina',
#   'sweden'],
#  ['anyon',
#   'els',
#   'woke',
#   'up',
#   'at',
#   'to',
#   'catch',
#   'the',
#   'match',
#   'and',
#   'then',
#   'realiz',
#   'there',
#   'was',
#   'not',
#   'one',
#   'today',
#   'did',
#   'not',
#   'even',
#   'need',
#   'an',
#   'alarm'],
#  ['diego',
#   'maradona',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'paid',
#   'fifa',
#   'ambassador',
#   'after',
#   'his',
#   'embarrass',
#   'and',
#   'provocot',
#   'behaviour',
#   'dure'],
#  ['what',
#   'an',
#   'amaz',
#   'set',
#   'for',
#   'game',
#   'of',
#   'footbal',
#   'young',
#   'russian',
#   'footbal',
#   'took',
#   'part',
#   'in',
#   'an',
#   'exhibit',
#   'match',
#   'at',
#   'moscow',
#   'fo'],
#  ['readi', 'for', 'the', 'knockout'],
#  ['round', 'of', 'predict', 'by', 'includ', 'vs', 'via'],
#  ['no', 'game', 'today', 'got', 'us', 'feel', 'like'],
#  ['we', 'know', 'who', 'this', 'guy', 'is', 'root', 'for', 'tomorrow'],
#  ['pleas', 'play', 'of'],
#  ['the',
#   'true',
#   'stori',
#   'of',
#   'the',
#   'world',
#   'greatest',
#   'ronaldo',
#   'avail',
#   'on',
#   'itun',
#   'now'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'nation',
#   'pick',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it'],
#  ['pablo',
#   'zabaleta',
#   'believ',
#   'it',
#   'the',
#   'last',
#   'chanc',
#   'for',
#   'mani',
#   'of',
#   'star',
#   'player',
#   'to',
#   'win',
#   'the'],
#  ['exo',
#   'ls',
#   'this',
#   'would',
#   'be',
#   'an',
#   'honour',
#   'for',
#   'exo',
#   'and',
#   'we',
#   'know',
#   'power',
#   'motiv',
#   'athlet',
#   'send',
#   'in',
#   'your',
#   'request',
#   'for',
#   'power',
#   'tag'],
#  ['when', 'you', 'wake', 'up', 'and', 'there', 'no', 'to', 'watch'],
#  ['power',
#   'is',
#   'the',
#   'ultim',
#   'song',
#   'to',
#   'give',
#   'energi',
#   'to',
#   'ani',
#   'soccer',
#   'player'],
#  ['disappoint',
#   'but',
#   'hope',
#   'should',
#   'beat',
#   'and',
#   'or',
#   'to',
#   'get',
#   'to',
#   'the',
#   'semi'],
#  ['rt', 'and', 'comment', 'pleas', 'play', 'of'],
#  ['franc', 'vs', 'argentina', 'who', 'will', 'win'],
#  ['pleas', 'play', 'of'],
#  ['qatar',
#   'lawyer',
#   'tri',
#   'desper',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communic',
#   'out',
#   'of',
#   'fe'],
#  ['the', 'round', 'of'],
#  ['wait', 'what'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['power', 'by', 'exo'],
#  ['for', 'tomorrow', 'nice'],
#  ['the',
#   'best',
#   'xi',
#   'from',
#   'group',
#   'stage',
#   'play',
#   'includ',
#   'real',
#   'madrid',
#   'teammat',
#   'modric',
#   'ronaldo',
#   'and',
#   'isco',
#   'along',
#   'with',
#   'harri',
#   'kane',
#   'no',
#   'messi'],
#  ['we',
#   've',
#   'heard',
#   'your',
#   'feedback',
#   'here',
#   'our',
#   'improv',
#   'world',
#   'cup',
#   'squad',
#   'thank',
#   'everyon'],
#  ['it', 'has', 'been', 'too', 'long', 'sinc', 'match'],
#  ['pleas', 'play', 'of'],
#  ['win', 'up', 'to', 'wnrs'],
#  ['in',
#   'the',
#   'where',
#   'to',
#   'watch',
#   'who',
#   'to',
#   'root',
#   'for',
#   'and',
#   'everyth',
#   'els',
#   'you',
#   'need',
#   'to',
#   'know',
#   'the',
#   'game',
#   'start',
#   'saturday',
#   'morn'],
#  ['you',
#   'should',
#   'play',
#   'it',
#   'was',
#   'perform',
#   'at',
#   'the',
#   'olymp',
#   'and',
#   'play',
#   'in',
#   'dubai',
#   'fountain',
#   'show',
#   'as',
#   'well',
#   'it'],
#  ['check',
#   'out',
#   'our',
#   'latest',
#   'talk',
#   'el',
#   'tri',
#   'as',
#   'we',
#   'preview',
#   'vs'],
#  ['we',
#   'would',
#   'recomend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'an',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'choosen'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['that', 'goal', 'celebr'],
#  ['pleas', 'play', 'of'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['are', 'not', 'they', 'just'],
#  ['vote',
#   'exo',
#   'power',
#   'to',
#   'be',
#   'play',
#   'in',
#   'stadium',
#   'the',
#   'song',
#   'is',
#   'so',
#   'amaz',
#   'and',
#   'lit',
#   'and',
#   'energ'],
#  ['and',
#   'here',
#   'it',
#   'is',
#   'your',
#   'last',
#   'draw',
#   'in',
#   'full',
#   'th',
#   'june',
#   'pm',
#   'pm',
#   'st',
#   'juli',
#   'pm'],
#  ['power', 'by'],
#  ['are',
#   'you',
# ...
#   'world',
#   'cup'],
#  ['fire', 'and', 'fake', 'love', 'by'],
#  ['pleas', 'play', 'of'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['best',
#   'goal',
#   'of',
#   'the',
#   'so',
#   'far',
#   'beauti',
#   'pass',
#   'perfect',
#   'first',
#   'touch',
#   'out',
#   'of',
#   'this',
#   'world',
#   'second',
#   'touch',
#   'brilli'],
#  ['the',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'game',
#   'goal',
#   'nil',
#   'nil',
#   'draw',
#   'penalti',
#   'own',
#   'goal'],
#  ['pleas', 'play'],
#  ['exo',
#   'energet',
#   'song',
#   'power',
#   'would',
#   'be',
#   'so',
#   'suitabl',
#   'to',
#   'be',
#   'play',
#   'the',
#   'song',
#   'have',
#   'be',
#   'perform',
#   'at',
#   'the',
#   'closin'],
#  ['pleas', 'play', 'of'],
#  ['olarrrr',
#   'we',
#   'want',
#   'to',
#   'hear',
#   'fake',
#   'love',
#   'by',
#   'at',
#   'play',
#   'for',
#   'us'],
#  ['as',
#   'the',
#   'group',
#   'stage',
#   'end',
#   'we',
#   'say',
#   'farewel',
#   'to',
#   'team',
#   'from',
#   'this',
#   'year',
#   'fifa',
#   'thank',
#   'for',
#   'the',
#   'memori'],
#  ['after',
#   'this',
#   'horrend',
#   'day',
#   'for',
#   'my',
#   'profess',
#   'that',
#   'began',
#   'with',
#   'the',
#   'joy',
#   'of',
#   'the',
#   'pleas',
#   'watch',
#   'this',
#   'uplift',
#   'video',
#   'of',
#   'on'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark',
#   'croatia'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['when',
#   'you',
#   'have',
#   'almost',
#   'made',
#   'it',
#   'through',
#   'whole',
#   'day',
#   'with',
#   'no',
#   'action'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['trigger', 'the', 'fever', 'by', 'nct', 'dream'],
#  ['pleas', 'play', 'power', 'by', 'exo'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['play', 'power', 'by', 'exo'],
#  ['exo', 'power'],
#  ['exo', 'power', 'pleas', 'play', 'of'],
#  ['it', 'there', 'for', 'the', 'take'],
#  ['rt', 'and', 'comment', 'pleas', 'play', 'of'],
#  ['trent',
#   'alexand',
#   'arnold',
#   'last',
#   'month',
#   'liverpool',
#   'debut',
#   'pl',
#   'debut',
#   'first',
#   'pl',
#   'goal',
#   'ucl',
#   'debut',
#   'ucl',
#   'debut',
#   'goal',
#   'ucl'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['airplan', 'pt'],
#  ['no', 'game', 'today', 'got', 'us', 'feel', 'like'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['trent',
#   'alexand',
#   'arnold',
#   'last',
#   'month',
#   'liverpool',
#   'debut',
#   'pl',
#   'debut',
#   'first',
#   'pl',
#   'goal',
#   'ucl',
#   'debut',
#   'ucl',
#   'debut',
#   'goal',
#   'ucl'],
#  ['bellanaija', 'japan', 'poland', 'watch', 'highlight'],
#  ['global',
#   'festiv',
#   'with',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheer',
#   'thank',
#   'to',
#   'the',
#   'foreign',
#   'support',
#   'from',
#   'differ',
#   'co'],
#  ['bellanaija',
#   'seneg',
#   'journey',
#   'come',
#   'to',
#   'an',
#   'end',
#   'after',
#   'loss',
#   'to',
#   'colombia',
#   'watch',
#   'highlight'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen',
#   'to'],
#  ['power', 'by'],
#  ['nct', 'dream', 'trigger', 'the', 'fever'],
#  ['say',
#   'can',
#   'take',
#   'confid',
#   'from',
#   'their',
#   'collect',
#   'experi',
#   'ahead',
#   'of',
#   'round',
#   'of'],
#  ['darl',
#   'can',
#   'you',
#   'at',
#   'least',
#   'take',
#   'someth',
#   'befor',
#   'go',
#   'to',
#   'bed',
#   'nigerian',
#   'men'],
#  ['anoth',
#   'song',
#   'would',
#   'like',
#   'to',
#   'recommend',
#   'is',
#   'hard',
#   'carri',
#   'by',
#   'hard',
#   'carri',
#   'hey',
#   'it',
#   'so',
#   'hype',
#   'and',
#   'so'],
#  ['like',
#   'or',
#   'rt',
#   'this',
#   'to',
#   'subscrib',
#   'to',
#   'your',
#   'digit',
#   'match',
#   'day',
#   'program'],
#  ['it',
#   'good',
#   'song',
#   'with',
#   'rhythm',
#   'that',
#   'can',
#   'burn',
#   'your',
#   'spirit'],
#  ['coral',
#   'sport',
#   'sat',
#   'th',
#   'june',
#   'uruguay',
#   'portug',
#   'coral',
#   'offer',
#   'max',
#   'bet',
#   'ronaldo',
#   'to',
#   'score',
#   'new',
#   'custom',
#   'onli',
#   'cs',
#   'appli',
#   'gambl',
#   'awar',
#   'claim'],
#  ['all', 'you', 'need', 'in', 'is', 'power'],
#  ['can',
#   'you',
#   'predict',
#   'the',
#   'result',
#   'of',
#   'who',
#   'will',
#   'score',
#   'first',
#   'when',
#   'face',
#   'how',
#   'will',
#   'finish',
#   'join',
#   'in'],
#  ['exol',
#   'pleas',
#   'repli',
#   'quot',
#   'tweet',
#   'below',
#   'with',
#   'request',
#   'exo',
#   'power',
#   'as',
#   'favourit',
#   'song',
#   'it',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadi'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['when', 'you', 'realis', 'there', 'are', 'no', 'game', 'on', 'today'],
#  ['the',
#   'energi',
#   'use',
#   'will',
#   'be',
#   'redirect',
#   'to',
#   'warm',
#   'myself',
#   'by',
#   'the',
#   'tv',
#   'which',
#   'is',
#   'on',
#   'for',
#   'the'],
#  ['an',
#   'estim',
#   'million',
#   'pint',
#   'were',
#   'pour',
#   'in',
#   'the',
#   'uk',
#   'last',
#   'night',
#   'just',
#   'imagin',
#   'if',
#   'we',
#   'win',
#   'the',
#   'bloodi',
#   'thing'],
#  ['o', 'e', 'p', 'w', 'r', 'o', 'e', 'by', 'exo'],
#  ['power',
#   'by',
#   'exo',
#   'is',
#   'your',
#   'song',
#   'fifa',
#   'it',
#   'go',
#   'to',
#   'turn',
#   'up',
#   'the',
#   'mood',
#   'even',
#   'more',
#   'will',
#   'bring',
#   'the',
#   'festiv',
#   'atmospher'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'it',
#   'was',
#   'perform',
#   'in',
#   'the',
#   'olymp',
#   'and',
#   'it',
#   'was',
#   'the',
#   'first',
#   'song',
#   'play',
#   'in',
#   'th'],
#  ['pleas', 'play', 'of'],
#  ['queroooooooo',
#   'we',
#   'want',
#   'to',
#   'hear',
#   'fake',
#   'love',
#   'by',
#   'at',
#   'play',
#   'for',
#   'us'],
#  ['good', 'morn'],
#  ['retweet',
#   'weight',
#   'watcher',
#   'readi',
#   'for',
#   'the',
#   'big',
#   'game',
#   'tonight',
#   'of',
#   'england',
#   'vs',
#   'belgium',
#   'in',
#   'battl',
#   'of',
#   'dessert',
#   'which',
#   'would',
#   'you',
#   'pick',
#   'find',
#   'both',
#   'recip',
#   'below'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen',
#   'to'],
#  ['we',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'is',
#   'such',
#   'energet',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'it',
#   'was',
#   'chosen'],
#  ['pleas', 'play', 'of'],
#  ['they',
#   'were',
#   'onli',
#   'befor',
#   'this',
#   'keisuk',
#   'honda',
#   'becom',
#   'the',
#   'th',
#   'ever',
#   'asian',
#   'player',
#   'to',
#   'score',
#   'in',
#   'world',
#   'cup',
#   'compet'],
#  ['thank', 'you', 'for', 'everyth', 'you', 'do', 'south', 'korea'],
#  ['the',
#   'world',
#   'footbal',
#   'phone',
#   'in',
#   'is',
#   'back',
#   'for',
#   'knockout',
#   'special',
#   'join',
#   'is',
#   'the',
#   'legendinho',
#   'northern',
#   'seoul',
#   'and',
#   'our',
#   'world',
#   'footbal',
#   'fan',
#   'how',
#   'did',
#   'you',
#   'cope',
#   'with',
#   'day',
#   'of',
#   'no',
#   'game'],
#  ['readi',
#   'for',
#   'the',
#   'big',
#   'game',
#   'tonight',
#   'of',
#   'england',
#   'vs',
#   'belgium',
#   'in',
#   'battl',
#   'of',
#   'dessert',
#   'which',
#   'would',
#   'you',
#   'pick',
#   'find',
#   'both',
#   'reci'],
#  ['power', 'by'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark',
#   'croatia'],
#  ['point',
#   'gd',
#   'score',
#   'head',
#   'to',
#   'head',
#   'yellow',
#   'card',
#   'for',
#   'the',
#   'first',
#   'time',
#   'ever',
#   'team',
#   'has',
#   'been',
#   'kno'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['most',
#   'take',
#   'on',
#   'complet',
#   'in',
#   'the',
#   'group',
#   'stage',
#   'lionel',
#   'messi',
#   'neymar',
#   'oghenekaro',
#   'etebo'],
#  ['mart',
#   'nez',
#   'is',
#   'fulli',
#   'fit',
#   'he',
#   'complet',
#   'the',
#   'train',
#   'session',
#   'today'],
#  ['it',
#   'realli',
#   'is',
#   'the',
#   'global',
#   'game',
#   'where',
#   'have',
#   'you',
#   'been',
#   'watch',
#   'the',
#   'from'],
#  ['qatar',
#   'lawyer',
#   'tri',
#   'desper',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communic',
#   'out',
#   'of',
#   'fe'],
#  ['did', 'someon', 'say', 'footbal', 'can', 'not', 'wait', 'for', 'tomorrow'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['exo',
#   'energet',
#   'song',
#   'power',
#   'would',
#   'be',
#   'so',
#   'suitabl',
#   'to',
#   'be',
#   'play',
#   'the',
#   'song',
#   'have',
#   'be',
#   'perform',
#   'at',
#   'the',
#   'closin'],
#  ['resili',
#   'can',
#   'give',
#   'you',
#   'strength',
#   'to',
#   'keep',
#   'move',
#   'forward',
#   'when',
#   'you',
#   'are',
#   'caught',
#   'in',
#   'the',
#   'rain',
#   'or',
#   'storm',
#   'and',
#   'keep',
#   'you',
#   'continuin'],
#  ['star', 'have', 'reach', 'the', 'knockout', 'stage', 'marco', 'rojo'],
#  ['the', 'seneg', 'defend', 'watch', 'colombia', 'score'],
#  ['break', 'trump', 'epic', 'world', 'cup', 'speech'],
#  ['charg', 'the', 'world', 'wait', 'for', 'leo', 'messi', 'tomorrow'],
#  ['pleas', 'play', 'of'],
#  ['retweet',
#   'if',
#   'your',
#   'countri',
#   'are',
#   'still',
#   'in',
#   'the',
#   'russia',
#   'uruguay',
#   'spain',
#   'portug',
#   'franc',
#   'denmark',
#   'croatia'],
#  ['think',
#   'of',
#   'would',
#   'be',
#   'an',
#   'amaz',
#   'song',
#   'for',
#   'the',
#   'world',
#   'cup'],
#  ['here',
#   'our',
#   'pick',
#   'for',
#   'our',
#   'world',
#   'cup',
#   'squad',
#   'which',
#   'oper',
#   'would',
#   'you',
#   'sub',
#   'in',
#   'https'],
#  ['as',
#   'the',
#   'group',
#   'stage',
#   'end',
#   'we',
#   'say',
#   'farewel',
#   'to',
#   'team',
#   'from',
#   'this',
#   'year',
#   'fifa',
#   'thank',
#   'for',
#   'the',
#   'memori'],
#  ['fake',
#   'love',
#   'by',
#   'bts',
#   'the',
#   'best',
#   'of',
#   'the',
#   'best',
#   'for',
#   'this'],
#  ['colombian',
#   'man',
#   'help',
#   'his',
#   'deaf',
#   'and',
#   'blind',
#   'friend',
#   'experi',
#   'the',
#   'joy',
#   'of',
#   'their',
#   'team',
#   'campaign',
#   'read',
#   'this',
#   'and',
#   'more'],
#  ['pleas', 'play', 'of'],
#  ['fire', 'and', 'fake', 'love', 'by'],
#  ['top',
#   'goalscor',
#   'by',
#   'leagu',
#   'la',
#   'liga',
#   'premier',
#   'leagu',
#   'bundesliga'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['here',
#   'how',
#   'group',
#   'finish',
#   'up',
#   'mean',
#   'play',
#   'and',
#   'play',
#   'in',
#   'the',
#   'next',
#   'round'],
#  ['just',
#   'wrote',
#   'my',
#   'first',
#   'piec',
#   'for',
#   'it',
#   'on',
#   'the',
#   'racist',
#   'slant',
#   'eye',
#   'gestur',
#   'that',
#   'keep',
#   'appear',
#   'at',
#   'the'],
#  ['no', 'game', 'today', 'got', 'us', 'feel', 'like'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['global',
#   'festiv',
#   'with',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheer',
#   'thank',
#   'to',
#   'the',
#   'foreign',
#   'support',
#   'from',
#   'differ',
#   'co'],
#  ['so', 'exci'],
#  ['the',
#   'song',
#   'is',
#   'play',
#   'at',
#   'the',
#   'biggest',
#   'fountain',
#   'in',
#   'dubai',
#   'and',
#   'the',
#   'song',
#   'is',
#   'veri',
#   'passion',
#   'and',
#   'uniqu',
#   'we',
#   'got'],
#  ['pleas', 'play', 'by'],
#  ['pleas', 'play', 'of'],
#  ['power', 'by', 'exo'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['kylian',
#   'mbapp',
#   'will',
#   'donat',
#   'everyth',
#   'he',
#   'earn',
#   'with',
#   'at',
#   'the',
#   'to',
#   'chariti',
#   'this',
#   'will',
#   'add',
#   'up',
#   'to',
#   'per',
#   'game'],
#  ['pleas', 'play', 'of'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['power', 'by'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['we',
#   'will',
#   'have',
#   'twelv',
#   'madridista',
#   'involv',
#   'in',
#   'the',
#   'last',
#   'of',
#   'the',
#   'find',
#   'out',
#   'who'],
#  ['have',
#   'to',
#   'leav',
#   'the',
#   'world',
#   'cup',
#   'alreadi',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'we',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['qatar',
#   'lawyer',
#   'tri',
#   'desper',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communic',
#   'out',
#   'of',
#   'fe'],
#  ['it',
#   'time',
#   'to',
#   'give',
#   'the',
#   'superior',
#   'song',
#   'the',
#   'recognit',
#   'it',
#   'deserv',
#   'request',
#   'nct',
#   'dream',
#   'trigger',
#   'the',
#   'fever',
#   'on',
#   'their'],
#  ['photo', 'or', 'renaiss', 'art', 'can', 'we', 'get', 'rule'],
#  ['o', 'e', 'p', 'w', 'r', 'o', 'e', 'by', 'exo'],
#  ['got',
#   'favourit',
#   'tune',
#   'tell',
#   'us',
#   'below',
#   'and',
#   'your',
#   'choic',
#   'could',
#   'be',
#   'play',
#   'in',
#   'stadium'],
#  ['pleas',
#   'play',
#   'power',
#   'by',
#   'exo',
#   'exo',
#   'also',
#   'perform',
#   'dure',
#   'the',
#   'close',
#   'ceremoni',
#   'of',
#   'the',
#   'winter',
#   'olymp',
#   'the',
#   'song',
#   'is'],
#  ['espn',
#   'lionel',
#   'messi',
#   'is',
#   'the',
#   'first',
#   'player',
#   'to',
#   'score',
#   'goal',
#   'in',
#   'his',
#   'teen',
#   'and'],
#  ['today',
#   'is',
#   'the',
#   'anniversari',
#   'of',
#   'the',
#   'upset',
#   'of',
#   'england',
#   'at',
#   'the',
#   'here',
#   'retrospect',
#   'from',
#   'the',
#   'lat'],
#  ['pleas', 'play', 'of'],
#  ['bts',
#   'obviusli',
#   'these',
#   'song',
#   'fake',
#   'love',
#   'it',
#   'veri',
#   'belov',
#   'song',
#   'it',
#   'liter',
#   'perfect',
#   'and',
#   'of',
#   'co'],
#  ['pleas', 'play', 'of'],
#  ['exo', 'power'],
#  ['all',
#   'team',
#   'given',
#   'score',
#   'out',
#   'of',
#   'what',
#   'would',
#   'you',
#   'give',
#   'the'],
#  ['power', 'de', 'exo', 'pleas', 'play', 'of', 'https'],
#  ['power',
#   'by',
#   'is',
#   'the',
#   'onli',
#   'global',
#   'hit',
#   'song',
#   'that',
#   'has',
#   'lyric',
#   'fit',
#   'for',
#   'sport',
#   'event',
#   'give',
#   'the',
#   'athlet'],
#  ['pleas', 'play', 'of'],
#  ['kylian',
#   'mbapp',
#   'will',
#   'donat',
#   'everyth',
#   'he',
#   'earn',
#   'with',
#   'at',
#   'the',
#   'to',
#   'chariti',
#   'this',
#   'will',
#   'add',
#   'up',
#   'to',
#   'per',
#   'game'],
#  ['icymi',
#   'some',
#   'muse',
#   'day',
#   'perfect',
#   'group',
#   'stage',
#   'doe',
#   'not',
#   'away',
#   'mean',
#   'championship',
#   'https'],
#  ['messi', 'get', 'face', 'save', 'kazan', 'mural', 'to', 'match', 'ronaldo'],
#  ['rt', 'and', 'comment', 'pleas', 'play', 'of'],
#  ['pleas', 'play', 'power', 'by', 'exo', 'thank'],
#  ...]

# %%
lemmatizer = WordNetLemmatizer()
tweets_lemm = []
for i in tweet_arr:
    lemmatized_list = [lemmatizer.lemmatize(token) for token in i]
    tweets_lemm.append(lemmatized_list)
tweets_lemm
# Out:
# [['Want',
#   'to',
#   'make',
#   'this',
#   'summer',
#   'football',
#   'that',
#   'little',
#   'bit',
#   'hotter',
#   'RT',
#   'follow',
#   'to'],
#  ['Didier',
#   'Deschamps',
#   'ha',
#   'confirmed',
#   'Benjamin',
#   'Mendy',
#   'will',
#   'miss',
#   'tomorrow',
#   'game',
#   'for',
#   'against',
#   'due',
#   'to',
#   'muscular',
#   'problem'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['week',
#   'team',
#   'game',
#   'goal',
#   'The',
#   'group',
#   'stage',
#   'wa',
#   'everything',
#   'we',
#   'hoped',
#   'for'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Hi',
#   'everyone',
#   'Lets',
#   'get',
#   'started',
#   'Round',
#   'am',
#   'so',
#   'excited',
#   'but',
#   'miss',
#   'every',
#   'football',
#   'league',
#   'that',
#   'will',
#   'come',
#   'after',
#   'World',
#   'Cup',
#   'a',
#   'well'],
#  ['First',
#   'night',
#   'with',
#   'no',
#   'world',
#   'cup',
#   'game',
#   'have',
#   'had',
#   'chat',
#   'with',
#   'my',
#   'missus',
#   'She',
#   'seems',
#   'nice',
#   'girl',
#   'to',
#   'be',
#   'fair'],
#  ['Batshuayi', 'with', 'arguably', 'the', 'funniest', 'moment', 'of', 'this'],
#  ['global',
#   'festival',
#   'with',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'to',
#   'the',
#   'foreign',
#   'supporter',
#   'from',
#   'different',
#   'co'],
#  ['Watch',
#   'Budweiser',
#   'Yerry',
#   'Mina',
#   'talk',
#   'about',
#   'his',
#   'squad',
#   'dance',
#   'What',
#   'should',
#   'they',
#   'do',
#   'next',
#   'http'],
#  ['Power', 'de', 'EXO', 'Please', 'play', 'of', 'http'],
#  ['The',
#   'Round',
#   'of',
#   'is',
#   'confirmed',
#   'Tin',
#   'Jedvaj',
#   'and',
#   'Croatia',
#   'will',
#   'take',
#   'on',
#   'Denmark',
#   'on',
#   'Sunday'],
#  ['Power', 'Please', 'play', 'of'],
#  ['CHARGING', 'The', 'world', 'wait', 'for', 'Leo', 'Messi', 'tomorrow'],
#  ['EXO',
#   'let',
#   'reply',
#   'this',
#   'tweet',
#   'and',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'be',
#   'played',
#   'in',
#   'Do',
#   'it',
#   'politely',
#   'Mention',
#   'abou'],
#  ['global',
#   'festival',
#   'with',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'to',
#   'the',
#   'foreign',
#   'supporter',
#   'from',
#   'different',
#   'co'],
#  ['There',
#   'you',
#   'have',
#   'it',
#   'The',
#   'last',
#   'have',
#   'been',
#   'confirmed',
#   'Catch',
#   'up',
#   'on',
#   'all',
#   'the',
#   'highlight',
#   'here',
#   'ht'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen'],
#  ['Soccer',
#   'themed',
#   'nesting',
#   'doll',
#   'score',
#   'point',
#   'with',
#   'fan',
#   'See',
#   'more'],
#  ['recommend',
#   'LO',
#   'SIENTO',
#   'By',
#   'Super',
#   'Junior',
#   'ft',
#   'Leslie',
#   'Grace',
#   'and',
#   'Playnskillz',
#   'Its',
#   'very',
#   'nice',
#   'trilingual',
#   'song',
#   'English',
#   'Spanish'],
#  ['Please', 'play', 'of'],
#  ['Mexican',
#   'pop',
#   'fan',
#   'celebrated',
#   'South',
#   'Koreas',
#   'win',
#   'in',
#   'their',
#   'own',
#   'way',
#   'mass',
#   'streaming',
#   'hit',
#   'single',
#   'Fake'],
#  ['When',
#   'you',
#   'have',
#   'almost',
#   'made',
#   'it',
#   'through',
#   'whole',
#   'day',
#   'with',
#   'no',
#   'action'],
#  ['Second', 'half', 'surge', 'see', 'Tunisia', 'bow', 'out', 'in', 'style'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['global',
#   'festival',
#   'with',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'to',
#   'the',
#   'foreign',
#   'supporter',
#   'from',
#   'different',
#   'co'],
#  ['Please', 'play', 'of'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['The', 'Senegal', 'defender', 'watching', 'Colombia', 'score'],
#  ['Please', 'play', 'of'],
#  ['Cameraman',
#   'FC',
#   'ha',
#   'been',
#   'the',
#   'real',
#   'MVP',
#   'of',
#   'the',
#   'so',
#   'far'],
#  ['You',
#   'should',
#   'play',
#   'it',
#   'wa',
#   'performed',
#   'at',
#   'the',
#   'Olympics',
#   'and',
#   'played',
#   'in',
#   'dubai',
#   'fountain',
#   'show',
#   'a',
#   'well',
#   'it'],
#  ['EXO',
#   'let',
#   'reply',
#   'this',
#   'tweet',
#   'and',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'be',
#   'played',
#   'in',
#   'Do',
#   'it',
#   'politely',
#   'Mention',
#   'abou'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['You',
#   'should',
#   'play',
#   'it',
#   'wa',
#   'performed',
#   'at',
#   'the',
#   'Olympics',
#   'and',
#   'played',
#   'in',
#   'dubai',
#   'fountain',
#   'show',
#   'a',
#   'well',
#   'it'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'below',
#   'with',
#   'requesting',
#   'EXO',
#   'Power',
#   'a',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadi'],
#  ['power', 'by'],
#  ['All', 'you', 'need', 'in', 'is', 'POWER'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['My', 'favourite', 'song', 'is', 'Fake', 'Love', 'by', 'thank', 'you'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Waking',
#   'up',
#   'this',
#   'morning',
#   'and',
#   'realizing',
#   'that',
#   'there',
#   'are',
#   'no',
#   'game',
#   'today'],
#  ['RT', 'and', 'comment', 'Please', 'play', 'of'],
#  ['Power',
#   'by',
#   'Exo',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please'],
#  ['Please', 'play', 'of'],
#  ['Guardiola',
#   'win',
#   'the',
#   'league',
#   'in',
#   'Spain',
#   'Spain',
#   'win',
#   'the',
#   'World',
#   'Cup',
#   'Guardiola',
#   'win',
#   'the',
#   'league',
#   'in',
#   'Germany'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['of', 'Po', 'Favor'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['voted',
#   'EXO',
#   'POWER',
#   'to',
#   'be',
#   'played',
#   'in',
#   'stadium',
#   'The',
#   'song',
#   'is',
#   'so',
#   'amazing',
#   'and',
#   'lit',
#   'and'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Power',
#   'by',
#   'This',
#   'song',
#   'is',
#   'so',
#   'energetic',
#   'really',
#   'suitable',
#   'for',
#   'worldcup',
#   'also',
#   'performed',
#   'on'],
#  ['Please', 'play', 'of'],
#  ['Please', 'play', 'of'],
#  ['voted',
#   'EXO',
#   'POWER',
#   'to',
#   'be',
#   'played',
#   'in',
#   'stadium',
#   'The',
#   'song',
#   'is',
#   'so',
#   'amazing',
#   'and',
#   'lit',
#   'and',
#   'en'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Please',
#   'play',
#   'of',
#   'WE',
#   'GOT',
#   'THE',
#   'POWER',
#   'EVERY',
#   'TIME',
#   'http'],
#  ['Please', 'play', 'of'],
#  ['tub',
#   'of',
#   'Haribo',
#   'of',
#   'your',
#   'choice',
#   'Simply',
#   'predict',
#   'the',
#   'st',
#   'goalscorer',
#   'of',
#   'tomorrow',
#   'night',
#   'crunch',
#   'last',
#   'tie',
#   'betwee'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Please', 'play', 'of'],
#  ['GOT',
#   'THE',
#   'New',
#   'Era',
#   'at',
#   'No',
#   'on',
#   'Billboard',
#   'Japan',
#   'a',
#   'the',
#   'boost',
#   'Suchmos'],
#  ['When', 'two', 'meme', 'meet'],
#  ['of', 'POWER', 'POWER'],
#  ['My', 'favorite', 'song', 'is', 'by'],
#  ['very',
#   'proud',
#   'moment',
#   'to',
#   'lead',
#   'out',
#   'my',
#   'country',
#   'at',
#   'the',
#   'last',
#   'night',
#   'Seen',
#   'some',
#   'celebration',
#   'video',
#   'from',
#   'back',
#   'home',
#   'love',
#   'them'],
#  ['of', 'Po', 'Favor'],
#  ['Another', 'cheerful', 'Colombian', 'celebration'],
#  ['So', 'Exci'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Its', 'there', 'for', 'the', 'taking'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark'],
#  ['recommend',
#   'LO',
#   'SIENTO',
#   'By',
#   'Super',
#   'Junior',
#   'ft',
#   'Leslie',
#   'Grace',
#   'and',
#   'Playnskillz',
#   'Its',
#   'very',
#   'nice',
#   'trilingual',
#   'song',
#   'English',
#   'Spanish'],
#  ['am', 'choose'],
#  ['this'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen',
#   'to'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'of',
#   'agreement',
#   'with',
#   'Sampdoria',
#   'for',
#   'Torreira',
#   'but',
#   'nothing',
#   'signed',
#   'no',
#   'player'],
#  ['Your', 'mother', 'come', 'first', 'Chat', 'about', 'Jesus'],
#  ['EXO', 'POWER', 'VAMOS', 'Please', 'play', 'of'],
#  ['recommend',
#   'GO',
#   'HIGHER',
#   'by',
#   'Its',
#   'the',
#   'perfect',
#   'song',
#   'to',
#   'energize',
#   'all',
#   'the',
#   'player',
#   'in',
#   'the'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Please',
#   'play',
#   'POWER',
#   'by',
#   'Its',
#   'bop',
#   'plus',
#   'it',
#   'about',
#   'hope',
#   'and',
#   'empowerment',
#   'Thanks',
#   'much'],
#  ['FOUND', 'THE', 'VIDEO', 'HAHAHA', 'play', 'blackpink', 'forever', 'young'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Fake', 'Love'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['knockout',
#   'bracket',
#   'is',
#   'here',
#   'Sadly',
#   'Germany',
#   'is',
#   'out',
#   'The',
#   'Joachim',
#   'w',
#   'hailing',
#   'cab',
#   'meme',
#   'is',
#   'going',
#   'to',
#   'waste',
#   'Still',
#   'laughing',
#   'at',
#   'this',
#   'Germany',
#   'they',
#   'have',
#   'manager',
#   'coach',
#   'who',
#   'always',
#   'look',
#   'like',
#   'an',
#   'aging',
#   'Beatle',
#   'trying',
#   'to',
#   'hail',
#   'cab'],
#  ['Mic', 'Drop', 'by', 'ft'],
#  ['EXO', 'POWER', 'everyone', 'will', 'be', 'happy', 'to', 'hear', 'it'],
#  ['You',
#   'know',
#   'Ronaldo',
#   'You',
#   'know',
#   'Messi',
#   'You',
#   'know',
#   'Neymar',
#   'Do',
#   'you',
#   'know',
#   'who',
#   'scored',
#   'more',
#   'goal',
#   'but',
#   'got',
#   'paid',
#   'much',
#   'much',
#   'le',
#   'Abby',
#   'Wam'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communication',
#   'out',
#   'of',
#   'fe'],
#  ['conclusion',
#   'power',
#   'fit',
#   'perfectly',
#   'with',
#   'the',
#   'energy',
#   'of',
#   'championship',
#   'a',
#   'it',
#   'is',
#   'the',
#   'world',
#   'cup',
#   'We',
#   'got',
#   'that',
#   'power'],
#  ['So',
#   'who',
#   'going',
#   'through',
#   'to',
#   'the',
#   'semi',
#   'final',
#   'between',
#   'Brazil',
#   'and',
#   'Belgium',
#   'Sol',
#   'Campbell',
#   'think',
#   'France'],
#  ['AIRPLANE', 'PT', 'by', 'BTS', 'Thankyou'],
#  ['Female',
#   'reporter',
#   'have',
#   'faced',
#   'sexism',
#   'in',
#   'sport',
#   'for',
#   'decade',
#   'but',
#   'at',
#   'this',
#   'year',
#   'some',
#   'are',
#   'speaking',
#   'out'],
#  ['POWER', 'EXO'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['As', 'they', 'say', 'this', 'is', 'football', 'ANYTHING', 'can', 'happen'],
#  ['GOT',
#   'THE',
#   'New',
#   'Era',
#   'at',
#   'No',
#   'on',
#   'Billboard',
#   'Japan',
#   'a',
#   'the',
#   'boost',
#   'Suchmos'],
#  ['recommend',
#   'LO',
#   'SIENTO',
#   'By',
#   'Super',
#   'Junior',
#   'ft',
#   'Leslie',
#   'Grace',
#   'and',
#   'Playnskillz',
#   'Its',
#   'very',
#   'nice',
#   'trilingual',
#   'song',
#   'English',
#   'Spanish'],
#  ['You',
#   'can',
#   'still',
#   'participate',
#   'in',
#   'our',
#   'competition',
#   'What',
#   'are',
#   'you',
#   'waiting',
#   'for',
#   'Win',
#   'valuable',
#   'electronic'],
#  ['EXO', 'POWER', 'Please', 'play', 'of'],
#  ['huge', 'day', 'in', 'Group', 'TEAM', 'NEWS'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Just',
#   'reminder',
#   'a',
#   'there',
#   'are',
#   'no',
#   'game',
#   'on',
#   'today',
#   'Air',
#   'Bud',
#   'World',
#   'Pup',
#   'is',
#   'on',
#   'Netflix'],
#  ['power', 'by'],
#  ['My',
#   'postcard',
#   'to',
#   'Jennifer',
#   'Salke',
#   'at',
#   'am',
#   'from',
#   'the',
#   'future',
#   'after',
#   'all',
#   'S',
#   'would',
#   'tell',
#   'you',
#   'who',
#   'won'],
#  ['Because', 'WE', 'GOT', 'THAT', 'POWER', 'Power'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Last',
#   'day',
#   'of',
#   'round',
#   'one',
#   'Make',
#   'you',
#   'pick',
#   'for',
#   'the',
#   'round',
#   'of',
#   'to',
#   'start',
#   'earning',
#   'MVU'],
#  ['Iceland', 'head', 'coach', 'day', 'after', 'elimination', 'Reddit'],
#  ['O', 'E', 'P', 'W', 'R', 'O', 'E', 'by', 'EXO'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['RETWEET',
#   'if',
#   'you',
#   'think',
#   'Cristiano',
#   'Ronaldo',
#   'will',
#   'score',
#   'against',
#   'Uruguay'],
#  ['power', 'by'],
#  ['Power', 'exo', 'Its', 'very', 'suitable', 'for', 'worldcup', 'think'],
#  ['No',
#   'fixture',
#   'today',
#   'but',
#   'this',
#   'GIF',
#   'should',
#   'help',
#   'pas',
#   'the',
#   'time',
#   'until',
#   'the',
#   'tournament',
#   'resume'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['The', 'Senegal', 'defender', 'watching', 'Colombia', 'score'],
#  ['Mexico',
#   'fan',
#   'going',
#   'through',
#   'security',
#   'in',
#   'Russia',
#   'Wait',
#   'for',
#   'it'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Vamos', 'EXO', 'RT', 'RT', 'Please', 'play', 'of'],
#  ['EXO', 'Olympics', 'EXO', 'Nations', 'Pick', 'POWER'],
#  ['Theres',
#   'more',
#   'to',
#   'than',
#   'being',
#   'the',
#   'smallest',
#   'nation',
#   'to',
#   'ever',
#   'qualify',
#   'for',
#   'the',
#   'Its',
#   'also',
#   'global',
#   'lead'],
#  ['power', 'by'],
#  ['Please', 'play', 'of'],
#  ['Hugo',
#   'Lloris',
#   'France',
#   'We',
#   'have',
#   'studied',
#   'Argeninas',
#   'group',
#   'game',
#   'which',
#   'give',
#   'u',
#   'an',
#   'indication',
#   'but',
#   'we',
#   'know',
#   'player',
#   'like',
#   'Messi',
#   'can',
#   'step',
#   'up',
#   'his',
#   'own',
#   'level',
#   'and',
#   'decide',
#   'the',
#   'fate',
#   'of',
#   'the',
#   'match',
#   'a',
#   'he',
#   'doe',
#   'with',
#   'Argentina',
#   'and',
#   'Barcelona'],
#  ['AIRPLANE', 'PT', 'by', 'BTS', 'Thankyou'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['EXO',
#   'let',
#   'reply',
#   'this',
#   'tweet',
#   'and',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'be',
#   'played',
#   'in',
#   'Do',
#   'it',
#   'politely',
#   'Mention',
#   'abou'],
#  ['Probable', 'line', 'up', 'for'],
#  ['If',
#   'you',
#   'only',
#   'read',
#   'one',
#   'Germany',
#   'World',
#   'Cup',
#   'post',
#   'mortem',
#   'make',
#   'it',
#   'this',
#   'one'],
#  ['Never',
#   'do',
#   'this',
#   'again',
#   'When',
#   'man',
#   'tried',
#   'kiss',
#   'her',
#   'while',
#   'she',
#   'wa',
#   'reporting',
#   'at',
#   'the',
#   'Brazilian',
#   'journalist',
#   'foug'],
#  ['Can',
#   'you',
#   'predict',
#   'the',
#   'result',
#   'of',
#   'Who',
#   'will',
#   'score',
#   'first',
#   'when',
#   'face',
#   'How',
#   'will',
#   'finish',
#   'Join',
#   'in'],
#  ['Japanese',
#   'cartoonist',
#   'latest',
#   'cartoon',
#   'show',
#   'the',
#   'team',
#   'left',
#   'in',
#   'the',
#   'after',
#   'the',
#   'group',
#   'stage'],
#  ['Power',
#   'by',
#   'exo',
#   'is',
#   'suitable',
#   'and',
#   'energetic',
#   'song',
#   'which',
#   'can',
#   'be',
#   'played',
#   'at',
#   'the',
#   'world',
#   'cup',
#   'believe',
#   'people',
#   'from'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Everything',
#   'point',
#   'to',
#   'win',
#   'tomorrow',
#   'but',
#   'because',
#   'the',
#   'is',
#   'mad',
#   'think',
#   'will',
#   'do',
#   'it'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen',
#   'to'],
#  ['With',
#   'the',
#   'knockout',
#   'round',
#   'bracket',
#   'set',
#   'take',
#   'look',
#   'at',
#   'the',
#   'SPI',
#   'chance',
#   'to',
#   'advance',
#   'to',
#   'each',
#   'round',
#   'and',
#   'win',
#   'it',
#   'all',
#   'fr'],
#  ['Eggs',
#   'were',
#   'thrown',
#   'at',
#   'the',
#   'Korean',
#   'national',
#   'team',
#   'after',
#   'defeating',
#   'Germany',
#   'at',
#   'the',
#   'Spurs',
#   'forward',
#   'Son',
#   'Heung'],
#  ['GOT',
#   'THE',
#   'New',
#   'Era',
#   'at',
#   'No',
#   'on',
#   'Billboard',
#   'Japan',
#   'a',
#   'the',
#   'boost',
#   'Suchmos'],
#  ['When',
#   'you',
#   'have',
#   'almost',
#   'made',
#   'it',
#   'through',
#   'whole',
#   'day',
#   'with',
#   'no',
#   'action'],
#  ['Please', 'play', 'of'],
#  ['TYPES', 'OF', 'PEOPLE', 'WATCHING', 'THE', 'WORLD', 'CUP', 'full', 'vid'],
#  ['EXO', 'POWER', 'Please', 'play', 'of', 'http'],
#  ['power', 'by'],
#  ['It',
#   'really',
#   'is',
#   'the',
#   'global',
#   'game',
#   'Where',
#   'have',
#   'you',
#   'been',
#   'watching',
#   'the',
#   'from'],
#  ['Entrenamiento',
#   'previo',
#   'al',
#   'partido',
#   'de',
#   'octavo',
#   'de',
#   'final',
#   'v',
#   'Last',
#   'training',
#   'session',
#   'before',
#   'next',
#   'Rou'],
#  ['Who',
#   'is',
#   'facing',
#   'who',
#   'in',
#   'the',
#   'last',
#   'of',
#   'the',
#   'and',
#   'one',
#   'side',
#   'of',
#   'the',
#   'draw',
#   'is',
#   'loaded',
#   'with',
#   'former',
#   'winner',
#   'http'],
#  ['EXO', 'POWER', 'Please', 'play', 'of', 'htt'],
#  ['Fake', 'love', 'and', 'Airplane', 'pt', 'by'],
#  ['Please', 'play', 'of'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['AIRPLANE', 'PT', 'by', 'BTS', 'Thankyou'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'The',
#   'song',
#   'is',
#   'about',
#   'The',
#   'POWER',
#   'of',
#   'Music',
#   'and',
#   'how',
#   'it',
#   'brings',
#   'people',
#   'together',
#   'and',
#   'together',
#   'we',
#   'have'],
#  ['Please', 'play', 'of'],
#  ['power', 'by'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Power',
#   'by',
#   'exo',
#   'is',
#   'your',
#   'song',
#   'FIFA',
#   'Its',
#   'going',
#   'to',
#   'turn',
#   'up',
#   'the',
#   'mood',
#   'even',
#   'more',
#   'Will',
#   'bring',
#   'the',
#   'festive',
#   'atmosphere'],
#  ['Fake', 'Love', 'by'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Matchday',
#   'Round',
#   'of',
#   'TSN',
#   'am',
#   'ET',
#   'international',
#   'played',
#   'for',
#   'Juventus',
#   'international',
#   'played',
#   'for',
#   'Juventus',
#   'Good',
#   'luck',
#   'to'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['My', 'favorite', 'song', 'is', 'by'],
#  ['Internet', 'is', 'beautiful', 'place'],
#  ['BREAKING',
#   'Diego',
#   'Maradona',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'paid',
#   'FIFA',
#   'ambassador',
#   'after',
#   'his',
#   'embarrassing',
#   'and',
#   'provocotive',
#   'behaviour',
#   'during'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['global',
#   'festival',
#   'with',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'to',
#   'the',
#   'foreign',
#   'supporter',
#   'from',
#   'different',
#   'co'],
#  ['Please', 'play', 'of'],
#  ['Last', 'Fixtures', 'Saturday', 'v', 'v', 'Sunday', 'v', 'v'],
#  ['These',
#   'Brazil',
#   'fan',
#   'had',
#   'funeral',
#   'procession',
#   'through',
#   'the',
#   'street',
#   'when',
#   'Germany',
#   'got',
#   'knocked',
#   'out',
#   'of',
#   'the'],
#  ['Power', 'by', 'would', 'be', 'great', 'choice'],
#  ['O', 'E', 'P', 'W', 'R', 'O', 'E', 'by', 'EXO'],
#  ['Most',
#   'chance',
#   'created',
#   'in',
#   'the',
#   'group',
#   'stage',
#   'Neymar',
#   'Joshua',
#   'Kimmich',
#   'Mesut',
#   'zil',
#   'Salman',
#   'Al',
#   'Faraj'],
#  ['GROWL', 'Please', 'play', 'of'],
#  ['Just',
#   'reminder',
#   'a',
#   'there',
#   'are',
#   'no',
#   'game',
#   'on',
#   'today',
#   'Air',
#   'Bud',
#   'World',
#   'Pup',
#   'is',
#   'on',
#   'Netflix'],
#  ['Our',
#   'Fashion',
#   'art',
#   'icon',
#   'of',
#   'the',
#   'Week',
#   'for',
#   'The',
#   'Tool',
#   'Fest',
#   'go',
#   'to',
#   'Curated',
#   'by'],
#  ['Power', 'Please', 'play', 'of'],
#  ['As',
#   'the',
#   'group',
#   'stage',
#   'end',
#   'we',
#   'say',
#   'farewell',
#   'to',
#   'team',
#   'from',
#   'this',
#   'year',
#   'FIFA',
#   'Thanks',
#   'for',
#   'the',
#   'memory'],
#  ['Please', 'play', 'Such', 'great', 'song', 'to', 'cheer', 'everyone', 'up'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Coutinho', 'during', 'training', 'with', 'Brazil', 'on', 'Friday', 'getty'],
#  ['Iconic', 'celebration', 'of', 'the', 'so', 'far', 'Who', 'will'],
#  ['Power',
#   'by',
#   'Exo',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please'],
#  ['Good', 'Luck', 'for', 'the', 'at'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen'],
#  ['RT', 'and', 'comment', 'Please', 'play', 'of'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['power', 'by'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'Exo',
#   'it',
#   'wa',
#   'performed',
#   'in',
#   'the',
#   'Olympic',
#   'and',
#   'it',
#   'wa',
#   'the',
#   'first',
#   'song',
#   'played',
#   'in',
#   'th'],
#  ['NEW',
#   'POD',
#   'We',
#   'are',
#   'joined',
#   'by',
#   'to',
#   'preview',
#   'what',
#   'look',
#   'to',
#   'be',
#   'wildly',
#   'entertaining',
#   'Round',
#   'of'],
#  ['Zhou',
#   'Mi',
#   'Weibo',
#   'update',
#   'As',
#   'football',
#   'fan',
#   'can',
#   'not',
#   'miss',
#   'out',
#   'having',
#   'shirt'],
#  ['FOUND', 'THE', 'VIDEO', 'HAHAHA', 'play', 'blackpink', 'forever', 'young'],
#  ['The', 'lack', 'of', 'any', 'match', 'today'],
#  ['Its',
#   'time',
#   'to',
#   'give',
#   'the',
#   'superior',
#   'song',
#   'the',
#   'recognition',
#   'it',
#   'deserves',
#   'Request',
#   'NCT',
#   'Dreams',
#   'Trigger',
#   'The',
#   'Fever',
#   'on',
#   'their'],
#  ['voted',
#   'EXO',
#   'POWER',
#   'to',
#   'be',
#   'played',
#   'in',
#   'stadium',
#   'The',
#   'song',
#   'is',
#   'so',
#   'amazing',
#   'and',
#   'lit',
#   'and',
#   'energ'],
#  ['Oasis', 'Champagne', 'Supernova', 'Kid', 'Cudi'],
#  ['EXOs',
#   'energetic',
#   'song',
#   'POWER',
#   'would',
#   'be',
#   'so',
#   'suitable',
#   'to',
#   'be',
#   'played',
#   'The',
#   'song',
#   'have',
#   'being',
#   'performed',
#   'at',
#   'the',
#   'closin'],
#  ['Fake', 'love', 'by'],
#  ['Please', 'play', 'of'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['My', 'favorite', 'song', 'is', 'by'],
#  ['power', 'by'],
#  ['Wait', 'what'],
#  ['My', 'favorite', 'song', 'is', 'by'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark'],
#  ['for',
#   'Nigeria',
#   'at',
#   'the',
#   'Most',
#   'take',
#   'ons',
#   'completed',
#   'Most',
#   'foul',
#   'won',
#   'Most',
#   'shot',
#   'Joint',
#   'most'],
#  ['Rihanna',
#   'This',
#   'Is',
#   'What',
#   'You',
#   'Came',
#   'For',
#   'Taylor',
#   'Swift',
#   'Ready',
#   'For',
#   'It'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communication',
#   'out',
#   'of',
#   'fe'],
#  ['Exo', 'Power', 'is', 'the', 'perfect', 'song', 'plea', 'give', 'it', 'try'],
#  ['Waking',
#   'up',
#   'this',
#   'morning',
#   'and',
#   'realizing',
#   'that',
#   'there',
#   'are',
#   'no',
#   'game',
#   'today'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Something', 'very', 'soothing', 'about', 'this', 'kit', 'image'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Cameraman',
#   'FC',
#   'ha',
#   'been',
#   'the',
#   'real',
#   'MVP',
#   'of',
#   'the',
#   'so',
#   'far'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communication',
#   'out',
#   'of',
#   'fe'],
#  ['please', 'play', 'by', 'THANKYOU', 'SO', 'MUCH'],
#  ['Looking',
#   'for',
#   'some',
#   'entertainment',
#   'on',
#   'the',
#   'first',
#   'rest',
#   'day',
#   'You',
#   'are',
#   'in',
#   'safe',
#   'hand',
#   'with',
#   'at',
#   'our',
#   'exhibition'],
#  ['voted',
#   'EXO',
#   'POWER',
#   'to',
#   'be',
#   'played',
#   'in',
#   'stadium',
#   'The',
#   'song',
#   'is',
#   'so',
#   'amazing',
#   'and',
#   'lit',
#   'and',
#   'energ'],
#  ['VOTEN', 'por', 'power', 'de', 'EXO', 'Please', 'play', 'of'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'of',
#   'agreement',
#   'with',
#   'Sampdoria',
#   'for',
#   'Torreira',
#   'but',
#   'nothing',
#   'signed',
#   'no',
#   'player'],
#  ['This',
#   'is',
#   'what',
#   'the',
#   'and',
#   'have',
#   'in',
#   'common',
#   'people',
#   'from',
#   'different',
#   'country',
#   'and',
#   'culture',
#   'can',
#   'bond',
#   'over',
#   'good'],
#  ['EXO',
#   'let',
#   'reply',
#   'this',
#   'tweet',
#   'and',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'be',
#   'played',
#   'in',
#   'Do',
#   'it',
#   'politely',
#   'Mention',
#   'abou'],
#  ['global',
#   'festival',
#   'with',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'to',
#   'the',
#   'foreign',
#   'supporter',
#   'from',
#   'different',
#   'co'],
#  ['Colombian',
#   'man',
#   'help',
#   'his',
#   'deaf',
#   'and',
#   'blind',
#   'friend',
#   'experience',
#   'the',
#   'joy',
#   'of',
#   'their',
#   'team',
#   'campaign'],
#  ['Power', 'de', 'EXO', 'Please', 'play', 'of'],
#  ['I',
#   'picked',
#   'Argentina',
#   'to',
#   'win',
#   'the',
#   'Play',
#   'World',
#   'Cup',
#   'Knockout',
#   'Bracket',
#   'on',
#   'for',
#   'chance',
#   'to',
#   'win',
#   'cash',
#   'prize'],
#  ['We', 'know', 'who', 'this', 'guy', 'is', 'rooting', 'for', 'tomorrow'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen'],
#  ['EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'closing',
#   'ceremony',
#   'of',
#   'the',
#   'Olympics',
#   'Power',
#   'is',
#   'about',
#   'over',
#   'coming',
#   'challenge',
#   'with'],
#  ['Would',
#   'you',
#   'believe',
#   'after',
#   'Mexico',
#   'got',
#   'through',
#   'the',
#   'top',
#   'BTS',
#   'rose',
#   'to',
#   'spot',
#   'on',
#   'the',
#   'Mexican',
#   'iTunes',
#   'Lmao',
#   'ya',
#   'will',
#   'the',
#   'hype',
#   'is',
#   'real'],
#  ['When', 'you', 'realise', 'there', 'are', 'no', 'game', 'on', 'today'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['BTS',
#   'OBVIUSLY',
#   'THESE',
#   'SONGS',
#   'Fake',
#   'Love',
#   'Its',
#   'very',
#   'beloved',
#   'song',
#   'it',
#   'literally',
#   'perfect',
#   'And',
#   'of',
#   'co'],
#  ['Top',
#   'Goalscorers',
#   'By',
#   'League',
#   'La',
#   'Liga',
#   'Premier',
#   'League',
#   'Bundesliga',
#   'Ligue'],
#  ['This', 'absolutely', 'got', 'to', 'me', 'What', 'man'],
#  ['EXO', 'Power', 'please', 'we', 'have', 'got', 'that', 'POWER', 'POWER'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'below',
#   'with',
#   'requesting',
#   'EXO',
#   'Power',
#   'a',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadi'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['AIRPLANE', 'PT'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'of',
#   'agreement',
#   'with',
#   'Sampdoria',
#   'for',
#   'Torreira',
#   'but',
#   'nothing',
#   'signed',
#   'no',
#   'player'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['EXO', 'POWER'],
#  ['Please', 'play', 'of'],
#  ['Back', 'to', 'the', 'Future'],
#  ['England',
#   'Vs',
#   'England',
#   'One',
#   'is',
#   'reflection',
#   'of',
#   'an',
#   'England',
#   'which',
#   'still',
#   'had',
#   'an',
#   'identity',
#   'Representatives',
#   'of',
#   'the',
#   'English'],
#  ['The', 'round', 'of'],
#  ['face',
#   'in',
#   'Tuesday',
#   'last',
#   'at',
#   'stadium',
#   'What',
#   'your',
#   'prediction'],
#  ['My', 'favourite', 'is'],
#  ['We',
#   'will',
#   'have',
#   'TWELVE',
#   'madridistas',
#   'involved',
#   'in',
#   'the',
#   'last',
#   'of',
#   'the',
#   'Find',
#   'out',
#   'who'],
#  ['It',
#   'really',
#   'is',
#   'the',
#   'global',
#   'game',
#   'Where',
#   'have',
#   'you',
#   'been',
#   'watching',
#   'the',
#   'from'],
#  ['Fake', 'Love', 'BTS', 'Airplane', 'pt', 'BTS'],
#  ['fever', 'warm', 'up', 'today', 'Via'],
#  ['EXOs',
#   'energetic',
#   'song',
#   'POWER',
#   'would',
#   'be',
#   'so',
#   'suitable',
#   'to',
#   'be',
#   'played',
#   'The',
#   'song',
#   'have',
#   'being',
#   'performed',
#   'at',
#   'the',
#   'closin'],
#  ['NEWS', 'Game', 'Congrats', 'Yoshi'],
#  ['global',
#   'festival',
#   'with',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'to',
#   'the',
#   'foreign',
#   'supporter',
#   'from',
#   'different',
#   'co'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['EXO', 'Olympics', 'EXO', 'Nations', 'Pick', 'POWER'],
#  ['Here',
#   'is',
#   'the',
#   'link',
#   'of',
#   'their',
#   'performance',
#   'olympic',
#   'acc',
#   'still',
#   'loving',
#   'our',
#   'Nation',
#   'Pick'],
#  ['Fake', 'Love', 'is', 'amazing'],
#  ['No', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['Symphonic', 'Narcotix', 'by', 'Artists', 'Prod', 'Mixed', 'Mastered'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Power', 'de', 'EXO', 'Please', 'play', 'of'],
#  ['Best',
#   'moment',
#   'of',
#   'the',
#   'You',
#   'can',
#   'not',
#   'Rank',
#   'World',
#   'Cup',
#   'Moments',
#   'Everything',
#   'Matters'],
#  ['Hi',
#   'our',
#   'favorite',
#   'song',
#   'is',
#   'Fake',
#   'Love',
#   'by',
#   'they',
#   'also',
#   'have',
#   'latin',
#   'inspired',
#   'one',
#   'called',
#   'Airplane',
#   'PT'],
#  ['When',
#   'you',
#   'have',
#   'almost',
#   'made',
#   'it',
#   'through',
#   'whole',
#   'day',
#   'with',
#   'no',
#   'action'],
#  ['Pre',
#   'tournament',
#   'predicted',
#   'Germany',
#   'to',
#   'win',
#   'the',
#   'that',
#   'hasn',
#   'gone',
#   'well',
#   'So',
#   'm',
#   'giving',
#   'myself',
#   'another',
#   'go',
#   'at'],
#  ['can',
#   'not',
#   'get',
#   'enough',
#   'of',
#   'the',
#   'FIFA',
#   'right',
#   'now',
#   'Like',
#   'or',
#   'Retweet',
#   'this',
#   'to',
#   'subscribe',
#   'to',
#   'the',
#   'Match',
#   'Day',
#   'Programme'],
#  ['Please', 'play', 'of'],
#  ['Please', 'play'],
#  ['FOUND', 'THE', 'VIDEO', 'HAHAHA', 'play', 'blackpink', 'forever', 'young'],
#  ['Please', 'play', 'of'],
#  ['with', 'the', 'inappropriate', 'Korea', 'joke'],
#  ['Land',
#   'transaction',
#   'approval',
#   'transferring',
#   'responsibility',
#   'Regulation',
#   'you',
#   'just',
#   'don',
#   'like',
#   'to',
#   'pause',
#   'for',
#   'breathing',
#   'No',
#   'wonder',
#   'you',
#   're',
#   'out',
#   'of',
#   'the'],
#  ['Power',
#   'by',
#   'exo',
#   'is',
#   'suitable',
#   'and',
#   'energetic',
#   'song',
#   'which',
#   'can',
#   'be',
#   'played',
#   'at',
#   'the',
#   'world',
#   'cup',
#   'believe',
#   'people',
#   'from'],
#  ['EXO',
#   'POWER',
#   'the',
#   'best',
#   'song',
#   'sounded',
#   'in',
#   'Olympics',
#   'Game',
#   'and',
#   'in',
#   'Dubai'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Mexican',
#   'pop',
#   'fan',
#   'celebrated',
#   'South',
#   'Koreas',
#   'win',
#   'in',
#   'their',
#   'own',
#   'way',
#   'mass',
#   'streaming',
#   'hit',
#   'single',
#   'Fake'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Fake', 'Love', 'is', 'amazing'],
#  ['it',
#   'good',
#   'song',
#   'with',
#   'rhythm',
#   'that',
#   'can',
#   'burn',
#   'your',
#   'spirit'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen'],
#  ['The', 'Senegal', 'defender', 'watching', 'Colombia', 'score'],
#  ['The', 'round', 'of'],
#  ['NEW', 'FUNNY', 'FORTNITE', 'CLIP'],
#  ['Airplane',
#   'PT',
#   'of',
#   'BTS',
#   'Its',
#   'great',
#   'song',
#   'to',
#   'dance',
#   'the',
#   'latin',
#   'people',
#   'would',
#   'enjoy',
#   'it'],
#  ['CHARGING', 'The', 'world', 'wait', 'for', 'Leo', 'Messi', 'tomorrow'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Please', 'play', 'of'],
#  ['recommend',
#   'GO',
#   'HIGHER',
#   'by',
#   'Its',
#   'the',
#   'perfect',
#   'song',
#   'to',
#   'energize',
#   'all',
#   'the',
#   'player',
#   'in',
#   'the'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen',
#   'to'],
#  ['Hi',
#   'our',
#   'favorite',
#   'song',
#   'is',
#   'Fake',
#   'Love',
#   'by',
#   'they',
#   'also',
#   'have',
#   'latin',
#   'inspired',
#   'one',
#   'called',
#   'Airplane',
#   'PT'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['EXO',
#   'let',
#   'reply',
#   'this',
#   'tweet',
#   'and',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'be',
#   'played',
#   'in',
#   'Do',
#   'it',
#   'politely',
#   'Mention',
#   'abou'],
#  ['Please', 'play', 'of'],
#  ['Prediction',
#   'in',
#   'the',
#   'Noble',
#   'Quran',
#   'Modern',
#   'Means',
#   'of',
#   'Transport',
#   'Chat',
#   'now'],
#  ['Probable', 'line', 'up', 'for'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'below',
#   'with',
#   'requesting',
#   'EXO',
#   'Power',
#   'a',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadi'],
#  ['There',
#   'are',
#   'some',
#   'BIG',
#   'clash',
#   'to',
#   'look',
#   'forward',
#   'to',
#   'in',
#   'the',
#   'Round',
#   'of',
#   'Are',
#   'we',
#   'in',
#   'for',
#   'any',
#   'shock'],
#  ['Please', 'play', 'of'],
#  ['GOT',
#   'THE',
#   'New',
#   'Era',
#   'at',
#   'No',
#   'on',
#   'Billboard',
#   'Japan',
#   'a',
#   'the',
#   'boost',
#   'Suchmos'],
#  ['Please', 'play', 'of'],
#  ['The',
#   'Last',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia',
#   'Argentina',
#   'Sweden'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'of',
#   'agreement',
#   'with',
#   'Sampdoria',
#   'for',
#   'Torreira',
#   'but',
#   'nothing',
#   'signed',
#   'no',
#   'player'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Please',
#   'play',
#   'of',
#   'This',
#   'song',
#   'is',
#   'so',
#   'energetic',
#   'amd',
#   'powerfull',
#   'Fit',
#   'perfectly',
#   'wit',
#   'the'],
#  ['On',
#   'June',
#   'from',
#   'to',
#   'pm',
#   'Victory',
#   'Museum',
#   'invite',
#   'football',
#   'fan',
#   'of',
#   'to',
#   'visit',
#   'it',
#   'open',
#   'air',
#   'exposition',
#   'of',
#   'militar'],
#  ['Best', 'Prom', 'Table', 'Plan', 'ever', 'Thank', 'you', 'Ms', 'Cuddy'],
#  ['POWER', 'by', 'Nations', 'Pick'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Jesse',
#   'Lingards',
#   'curler',
#   'is',
#   'up',
#   'with',
#   'one',
#   'of',
#   'the',
#   'great',
#   'goal',
#   'of',
#   'this',
#   'year',
#   'FIFA',
#   'Do',
#   'you',
#   'agree',
#   'Watch',
#   'him',
#   'and',
#   'Engla'],
#  ['It',
#   'really',
#   'is',
#   'the',
#   'global',
#   'game',
#   'Where',
#   'have',
#   'you',
#   'been',
#   'watching',
#   'the',
#   'from'],
#  ['The', 'best', 'fan', 'at', 'the', 'are'],
#  ['My', 'favorite', 'song', 'is'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen',
#   'to'],
#  ['Fake', 'Love', 'by'],
#  ['Catch',
#   'up',
#   'on',
#   'featuring',
#   'three',
#   'current',
#   'Reds',
#   'and',
#   'winner',
#   'from',
#   'former',
#   'player'],
#  ['City',
#   'Country',
#   'named',
#   'in',
#   'airplaine',
#   'part',
#   'participating',
#   'in',
#   'the',
#   'worldcup',
#   'London',
#   'Paris',
#   'Tokyo',
#   'Mexico',
#   'City',
#   'Brazil',
#   'ALL',
#   'THESE',
#   'COUNTRY'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'below',
#   'with',
#   'requesting',
#   'EXO',
#   'Power',
#   'a',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadi'],
#  ['Its', 'now', 'or', 'never', 'for', 'England'],
#  ['Please', 'play', 'of'],
#  ['EXO', 'POWER'],
#  ['As',
#   'the',
#   'group',
#   'stage',
#   'end',
#   'we',
#   'say',
#   'farewell',
#   'to',
#   'team',
#   'from',
#   'this',
#   'year',
#   'FIFA',
#   'Thanks',
#   'for',
#   'the',
#   'memory'],
#  ['The',
#   'ECA',
#   'campaign',
#   'ha',
#   'launched',
#   'to',
#   'accelerate',
#   'the',
#   'mass',
#   'adoption',
#   'of',
#   'and',
#   'we',
#   'are',
#   'goi'],
#  ['Who', 'going', 'to', 'win'],
#  ['Fun',
#   'Fact',
#   'At',
#   'least',
#   'national',
#   'team',
#   'arrived',
#   'in',
#   'style',
#   'for',
#   'the',
#   'FIFA',
#   'Check',
#   'out',
#   'few',
#   'of',
#   'their'],
#  ['Diego',
#   'Maradona',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'paid',
#   'FIFA',
#   'ambassador',
#   'after',
#   'his',
#   'embarrassing',
#   'and',
#   'provocotive',
#   'behaviour',
#   'during'],
#  ['Fake', 'Love', 'is', 'amazing'],
#  ['Transformer', 'Please', 'play', 'of'],
#  ['My',
#   'postcard',
#   'to',
#   'Jennifer',
#   'Salke',
#   'at',
#   'am',
#   'from',
#   'the',
#   'future',
#   'after',
#   'all',
#   'S',
#   'would',
#   'tell',
#   'you',
#   'who',
#   'won'],
#  ['The',
#   'Last',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia',
#   'Argentina',
#   'Sweden'],
#  ['Anyone',
#   'else',
#   'woke',
#   'up',
#   'at',
#   'to',
#   'catch',
#   'the',
#   'match',
#   'and',
#   'then',
#   'realize',
#   'there',
#   'wa',
#   'not',
#   'one',
#   'today',
#   'did',
#   'not',
#   'even',
#   'need',
#   'an',
#   'alarm'],
#  ['Diego',
#   'Maradona',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'paid',
#   'FIFA',
#   'ambassador',
#   'after',
#   'his',
#   'embarrassing',
#   'and',
#   'provocotive',
#   'behaviour',
#   'during'],
#  ['What',
#   'an',
#   'amazing',
#   'setting',
#   'for',
#   'game',
#   'of',
#   'football',
#   'Young',
#   'Russian',
#   'footballer',
#   'took',
#   'part',
#   'in',
#   'an',
#   'exhibition',
#   'match',
#   'at',
#   'Moscows',
#   'Fo'],
#  ['Ready', 'for', 'the', 'knockout'],
#  ['Round', 'of', 'Predictions', 'by', 'Including', 'v', 'via'],
#  ['No', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['We', 'know', 'who', 'this', 'guy', 'is', 'rooting', 'for', 'tomorrow'],
#  ['Please', 'play', 'of'],
#  ['The',
#   'true',
#   'story',
#   'of',
#   'the',
#   'world',
#   'greatest',
#   'Ronaldo',
#   'available',
#   'on',
#   'iTunes',
#   'now'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Nation',
#   'Pick',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it'],
#  ['Pablo',
#   'Zabaleta',
#   'belief',
#   'Its',
#   'the',
#   'last',
#   'chance',
#   'for',
#   'many',
#   'of',
#   'star',
#   'player',
#   'to',
#   'win',
#   'the'],
#  ['EXO',
#   'Ls',
#   'This',
#   'would',
#   'be',
#   'an',
#   'honour',
#   'for',
#   'EXO',
#   'and',
#   'we',
#   'know',
#   'POWER',
#   'motivates',
#   'athlete',
#   'Send',
#   'in',
#   'your',
#   'request',
#   'for',
#   'POWER',
#   'tag'],
#  ['When', 'you', 'wake', 'up', 'and', 'there', 'no', 'to', 'watch'],
#  ['POWER',
#   'is',
#   'the',
#   'ultimate',
#   'song',
#   'to',
#   'give',
#   'energy',
#   'to',
#   'any',
#   'soccer',
#   'player'],
#  ['Disappointed',
#   'but',
#   'hopefully',
#   'should',
#   'beat',
#   'and',
#   'or',
#   'to',
#   'get',
#   'to',
#   'the',
#   'Semis'],
#  ['RT', 'and', 'comment', 'Please', 'play', 'of'],
#  ['France', 'VS', 'Argentina', 'Who', 'will', 'win'],
#  ['Please', 'play', 'of'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communication',
#   'out',
#   'of',
#   'fe'],
#  ['The', 'round', 'of'],
#  ['Wait', 'what'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Power', 'by', 'EXO'],
#  ['for', 'tomorrow', 'Nice'],
#  ['The',
#   'best',
#   'XI',
#   'from',
#   'group',
#   'stage',
#   'play',
#   'includes',
#   'Real',
#   'Madrid',
#   'teammate',
#   'Modric',
#   'Ronaldo',
#   'and',
#   'Isco',
#   'along',
#   'with',
#   'Harry',
#   'Kane',
#   'No',
#   'Messi'],
#  ['We',
#   've',
#   'heard',
#   'your',
#   'feedback',
#   'here',
#   'our',
#   'IMPROVED',
#   'World',
#   'Cup',
#   'squad',
#   'Thanks',
#   'everyone'],
#  ['It', 'ha', 'been', 'TOO', 'LONG', 'since', 'match'],
#  ['Please', 'play', 'of'],
#  ['Win', 'up', 'to', 'wnrs'],
#  ['in',
#   'the',
#   'where',
#   'to',
#   'watch',
#   'who',
# ...
#   'Stages',
#   'Games',
#   'Goals',
#   'Nil',
#   'Nil',
#   'Draw',
#   'Penalties',
#   'Own',
#   'Goals'],
#  ['Please', 'play'],
#  ['EXOs',
#   'energetic',
#   'song',
#   'POWER',
#   'would',
#   'be',
#   'so',
#   'suitable',
#   'to',
#   'be',
#   'played',
#   'The',
#   'song',
#   'have',
#   'being',
#   'performed',
#   'at',
#   'the',
#   'closin'],
#  ['Please', 'play', 'of'],
#  ['Olarrrr',
#   'We',
#   'want',
#   'to',
#   'hear',
#   'Fake',
#   'Love',
#   'by',
#   'at',
#   'Play',
#   'for',
#   'u'],
#  ['As',
#   'the',
#   'group',
#   'stage',
#   'end',
#   'we',
#   'say',
#   'farewell',
#   'to',
#   'team',
#   'from',
#   'this',
#   'year',
#   'FIFA',
#   'Thanks',
#   'for',
#   'the',
#   'memory'],
#  ['After',
#   'this',
#   'horrendous',
#   'day',
#   'for',
#   'my',
#   'profession',
#   'that',
#   'began',
#   'with',
#   'the',
#   'joy',
#   'of',
#   'the',
#   'please',
#   'watch',
#   'this',
#   'uplifting',
#   'video',
#   'of',
#   'on'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['When',
#   'you',
#   'have',
#   'almost',
#   'made',
#   'it',
#   'through',
#   'whole',
#   'day',
#   'with',
#   'no',
#   'action'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['TRIGGER', 'THE', 'FEVER', 'by', 'NCT', 'DREAM'],
#  ['Please', 'play', 'power', 'by', 'EXO'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Play', 'Power', 'by', 'EXO'],
#  ['EXO', 'POWER'],
#  ['EXO', 'POWER', 'Please', 'play', 'of'],
#  ['Its', 'there', 'for', 'the', 'taking'],
#  ['RT', 'and', 'comment', 'Please', 'play', 'of'],
#  ['Trent',
#   'Alexander',
#   'Arnold',
#   'Last',
#   'Months',
#   'Liverpool',
#   'Debut',
#   'PL',
#   'Debut',
#   'First',
#   'PL',
#   'Goal',
#   'UCL',
#   'Debut',
#   'UCL',
#   'Debut',
#   'Goal',
#   'UCL'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['AIRPLANE', 'PT'],
#  ['No', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Trent',
#   'Alexander',
#   'Arnold',
#   'Last',
#   'Months',
#   'Liverpool',
#   'Debut',
#   'PL',
#   'Debut',
#   'First',
#   'PL',
#   'Goal',
#   'UCL',
#   'Debut',
#   'UCL',
#   'Debut',
#   'Goal',
#   'UCL'],
#  ['bellanaija', 'Japan', 'Poland', 'Watch', 'Highlights'],
#  ['global',
#   'festival',
#   'with',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'to',
#   'the',
#   'foreign',
#   'supporter',
#   'from',
#   'different',
#   'co'],
#  ['bellanaija',
#   'Senegal',
#   'Journey',
#   'come',
#   'to',
#   'an',
#   'End',
#   'after',
#   'loss',
#   'to',
#   'Colombia',
#   'Watch',
#   'Highlights'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen',
#   'to'],
#  ['Power', 'by'],
#  ['NCT', 'DREAM', 'TRIGGER', 'THE', 'FEVER'],
#  ['say',
#   'can',
#   'take',
#   'confidence',
#   'from',
#   'their',
#   'collective',
#   'experience',
#   'ahead',
#   'of',
#   'Round',
#   'of'],
#  ['Darling',
#   'can',
#   'you',
#   'at',
#   'least',
#   'take',
#   'something',
#   'before',
#   'going',
#   'to',
#   'bed',
#   'Nigerian',
#   'men'],
#  ['Another',
#   'song',
#   'would',
#   'like',
#   'to',
#   'recommend',
#   'is',
#   'Hard',
#   'Carry',
#   'by',
#   'HARD',
#   'CARRY',
#   'HEY',
#   'Its',
#   'so',
#   'HYPE',
#   'and',
#   'so'],
#  ['Like',
#   'or',
#   'RT',
#   'this',
#   'to',
#   'subscribe',
#   'to',
#   'your',
#   'digital',
#   'Match',
#   'Day',
#   'Program'],
#  ['it',
#   'good',
#   'song',
#   'with',
#   'rhythm',
#   'that',
#   'can',
#   'burn',
#   'your',
#   'spirit'],
#  ['Coral',
#   'Sports',
#   'Sat',
#   'th',
#   'June',
#   'Uruguay',
#   'Portugal',
#   'Coral',
#   'Offer',
#   'Max',
#   'bet',
#   'Ronaldo',
#   'to',
#   'Score',
#   'New',
#   'Customers',
#   'Only',
#   'Cs',
#   'Apply',
#   'Gamble',
#   'Aware',
#   'Claim'],
#  ['All', 'you', 'need', 'in', 'is', 'POWER'],
#  ['Can',
#   'you',
#   'predict',
#   'the',
#   'result',
#   'of',
#   'Who',
#   'will',
#   'score',
#   'first',
#   'when',
#   'face',
#   'How',
#   'will',
#   'finish',
#   'Join',
#   'in'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'below',
#   'with',
#   'requesting',
#   'EXO',
#   'Power',
#   'a',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadi'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['When', 'you', 'realise', 'there', 'are', 'no', 'game', 'on', 'today'],
#  ['The',
#   'energy',
#   'use',
#   'will',
#   'be',
#   'redirected',
#   'to',
#   'warming',
#   'myself',
#   'by',
#   'the',
#   'TV',
#   'which',
#   'is',
#   'on',
#   'for',
#   'the'],
#  ['An',
#   'estimated',
#   'million',
#   'pint',
#   'were',
#   'poured',
#   'in',
#   'the',
#   'UK',
#   'last',
#   'night',
#   'Just',
#   'imagine',
#   'if',
#   'we',
#   'win',
#   'the',
#   'bloody',
#   'thing'],
#  ['O', 'E', 'P', 'W', 'R', 'O', 'E', 'by', 'EXO'],
#  ['Power',
#   'by',
#   'exo',
#   'is',
#   'your',
#   'song',
#   'FIFA',
#   'Its',
#   'going',
#   'to',
#   'turn',
#   'up',
#   'the',
#   'mood',
#   'even',
#   'more',
#   'Will',
#   'bring',
#   'the',
#   'festive',
#   'atmosphere'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'Exo',
#   'it',
#   'wa',
#   'performed',
#   'in',
#   'the',
#   'Olympic',
#   'and',
#   'it',
#   'wa',
#   'the',
#   'first',
#   'song',
#   'played',
#   'in',
#   'th'],
#  ['Please', 'play', 'of'],
#  ['Queroooooooo',
#   'We',
#   'want',
#   'to',
#   'hear',
#   'Fake',
#   'Love',
#   'by',
#   'at',
#   'Play',
#   'for',
#   'u'],
#  ['Good', 'Morning'],
#  ['Retweeted',
#   'Weight',
#   'Watchers',
#   'Ready',
#   'for',
#   'the',
#   'big',
#   'game',
#   'tonight',
#   'of',
#   'England',
#   'VS',
#   'Belgium',
#   'In',
#   'battle',
#   'of',
#   'dessert',
#   'which',
#   'would',
#   'you',
#   'pick',
#   'Find',
#   'both',
#   'recipe',
#   'below'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen',
#   'to'],
#  ['We',
#   'would',
#   'recommend',
#   'you',
#   'to',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'is',
#   'such',
#   'energetic',
#   'song',
#   'and',
#   'will',
#   'suit',
#   'it',
#   'It',
#   'wa',
#   'chosen'],
#  ['Please', 'play', 'of'],
#  ['They',
#   'were',
#   'only',
#   'before',
#   'this',
#   'Keisuke',
#   'Honda',
#   'becomes',
#   'the',
#   'th',
#   'ever',
#   'Asian',
#   'player',
#   'to',
#   'score',
#   'in',
#   'World',
#   'Cup',
#   'competiti'],
#  ['Thank', 'you', 'for', 'everything', 'you', 'do', 'South', 'Korea'],
#  ['The',
#   'World',
#   'Football',
#   'Phone',
#   'in',
#   'is',
#   'back',
#   'for',
#   'knockout',
#   'special',
#   'Joining',
#   'is',
#   'the',
#   'Legendinho',
#   'Northern',
#   'Seoul',
#   'and',
#   'our',
#   'world',
#   'football',
#   'fan',
#   'How',
#   'did',
#   'you',
#   'cope',
#   'with',
#   'day',
#   'of',
#   'no',
#   'game'],
#  ['Ready',
#   'for',
#   'the',
#   'big',
#   'game',
#   'tonight',
#   'of',
#   'England',
#   'VS',
#   'Belgium',
#   'In',
#   'battle',
#   'of',
#   'dessert',
#   'which',
#   'would',
#   'you',
#   'pick',
#   'Find',
#   'both',
#   'reci'],
#  ['Power', 'by'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Points',
#   'GD',
#   'Scored',
#   'Head',
#   'to',
#   'head',
#   'Yellow',
#   'card',
#   'For',
#   'the',
#   'first',
#   'time',
#   'ever',
#   'team',
#   'ha',
#   'been',
#   'kno'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Most',
#   'take',
#   'ons',
#   'completed',
#   'in',
#   'the',
#   'group',
#   'stage',
#   'Lionel',
#   'Messi',
#   'Neymar',
#   'Oghenekaro',
#   'Etebo'],
#  ['Mart',
#   'nez',
#   'is',
#   'fully',
#   'fit',
#   'He',
#   'completed',
#   'the',
#   'training',
#   'session',
#   'today'],
#  ['It',
#   'really',
#   'is',
#   'the',
#   'global',
#   'game',
#   'Where',
#   'have',
#   'you',
#   'been',
#   'watching',
#   'the',
#   'from'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communication',
#   'out',
#   'of',
#   'fe'],
#  ['Did',
#   'someone',
#   'say',
#   'football',
#   'can',
#   'not',
#   'wait',
#   'for',
#   'tomorrow'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['EXOs',
#   'energetic',
#   'song',
#   'POWER',
#   'would',
#   'be',
#   'so',
#   'suitable',
#   'to',
#   'be',
#   'played',
#   'The',
#   'song',
#   'have',
#   'being',
#   'performed',
#   'at',
#   'the',
#   'closin'],
#  ['Resilience',
#   'can',
#   'give',
#   'you',
#   'strength',
#   'to',
#   'keep',
#   'moving',
#   'forward',
#   'when',
#   'you',
#   'are',
#   'caught',
#   'in',
#   'the',
#   'rain',
#   'or',
#   'storm',
#   'and',
#   'keep',
#   'you',
#   'continuin'],
#  ['star', 'have', 'reached', 'the', 'knockout', 'stage', 'Marcos', 'Rojo'],
#  ['The', 'Senegal', 'defender', 'watching', 'Colombia', 'score'],
#  ['BREAKING', 'Trumps', 'Epic', 'World', 'Cup', 'Speech'],
#  ['CHARGING', 'The', 'world', 'wait', 'for', 'Leo', 'Messi', 'tomorrow'],
#  ['Please', 'play', 'of'],
#  ['Retweet',
#   'if',
#   'your',
#   'country',
#   'are',
#   'still',
#   'in',
#   'the',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['think',
#   'of',
#   'would',
#   'be',
#   'an',
#   'amazing',
#   'song',
#   'for',
#   'the',
#   'World',
#   'Cup'],
#  ['Here',
#   'our',
#   'pick',
#   'for',
#   'our',
#   'World',
#   'Cup',
#   'squad',
#   'which',
#   'operator',
#   'would',
#   'you',
#   'sub',
#   'in',
#   'http'],
#  ['As',
#   'the',
#   'group',
#   'stage',
#   'end',
#   'we',
#   'say',
#   'farewell',
#   'to',
#   'team',
#   'from',
#   'this',
#   'year',
#   'FIFA',
#   'Thanks',
#   'for',
#   'the',
#   'memory'],
#  ['Fake',
#   'love',
#   'by',
#   'BTS',
#   'the',
#   'best',
#   'of',
#   'the',
#   'best',
#   'for',
#   'this'],
#  ['Colombian',
#   'man',
#   'help',
#   'his',
#   'deaf',
#   'and',
#   'blind',
#   'friend',
#   'experience',
#   'the',
#   'joy',
#   'of',
#   'their',
#   'team',
#   'campaign',
#   'Read',
#   'this',
#   'and',
#   'more'],
#  ['Please', 'play', 'of'],
#  ['Fire', 'and', 'FAKE', 'LOVE', 'by'],
#  ['Top',
#   'Goalscorers',
#   'By',
#   'League',
#   'La',
#   'Liga',
#   'Premier',
#   'League',
#   'Bundesliga'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Heres',
#   'how',
#   'group',
#   'finished',
#   'up',
#   'meaning',
#   'play',
#   'and',
#   'play',
#   'in',
#   'the',
#   'next',
#   'round'],
#  ['Just',
#   'wrote',
#   'my',
#   'first',
#   'piece',
#   'for',
#   'Its',
#   'on',
#   'the',
#   'racist',
#   'slanted',
#   'eye',
#   'gesture',
#   'that',
#   'keep',
#   'appearing',
#   'at',
#   'the'],
#  ['No', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['global',
#   'festival',
#   'with',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'to',
#   'the',
#   'foreign',
#   'supporter',
#   'from',
#   'different',
#   'co'],
#  ['So', 'Exci'],
#  ['The',
#   'song',
#   'is',
#   'playing',
#   'at',
#   'the',
#   'biggest',
#   'fountain',
#   'in',
#   'Dubai',
#   'and',
#   'the',
#   'song',
#   'is',
#   'very',
#   'passionate',
#   'and',
#   'unique',
#   'We',
#   'got'],
#  ['Please', 'play', 'by'],
#  ['Please', 'play', 'of'],
#  ['Power', 'by', 'EXO'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Kylian',
#   'Mbapp',
#   'will',
#   'donate',
#   'everything',
#   'he',
#   'earns',
#   'with',
#   'at',
#   'the',
#   'to',
#   'charity',
#   'This',
#   'will',
#   'add',
#   'up',
#   'to',
#   'per',
#   'game'],
#  ['Please', 'play', 'of'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['Power', 'by'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['We',
#   'will',
#   'have',
#   'TWELVE',
#   'madridistas',
#   'involved',
#   'in',
#   'the',
#   'last',
#   'of',
#   'the',
#   'Find',
#   'out',
#   'who'],
#  ['Having',
#   'to',
#   'leave',
#   'the',
#   'World',
#   'Cup',
#   'already',
#   'after',
#   'the',
#   'group',
#   'stage',
#   'hurt',
#   'so',
#   'much',
#   'We',
#   'just',
#   'were',
#   'not',
#   'good',
#   'enough',
#   'will',
#   'need',
#   'some'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'to',
#   'keep',
#   'their',
#   'secret',
#   'communication',
#   'out',
#   'of',
#   'fe'],
#  ['Its',
#   'time',
#   'to',
#   'give',
#   'the',
#   'superior',
#   'song',
#   'the',
#   'recognition',
#   'it',
#   'deserves',
#   'Request',
#   'NCT',
#   'Dreams',
#   'Trigger',
#   'The',
#   'Fever',
#   'on',
#   'their'],
#  ['photo', 'or', 'renaissance', 'art', 'Can', 'we', 'get', 'ruling'],
#  ['O', 'E', 'P', 'W', 'R', 'O', 'E', 'by', 'EXO'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'below',
#   'and',
#   'your',
#   'choice',
#   'could',
#   'be',
#   'played',
#   'in',
#   'stadium'],
#  ['Please',
#   'play',
#   'Power',
#   'by',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'during',
#   'the',
#   'Closing',
#   'Ceremony',
#   'of',
#   'the',
#   'Winter',
#   'Olympics',
#   'The',
#   'song',
#   'is'],
#  ['ESPN',
#   'Lionel',
#   'Messi',
#   'is',
#   'the',
#   'first',
#   'player',
#   'to',
#   'score',
#   'goal',
#   'in',
#   'his',
#   'teen',
#   'and'],
#  ['Today',
#   'is',
#   'the',
#   'anniversary',
#   'of',
#   'the',
#   'upset',
#   'of',
#   'England',
#   'at',
#   'the',
#   'Heres',
#   'retrospective',
#   'from',
#   'the',
#   'lat'],
#  ['Please', 'play', 'of'],
#  ['BTS',
#   'OBVIUSLY',
#   'THESE',
#   'SONGS',
#   'Fake',
#   'Love',
#   'Its',
#   'very',
#   'beloved',
#   'song',
#   'it',
#   'literally',
#   'perfect',
#   'And',
#   'of',
#   'co'],
#  ['Please', 'play', 'of'],
#  ['EXO', 'POWER'],
#  ['All',
#   'team',
#   'given',
#   'score',
#   'out',
#   'of',
#   'What',
#   'would',
#   'you',
#   'give',
#   'the'],
#  ['Power', 'de', 'EXO', 'Please', 'play', 'of', 'http'],
#  ['POWER',
#   'by',
#   'is',
#   'the',
#   'only',
#   'global',
#   'hit',
#   'song',
#   'that',
#   'ha',
#   'lyric',
#   'fitting',
#   'for',
#   'sport',
#   'event',
#   'giving',
#   'the',
#   'athlet'],
#  ['Please', 'play', 'of'],
#  ['Kylian',
#   'Mbapp',
#   'will',
#   'donate',
#   'everything',
#   'he',
#   'earns',
#   'with',
#   'at',
#   'the',
#   'to',
#   'charity',
#   'This',
#   'will',
#   'add',
#   'up',
#   'to',
#   'per',
#   'game'],
#  ['ICYMI',
#   'Some',
#   'musing',
#   'Day',
#   'perfect',
#   'group',
#   'stage',
#   'doe',
#   'not',
#   'aways',
#   'mean',
#   'championship',
#   'http'],
#  ['Messi',
#   'get',
#   'face',
#   'saving',
#   'Kazan',
#   'mural',
#   'to',
#   'match',
#   'Ronaldos'],
#  ['RT', 'and', 'comment', 'Please', 'play', 'of'],
#  ['Please', 'play', 'POWER', 'by', 'EXO', 'thanks'],
#  ...]

# %% [markdown]
# ## 2b. Remove Stopwords:

# %%
stop = set(stopwords.words('english'))
stop
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
tweets_no_sw = []
for i in tweets_lemm:
    no_stopwords = [token for token in i if token not in stop]
    tweets_no_sw.append(no_stopwords)
tweets_no_sw
# Out:
# [['Want',
#   'make',
#   'summer',
#   'football',
#   'little',
#   'bit',
#   'hotter',
#   'RT',
#   'follow'],
#  ['Didier',
#   'Deschamps',
#   'ha',
#   'confirmed',
#   'Benjamin',
#   'Mendy',
#   'miss',
#   'tomorrow',
#   'game',
#   'due',
#   'muscular',
#   'problem'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['week',
#   'team',
#   'game',
#   'goal',
#   'The',
#   'group',
#   'stage',
#   'wa',
#   'everything',
#   'hoped'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Hi',
#   'everyone',
#   'Lets',
#   'get',
#   'started',
#   'Round',
#   'excited',
#   'miss',
#   'every',
#   'football',
#   'league',
#   'come',
#   'World',
#   'Cup',
#   'well'],
#  ['First',
#   'night',
#   'world',
#   'cup',
#   'game',
#   'chat',
#   'missus',
#   'She',
#   'seems',
#   'nice',
#   'girl',
#   'fair'],
#  ['Batshuayi', 'arguably', 'funniest', 'moment'],
#  ['global',
#   'festival',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['Watch',
#   'Budweiser',
#   'Yerry',
#   'Mina',
#   'talk',
#   'squad',
#   'dance',
#   'What',
#   'next',
#   'http'],
#  ['Power', 'de', 'EXO', 'Please', 'play', 'http'],
#  ['The',
#   'Round',
#   'confirmed',
#   'Tin',
#   'Jedvaj',
#   'Croatia',
#   'take',
#   'Denmark',
#   'Sunday'],
#  ['Power', 'Please', 'play'],
#  ['CHARGING', 'The', 'world', 'wait', 'Leo', 'Messi', 'tomorrow'],
#  ['EXO',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'played',
#   'Do',
#   'politely',
#   'Mention',
#   'abou'],
#  ['global',
#   'festival',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['There', 'The', 'last', 'confirmed', 'Catch', 'highlight', 'ht'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['Soccer', 'themed', 'nesting', 'doll', 'score', 'point', 'fan', 'See'],
#  ['recommend',
#   'LO',
#   'SIENTO',
#   'By',
#   'Super',
#   'Junior',
#   'ft',
#   'Leslie',
#   'Grace',
#   'Playnskillz',
#   'Its',
#   'nice',
#   'trilingual',
#   'song',
#   'English',
#   'Spanish'],
#  ['Please', 'play'],
#  ['Mexican',
#   'pop',
#   'fan',
#   'celebrated',
#   'South',
#   'Koreas',
#   'win',
#   'way',
#   'mass',
#   'streaming',
#   'hit',
#   'single',
#   'Fake'],
#  ['When', 'almost', 'made', 'whole', 'day', 'action'],
#  ['Second', 'half', 'surge', 'see', 'Tunisia', 'bow', 'style'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['global',
#   'festival',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['Please', 'play'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['The', 'Senegal', 'defender', 'watching', 'Colombia', 'score'],
#  ['Please', 'play'],
#  ['Cameraman', 'FC', 'ha', 'real', 'MVP', 'far'],
#  ['You',
#   'play',
#   'wa',
#   'performed',
#   'Olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['EXO',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'played',
#   'Do',
#   'politely',
#   'Mention',
#   'abou'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['You',
#   'play',
#   'wa',
#   'performed',
#   'Olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'EXO',
#   'Power',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'played',
#   'stadi'],
#  ['power'],
#  ['All', 'need', 'POWER'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['My', 'favourite', 'song', 'Fake', 'Love', 'thank'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Waking', 'morning', 'realizing', 'game', 'today'],
#  ['RT', 'comment', 'Please', 'play'],
#  ['Power',
#   'Exo',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please'],
#  ['Please', 'play'],
#  ['Guardiola',
#   'win',
#   'league',
#   'Spain',
#   'Spain',
#   'win',
#   'World',
#   'Cup',
#   'Guardiola',
#   'win',
#   'league',
#   'Germany'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Po', 'Favor'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['voted',
#   'EXO',
#   'POWER',
#   'played',
#   'stadium',
#   'The',
#   'song',
#   'amazing',
#   'lit'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Power',
#   'This',
#   'song',
#   'energetic',
#   'really',
#   'suitable',
#   'worldcup',
#   'also',
#   'performed'],
#  ['Please', 'play'],
#  ['Please', 'play'],
#  ['voted',
#   'EXO',
#   'POWER',
#   'played',
#   'stadium',
#   'The',
#   'song',
#   'amazing',
#   'lit',
#   'en'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Please', 'play', 'WE', 'GOT', 'THE', 'POWER', 'EVERY', 'TIME', 'http'],
#  ['Please', 'play'],
#  ['tub',
#   'Haribo',
#   'choice',
#   'Simply',
#   'predict',
#   'st',
#   'goalscorer',
#   'tomorrow',
#   'night',
#   'crunch',
#   'last',
#   'tie',
#   'betwee'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Please', 'play'],
#  ['GOT', 'THE', 'New', 'Era', 'No', 'Billboard', 'Japan', 'boost', 'Suchmos'],
#  ['When', 'two', 'meme', 'meet'],
#  ['POWER', 'POWER'],
#  ['My', 'favorite', 'song'],
#  ['proud',
#   'moment',
#   'lead',
#   'country',
#   'last',
#   'night',
#   'Seen',
#   'celebration',
#   'video',
#   'back',
#   'home',
#   'love'],
#  ['Po', 'Favor'],
#  ['Another', 'cheerful', 'Colombian', 'celebration'],
#  ['So', 'Exci'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Its', 'taking'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark'],
#  ['recommend',
#   'LO',
#   'SIENTO',
#   'By',
#   'Super',
#   'Junior',
#   'ft',
#   'Leslie',
#   'Grace',
#   'Playnskillz',
#   'Its',
#   'nice',
#   'trilingual',
#   'song',
#   'English',
#   'Spanish'],
#  ['choose'],
#  [],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'agreement',
#   'Sampdoria',
#   'Torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['Your', 'mother', 'come', 'first', 'Chat', 'Jesus'],
#  ['EXO', 'POWER', 'VAMOS', 'Please', 'play'],
#  ['recommend', 'GO', 'HIGHER', 'Its', 'perfect', 'song', 'energize', 'player'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Please',
#   'play',
#   'POWER',
#   'Its',
#   'bop',
#   'plus',
#   'hope',
#   'empowerment',
#   'Thanks',
#   'much'],
#  ['FOUND', 'THE', 'VIDEO', 'HAHAHA', 'play', 'blackpink', 'forever', 'young'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Fake', 'Love'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['knockout',
#   'bracket',
#   'Sadly',
#   'Germany',
#   'The',
#   'Joachim',
#   'w',
#   'hailing',
#   'cab',
#   'meme',
#   'going',
#   'waste',
#   'Still',
#   'laughing',
#   'Germany',
#   'manager',
#   'coach',
#   'always',
#   'look',
#   'like',
#   'aging',
#   'Beatle',
#   'trying',
#   'hail',
#   'cab'],
#  ['Mic', 'Drop', 'ft'],
#  ['EXO', 'POWER', 'everyone', 'happy', 'hear'],
#  ['You',
#   'know',
#   'Ronaldo',
#   'You',
#   'know',
#   'Messi',
#   'You',
#   'know',
#   'Neymar',
#   'Do',
#   'know',
#   'scored',
#   'goal',
#   'got',
#   'paid',
#   'much',
#   'much',
#   'le',
#   'Abby',
#   'Wam'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['conclusion',
#   'power',
#   'fit',
#   'perfectly',
#   'energy',
#   'championship',
#   'world',
#   'cup',
#   'We',
#   'got',
#   'power'],
#  ['So',
#   'going',
#   'semi',
#   'final',
#   'Brazil',
#   'Belgium',
#   'Sol',
#   'Campbell',
#   'think',
#   'France'],
#  ['AIRPLANE', 'PT', 'BTS', 'Thankyou'],
#  ['Female',
#   'reporter',
#   'faced',
#   'sexism',
#   'sport',
#   'decade',
#   'year',
#   'speaking'],
#  ['POWER', 'EXO'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['As', 'say', 'football', 'ANYTHING', 'happen'],
#  ['GOT', 'THE', 'New', 'Era', 'No', 'Billboard', 'Japan', 'boost', 'Suchmos'],
#  ['recommend',
#   'LO',
#   'SIENTO',
#   'By',
#   'Super',
#   'Junior',
#   'ft',
#   'Leslie',
#   'Grace',
#   'Playnskillz',
#   'Its',
#   'nice',
#   'trilingual',
#   'song',
#   'English',
#   'Spanish'],
#  ['You',
#   'still',
#   'participate',
#   'competition',
#   'What',
#   'waiting',
#   'Win',
#   'valuable',
#   'electronic'],
#  ['EXO', 'POWER', 'Please', 'play'],
#  ['huge', 'day', 'Group', 'TEAM', 'NEWS'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Just',
#   'reminder',
#   'game',
#   'today',
#   'Air',
#   'Bud',
#   'World',
#   'Pup',
#   'Netflix'],
#  ['power'],
#  ['My', 'postcard', 'Jennifer', 'Salke', 'future', 'S', 'would', 'tell'],
#  ['Because', 'WE', 'GOT', 'THAT', 'POWER', 'Power'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Last',
#   'day',
#   'round',
#   'one',
#   'Make',
#   'pick',
#   'round',
#   'start',
#   'earning',
#   'MVU'],
#  ['Iceland', 'head', 'coach', 'day', 'elimination', 'Reddit'],
#  ['O', 'E', 'P', 'W', 'R', 'O', 'E', 'EXO'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['RETWEET', 'think', 'Cristiano', 'Ronaldo', 'score', 'Uruguay'],
#  ['power'],
#  ['Power', 'exo', 'Its', 'suitable', 'worldcup', 'think'],
#  ['No',
#   'fixture',
#   'today',
#   'GIF',
#   'help',
#   'pas',
#   'time',
#   'tournament',
#   'resume'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['The', 'Senegal', 'defender', 'watching', 'Colombia', 'score'],
#  ['Mexico', 'fan', 'going', 'security', 'Russia', 'Wait'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Vamos', 'EXO', 'RT', 'RT', 'Please', 'play'],
#  ['EXO', 'Olympics', 'EXO', 'Nations', 'Pick', 'POWER'],
#  ['Theres',
#   'smallest',
#   'nation',
#   'ever',
#   'qualify',
#   'Its',
#   'also',
#   'global',
#   'lead'],
#  ['power'],
#  ['Please', 'play'],
#  ['Hugo',
#   'Lloris',
#   'France',
#   'We',
#   'studied',
#   'Argeninas',
#   'group',
#   'game',
#   'give',
#   'u',
#   'indication',
#   'know',
#   'player',
#   'like',
#   'Messi',
#   'step',
#   'level',
#   'decide',
#   'fate',
#   'match',
#   'doe',
#   'Argentina',
#   'Barcelona'],
#  ['AIRPLANE', 'PT', 'BTS', 'Thankyou'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['EXO',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'played',
#   'Do',
#   'politely',
#   'Mention',
#   'abou'],
#  ['Probable', 'line'],
#  ['If',
#   'read',
#   'one',
#   'Germany',
#   'World',
#   'Cup',
#   'post',
#   'mortem',
#   'make',
#   'one'],
#  ['Never',
#   'When',
#   'man',
#   'tried',
#   'kiss',
#   'wa',
#   'reporting',
#   'Brazilian',
#   'journalist',
#   'foug'],
#  ['Can',
#   'predict',
#   'result',
#   'Who',
#   'score',
#   'first',
#   'face',
#   'How',
#   'finish',
#   'Join'],
#  ['Japanese',
#   'cartoonist',
#   'latest',
#   'cartoon',
#   'show',
#   'team',
#   'left',
#   'group',
#   'stage'],
#  ['Power',
#   'exo',
#   'suitable',
#   'energetic',
#   'song',
#   'played',
#   'world',
#   'cup',
#   'believe',
#   'people'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Everything', 'point', 'win', 'tomorrow', 'mad', 'think'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['With',
#   'knockout',
#   'round',
#   'bracket',
#   'set',
#   'take',
#   'look',
#   'SPI',
#   'chance',
#   'advance',
#   'round',
#   'win',
#   'fr'],
#  ['Eggs',
#   'thrown',
#   'Korean',
#   'national',
#   'team',
#   'defeating',
#   'Germany',
#   'Spurs',
#   'forward',
#   'Son',
#   'Heung'],
#  ['GOT', 'THE', 'New', 'Era', 'No', 'Billboard', 'Japan', 'boost', 'Suchmos'],
#  ['When', 'almost', 'made', 'whole', 'day', 'action'],
#  ['Please', 'play'],
#  ['TYPES', 'OF', 'PEOPLE', 'WATCHING', 'THE', 'WORLD', 'CUP', 'full', 'vid'],
#  ['EXO', 'POWER', 'Please', 'play', 'http'],
#  ['power'],
#  ['It', 'really', 'global', 'game', 'Where', 'watching'],
#  ['Entrenamiento',
#   'previo',
#   'al',
#   'partido',
#   'de',
#   'octavo',
#   'de',
#   'final',
#   'v',
#   'Last',
#   'training',
#   'session',
#   'next',
#   'Rou'],
#  ['Who',
#   'facing',
#   'last',
#   'one',
#   'side',
#   'draw',
#   'loaded',
#   'former',
#   'winner',
#   'http'],
#  ['EXO', 'POWER', 'Please', 'play', 'htt'],
#  ['Fake', 'love', 'Airplane', 'pt'],
#  ['Please', 'play'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['AIRPLANE', 'PT', 'BTS', 'Thankyou'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'The',
#   'song',
#   'The',
#   'POWER',
#   'Music',
#   'brings',
#   'people',
#   'together',
#   'together'],
#  ['Please', 'play'],
#  ['power'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Power',
#   'exo',
#   'song',
#   'FIFA',
#   'Its',
#   'going',
#   'turn',
#   'mood',
#   'even',
#   'Will',
#   'bring',
#   'festive',
#   'atmosphere'],
#  ['Fake', 'Love'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Matchday',
#   'Round',
#   'TSN',
#   'ET',
#   'international',
#   'played',
#   'Juventus',
#   'international',
#   'played',
#   'Juventus',
#   'Good',
#   'luck'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['My', 'favorite', 'song'],
#  ['Internet', 'beautiful', 'place'],
#  ['BREAKING',
#   'Diego',
#   'Maradona',
#   'longer',
#   'paid',
#   'FIFA',
#   'ambassador',
#   'embarrassing',
#   'provocotive',
#   'behaviour'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['global',
#   'festival',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['Please', 'play'],
#  ['Last', 'Fixtures', 'Saturday', 'v', 'v', 'Sunday', 'v', 'v'],
#  ['These',
#   'Brazil',
#   'fan',
#   'funeral',
#   'procession',
#   'street',
#   'Germany',
#   'got',
#   'knocked'],
#  ['Power', 'would', 'great', 'choice'],
#  ['O', 'E', 'P', 'W', 'R', 'O', 'E', 'EXO'],
#  ['Most',
#   'chance',
#   'created',
#   'group',
#   'stage',
#   'Neymar',
#   'Joshua',
#   'Kimmich',
#   'Mesut',
#   'zil',
#   'Salman',
#   'Al',
#   'Faraj'],
#  ['GROWL', 'Please', 'play'],
#  ['Just',
#   'reminder',
#   'game',
#   'today',
#   'Air',
#   'Bud',
#   'World',
#   'Pup',
#   'Netflix'],
#  ['Our',
#   'Fashion',
#   'art',
#   'icon',
#   'Week',
#   'The',
#   'Tool',
#   'Fest',
#   'go',
#   'Curated'],
#  ['Power', 'Please', 'play'],
#  ['As',
#   'group',
#   'stage',
#   'end',
#   'say',
#   'farewell',
#   'team',
#   'year',
#   'FIFA',
#   'Thanks',
#   'memory'],
#  ['Please', 'play', 'Such', 'great', 'song', 'cheer', 'everyone'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Coutinho', 'training', 'Brazil', 'Friday', 'getty'],
#  ['Iconic', 'celebration', 'far', 'Who'],
#  ['Power',
#   'Exo',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please'],
#  ['Good', 'Luck'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['RT', 'comment', 'Please', 'play'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['power'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Please',
#   'play',
#   'Power',
#   'Exo',
#   'wa',
#   'performed',
#   'Olympic',
#   'wa',
#   'first',
#   'song',
#   'played',
#   'th'],
#  ['NEW',
#   'POD',
#   'We',
#   'joined',
#   'preview',
#   'look',
#   'wildly',
#   'entertaining',
#   'Round'],
#  ['Zhou', 'Mi', 'Weibo', 'update', 'As', 'football', 'fan', 'miss', 'shirt'],
#  ['FOUND', 'THE', 'VIDEO', 'HAHAHA', 'play', 'blackpink', 'forever', 'young'],
#  ['The', 'lack', 'match', 'today'],
#  ['Its',
#   'time',
#   'give',
#   'superior',
#   'song',
#   'recognition',
#   'deserves',
#   'Request',
#   'NCT',
#   'Dreams',
#   'Trigger',
#   'The',
#   'Fever'],
#  ['voted',
#   'EXO',
#   'POWER',
#   'played',
#   'stadium',
#   'The',
#   'song',
#   'amazing',
#   'lit',
#   'energ'],
#  ['Oasis', 'Champagne', 'Supernova', 'Kid', 'Cudi'],
#  ['EXOs',
#   'energetic',
#   'song',
#   'POWER',
#   'would',
#   'suitable',
#   'played',
#   'The',
#   'song',
#   'performed',
#   'closin'],
#  ['Fake', 'love'],
#  ['Please', 'play'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['My', 'favorite', 'song'],
#  ['power'],
#  ['Wait'],
#  ['My', 'favorite', 'song'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark'],
#  ['Nigeria',
#   'Most',
#   'take',
#   'ons',
#   'completed',
#   'Most',
#   'foul',
#   'Most',
#   'shot',
#   'Joint'],
#  ['Rihanna',
#   'This',
#   'Is',
#   'What',
#   'You',
#   'Came',
#   'For',
#   'Taylor',
#   'Swift',
#   'Ready',
#   'For',
#   'It'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['Exo', 'Power', 'perfect', 'song', 'plea', 'give', 'try'],
#  ['Waking', 'morning', 'realizing', 'game', 'today'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Something', 'soothing', 'kit', 'image'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Cameraman', 'FC', 'ha', 'real', 'MVP', 'far'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['please', 'play', 'THANKYOU', 'SO', 'MUCH'],
#  ['Looking',
#   'entertainment',
#   'first',
#   'rest',
#   'day',
#   'You',
#   'safe',
#   'hand',
#   'exhibition'],
#  ['voted',
#   'EXO',
#   'POWER',
#   'played',
#   'stadium',
#   'The',
#   'song',
#   'amazing',
#   'lit',
#   'energ'],
#  ['VOTEN', 'por', 'power', 'de', 'EXO', 'Please', 'play'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'agreement',
#   'Sampdoria',
#   'Torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['This',
#   'common',
#   'people',
#   'different',
#   'country',
#   'culture',
#   'bond',
#   'good'],
#  ['EXO',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'played',
#   'Do',
#   'politely',
#   'Mention',
#   'abou'],
#  ['global',
#   'festival',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['Colombian',
#   'man',
#   'help',
#   'deaf',
#   'blind',
#   'friend',
#   'experience',
#   'joy',
#   'team',
#   'campaign'],
#  ['Power', 'de', 'EXO', 'Please', 'play'],
#  ['I',
#   'picked',
#   'Argentina',
#   'win',
#   'Play',
#   'World',
#   'Cup',
#   'Knockout',
#   'Bracket',
#   'chance',
#   'win',
#   'cash',
#   'prize'],
#  ['We', 'know', 'guy', 'rooting', 'tomorrow'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['EXO',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'Olympics',
#   'Power',
#   'coming',
#   'challenge'],
#  ['Would',
#   'believe',
#   'Mexico',
#   'got',
#   'top',
#   'BTS',
#   'rose',
#   'spot',
#   'Mexican',
#   'iTunes',
#   'Lmao',
#   'ya',
#   'hype',
#   'real'],
#  ['When', 'realise', 'game', 'today'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['BTS',
#   'OBVIUSLY',
#   'THESE',
#   'SONGS',
#   'Fake',
#   'Love',
#   'Its',
#   'beloved',
#   'song',
#   'literally',
#   'perfect',
#   'And',
#   'co'],
#  ['Top',
#   'Goalscorers',
#   'By',
#   'League',
#   'La',
#   'Liga',
#   'Premier',
#   'League',
#   'Bundesliga',
#   'Ligue'],
#  ['This', 'absolutely', 'got', 'What', 'man'],
#  ['EXO', 'Power', 'please', 'got', 'POWER', 'POWER'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'EXO',
#   'Power',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'played',
#   'stadi'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['AIRPLANE', 'PT'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'agreement',
#   'Sampdoria',
#   'Torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['EXO', 'POWER'],
#  ['Please', 'play'],
#  ['Back', 'Future'],
#  ['England',
#   'Vs',
#   'England',
#   'One',
#   'reflection',
#   'England',
#   'still',
#   'identity',
#   'Representatives',
#   'English'],
#  ['The', 'round'],
#  ['face', 'Tuesday', 'last', 'stadium', 'What', 'prediction'],
#  ['My', 'favourite'],
#  ['We', 'TWELVE', 'madridistas', 'involved', 'last', 'Find'],
#  ['It', 'really', 'global', 'game', 'Where', 'watching'],
#  ['Fake', 'Love', 'BTS', 'Airplane', 'pt', 'BTS'],
#  ['fever', 'warm', 'today', 'Via'],
#  ['EXOs',
#   'energetic',
#   'song',
#   'POWER',
#   'would',
#   'suitable',
#   'played',
#   'The',
#   'song',
#   'performed',
#   'closin'],
#  ['NEWS', 'Game', 'Congrats', 'Yoshi'],
#  ['global',
#   'festival',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['EXO', 'Olympics', 'EXO', 'Nations', 'Pick', 'POWER'],
#  ['Here',
#   'link',
#   'performance',
#   'olympic',
#   'acc',
#   'still',
#   'loving',
#   'Nation',
#   'Pick'],
#  ['Fake', 'Love', 'amazing'],
#  ['No', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['Symphonic', 'Narcotix', 'Artists', 'Prod', 'Mixed', 'Mastered'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Power', 'de', 'EXO', 'Please', 'play'],
#  ['Best',
#   'moment',
#   'You',
#   'Rank',
#   'World',
#   'Cup',
#   'Moments',
#   'Everything',
#   'Matters'],
#  ['Hi',
#   'favorite',
#   'song',
#   'Fake',
#   'Love',
#   'also',
#   'latin',
#   'inspired',
#   'one',
#   'called',
#   'Airplane',
#   'PT'],
#  ['When', 'almost', 'made', 'whole', 'day', 'action'],
#  ['Pre',
#   'tournament',
#   'predicted',
#   'Germany',
#   'win',
#   'gone',
#   'well',
#   'So',
#   'giving',
#   'another',
#   'go'],
#  ['get',
#   'enough',
#   'FIFA',
#   'right',
#   'Like',
#   'Retweet',
#   'subscribe',
#   'Match',
#   'Day',
#   'Programme'],
#  ['Please', 'play'],
#  ['Please', 'play'],
#  ['FOUND', 'THE', 'VIDEO', 'HAHAHA', 'play', 'blackpink', 'forever', 'young'],
#  ['Please', 'play'],
#  ['inappropriate', 'Korea', 'joke'],
#  ['Land',
#   'transaction',
#   'approval',
#   'transferring',
#   'responsibility',
#   'Regulation',
#   'like',
#   'pause',
#   'breathing',
#   'No',
#   'wonder'],
#  ['Power',
#   'exo',
#   'suitable',
#   'energetic',
#   'song',
#   'played',
#   'world',
#   'cup',
#   'believe',
#   'people'],
#  ['EXO', 'POWER', 'best', 'song', 'sounded', 'Olympics', 'Game', 'Dubai'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Mexican',
#   'pop',
#   'fan',
#   'celebrated',
#   'South',
#   'Koreas',
#   'win',
#   'way',
#   'mass',
#   'streaming',
#   'hit',
#   'single',
#   'Fake'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Fake', 'Love', 'amazing'],
#  ['good', 'song', 'rhythm', 'burn', 'spirit'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['The', 'Senegal', 'defender', 'watching', 'Colombia', 'score'],
#  ['The', 'round'],
#  ['NEW', 'FUNNY', 'FORTNITE', 'CLIP'],
#  ['Airplane',
#   'PT',
#   'BTS',
#   'Its',
#   'great',
#   'song',
#   'dance',
#   'latin',
#   'people',
#   'would',
#   'enjoy'],
#  ['CHARGING', 'The', 'world', 'wait', 'Leo', 'Messi', 'tomorrow'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Please', 'play'],
#  ['recommend', 'GO', 'HIGHER', 'Its', 'perfect', 'song', 'energize', 'player'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['Hi',
#   'favorite',
#   'song',
#   'Fake',
#   'Love',
#   'also',
#   'latin',
#   'inspired',
#   'one',
#   'called',
#   'Airplane',
#   'PT'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['EXO',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'played',
#   'Do',
#   'politely',
#   'Mention',
#   'abou'],
#  ['Please', 'play'],
#  ['Prediction', 'Noble', 'Quran', 'Modern', 'Means', 'Transport', 'Chat'],
#  ['Probable', 'line'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'EXO',
#   'Power',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'played',
#   'stadi'],
#  ['There', 'BIG', 'clash', 'look', 'forward', 'Round', 'Are', 'shock'],
#  ['Please', 'play'],
#  ['GOT', 'THE', 'New', 'Era', 'No', 'Billboard', 'Japan', 'boost', 'Suchmos'],
#  ['Please', 'play'],
#  ['The',
#   'Last',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia',
#   'Argentina',
#   'Sweden'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'agreement',
#   'Sampdoria',
#   'Torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Please',
#   'play',
#   'This',
#   'song',
#   'energetic',
#   'amd',
#   'powerfull',
#   'Fit',
#   'perfectly',
#   'wit'],
#  ['On',
#   'June',
#   'pm',
#   'Victory',
#   'Museum',
#   'invite',
#   'football',
#   'fan',
#   'visit',
#   'open',
#   'air',
#   'exposition',
#   'militar'],
#  ['Best', 'Prom', 'Table', 'Plan', 'ever', 'Thank', 'Ms', 'Cuddy'],
#  ['POWER', 'Nations', 'Pick'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Jesse',
#   'Lingards',
#   'curler',
#   'one',
#   'great',
#   'goal',
#   'year',
#   'FIFA',
#   'Do',
#   'agree',
#   'Watch',
#   'Engla'],
#  ['It', 'really', 'global', 'game', 'Where', 'watching'],
#  ['The', 'best', 'fan'],
#  ['My', 'favorite', 'song'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['Fake', 'Love'],
#  ['Catch',
#   'featuring',
#   'three',
#   'current',
#   'Reds',
#   'winner',
#   'former',
#   'player'],
#  ['City',
#   'Country',
#   'named',
#   'airplaine',
#   'part',
#   'participating',
#   'worldcup',
#   'London',
#   'Paris',
#   'Tokyo',
#   'Mexico',
#   'City',
#   'Brazil',
#   'ALL',
#   'THESE',
#   'COUNTRY'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'EXO',
#   'Power',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'played',
#   'stadi'],
#  ['Its', 'never', 'England'],
#  ['Please', 'play'],
#  ['EXO', 'POWER'],
#  ['As',
#   'group',
#   'stage',
#   'end',
#   'say',
#   'farewell',
#   'team',
#   'year',
#   'FIFA',
#   'Thanks',
#   'memory'],
#  ['The',
#   'ECA',
#   'campaign',
#   'ha',
#   'launched',
#   'accelerate',
#   'mass',
#   'adoption',
#   'goi'],
#  ['Who', 'going', 'win'],
#  ['Fun',
#   'Fact',
#   'At',
#   'least',
#   'national',
#   'team',
#   'arrived',
#   'style',
#   'FIFA',
#   'Check'],
#  ['Diego',
#   'Maradona',
#   'longer',
#   'paid',
#   'FIFA',
#   'ambassador',
#   'embarrassing',
#   'provocotive',
#   'behaviour'],
#  ['Fake', 'Love', 'amazing'],
#  ['Transformer', 'Please', 'play'],
#  ['My', 'postcard', 'Jennifer', 'Salke', 'future', 'S', 'would', 'tell'],
#  ['The',
#   'Last',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia',
#   'Argentina',
#   'Sweden'],
#  ['Anyone',
#   'else',
#   'woke',
#   'catch',
#   'match',
#   'realize',
#   'wa',
#   'one',
#   'today',
#   'even',
#   'need',
#   'alarm'],
#  ['Diego',
#   'Maradona',
#   'longer',
#   'paid',
#   'FIFA',
#   'ambassador',
#   'embarrassing',
#   'provocotive',
#   'behaviour'],
#  ['What',
#   'amazing',
#   'setting',
#   'game',
#   'football',
#   'Young',
#   'Russian',
#   'footballer',
#   'took',
#   'part',
#   'exhibition',
#   'match',
#   'Moscows',
#   'Fo'],
#  ['Ready', 'knockout'],
#  ['Round', 'Predictions', 'Including', 'v', 'via'],
#  ['No', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['We', 'know', 'guy', 'rooting', 'tomorrow'],
#  ['Please', 'play'],
#  ['The',
#   'true',
#   'story',
#   'world',
#   'greatest',
#   'Ronaldo',
#   'available',
#   'iTunes'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Nation',
#   'Pick',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit'],
#  ['Pablo',
#   'Zabaleta',
#   'belief',
#   'Its',
#   'last',
#   'chance',
#   'many',
#   'star',
#   'player',
#   'win'],
#  ['EXO',
#   'Ls',
#   'This',
#   'would',
#   'honour',
#   'EXO',
#   'know',
#   'POWER',
#   'motivates',
#   'athlete',
#   'Send',
#   'request',
#   'POWER',
#   'tag'],
#  ['When', 'wake', 'watch'],
#  ['POWER', 'ultimate', 'song', 'give', 'energy', 'soccer', 'player'],
#  ['Disappointed', 'hopefully', 'beat', 'get', 'Semis'],
#  ['RT', 'comment', 'Please', 'play'],
#  ['France', 'VS', 'Argentina', 'Who', 'win'],
#  ['Please', 'play'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['The', 'round'],
#  ['Wait'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Power', 'EXO'],
#  ['tomorrow', 'Nice'],
#  ['The',
#   'best',
#   'XI',
#   'group',
#   'stage',
#   'play',
#   'includes',
#   'Real',
#   'Madrid',
#   'teammate',
#   'Modric',
#   'Ronaldo',
#   'Isco',
#   'along',
#   'Harry',
#   'Kane',
#   'No',
#   'Messi'],
#  ['We',
#   'heard',
#   'feedback',
#   'IMPROVED',
#   'World',
#   'Cup',
#   'squad',
#   'Thanks',
#   'everyone'],
#  ['It', 'ha', 'TOO', 'LONG', 'since', 'match'],
#  ['Please', 'play'],
#  ['Win', 'wnrs'],
#  ['watch',
#   'root',
#   'everything',
#   'else',
#   'need',
#   'know',
#   'The',
#   'game',
#   'start',
#   'Saturday',
#   'morning'],
#  ['You',
#   'play',
#   'wa',
#   'performed',
#   'Olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['Check', 'latest', 'Talking', 'El', 'Tri', 'preview', 'v'],
#  ['We',
#   'would',
#   'recomended',
#   'play',
#   'EXO',
#   'Power',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'choosen'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['That', 'goal', 'celebration'],
#  ['Please', 'play'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Are'],
#  ['voted',
#   'EXO',
#   'POWER',
#   'played',
#   'stadium',
#   'The',
#   'song',
#   'amazing',
#   'lit',
#   'energ'],
#  ['And', 'last', 'draw', 'full', 'th', 'June', 'pm', 'pm', 'st', 'July', 'pm'],
#  ['POWER'],
#  ['Are', 'excited', 'match', 'later', 'We', 'ADIDAS', 'STARLANCER'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'EXO',
#   'Power',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'played',
#   'stadi'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['Black', 'Pink', 'twice'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['EXO',
#   'Ls',
#   'This',
#   'would',
#   'honour',
#   'EXO',
#   'know',
#   'POWER',
#   'motivates',
#   'athlete',
#   'Send',
#   'request',
#   'POWER',
#   'tag'],
#  ['Power', 'de', 'EXO', 'Please', 'play', 'http'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Power', 'Exo', 'please', 'like', 'much'],
#  ['want',
#   'spirit',
#   'energy',
#   'right',
#   'recomend',
#   'Power',
#   'EXO',
#   'song',
#   'actually',
#   'burn',
#   'spirit'],
#  ['EXO',
#   'Ls',
#   'This',
#   'would',
#   'honour',
#   'EXO',
#   'know',
#   'POWER',
#   'motivates',
#   'athlete',
#   'Send',
#   'request',
#   'POWER',
#   'tag'],
#  ['Fun',
#   'Fact',
#   'At',
#   'least',
#   'national',
#   'team',
#   'arrived',
#   'style',
#   'FIFA',
#   'Check'],
#  ['RT', 'comment', 'Please', 'play'],
#  ['How', 'far', 'go'],
#  ['would', 'perfect', 'put', 'POWER'],
#  ['POWER'],
#  ['BTS',
#   'OBVIUSLY',
#   'THESE',
#   'SONGS',
#   'Fake',
#   'Love',
#   'Its',
#   'beloved',
#   'song',
#   'literally',
#   'perfect',
#   'And',
#   'co'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['RT', 'Please', 'play'],
#  ['wonder',
#   'much',
#   'time',
#   'spends',
#   'day',
#   'perfecting',
#   'hit',
#   'rolling',
#   'back',
#   'Brazil',
#   'roll'],
#  ['Power',
#   'perfect',
#   'song',
#   'wa',
#   'played',
#   'Winter',
#   'Olympic',
#   'closing',
#   'ceremony'],
#  ['BREAKING',
#   'Diego',
#   'Maradona',
#   'longer',
#   'paid',
#   'FIFA',
#   'ambassador',
#   'embarrassing',
#   'provocotive',
#   'behaviour'],
#  ['AIRPLANE', 'PT', 'BTS', 'Thankyou'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen',
#   'played',
#   'Olym'],
#  ['France',
#   'Round',
#   'Won',
#   'Nigeria',
#   'Lost',
#   'Spain',
#   'Won',
#   'Paraguay',
#   'aet',
#   'Won',
#   'Italy',
#   'Lost',
#   'Austria',
#   'aet'],
#  ['SUPPORTING',
#   'MY',
#   'FRENCH',
#   'TEAM',
#   'TOMORROW',
#   'WE',
#   'ARE',
#   'NOT',
#   'SCARED',
#   'NUT',
#   'FANS',
#   'AND',
#   'YOU'],
#  ['Power',
#   'Exo',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please'],
#  ['Please', 'play'],
#  ['de', 'Please', 'play'],
#  ['Please', 'play'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen',
#   'played',
#   'Olym'],
#  ['We',
#   'removing',
#   'German',
#   'category',
#   'Pornhub',
#   'following',
#   'humiliating',
#   'elimination'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['POWER'],
#  ['Please', 'play'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Nation',
#   'Pick',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit'],
#  ['When',
#   'Son',
#   'Heungmin',
#   'capped',
#   'famous',
#   'win',
#   'Korea',
#   'Republic',
#   'reigning',
#   'champion',
#   'German'],
#  ['Mexican',
#   'pop',
#   'fan',
#   'celebrated',
#   'South',
#   'Koreas',
#   'win',
#   'way',
#   'mass',
#   'streaming',
#   'hit',
#   'single',
#   'Fake'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['Our',
#   'thought',
#   'Iran',
#   'striker',
#   'Sardar',
#   'Azmoun',
#   'ha',
#   'retired',
#   'international',
#   'football',
#   'age',
#   'He'],
#  ['EXO', 'Olympics', 'EXO', 'Nations', 'Pick', 'POWER'],
#  ['POWER', 'POWER'],
#  ['The',
#   'best',
#   'XI',
#   'group',
#   'stage',
#   'play',
#   'includes',
#   'Real',
#   'Madrid',
#   'teammate',
#   'Modric',
#   'Ronaldo',
#   'Isco',
#   'along',
#   'Harry',
#   'Kane',
#   'No',
#   'Messi',
#   'More'],
#  ['Please', 'play'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Please', 'play'],
#  ['So',
#   'please',
#   'play',
#   'Power',
#   'stadium',
#   'Power',
#   'song',
#   'make',
#   'anyone',
#   'hears',
#   'becomes',
#   'spirit',
#   'EXO',
#   'channeled',
#   'passion',
#   'many',
#   'people',
#   'song',
#   'well',
#   'Thankyou',
#   'much'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['POWER'],
#  ['This',
#   'World',
#   'Cup',
#   'rest',
#   'day',
#   'causing',
#   'acute',
#   'withdrawal',
#   'symptom'],
#  ['For',
#   'everyone',
#   'missed',
#   'England',
#   'Vs',
#   'Belgium',
#   'game',
#   'highlight'],
#  ['FOUND', 'THE', 'VIDEO', 'HAHAHA', 'play', 'blackpink', 'forever', 'young'],
#  ['The', 'best', 'goal', 'celebration', 'ever'],
#  ['POWER', 'ultimate', 'song', 'give', 'energy', 'soccer', 'player'],
#  ['The', 'Senegal', 'defender', 'watching', 'Colombia', 'score'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Nation',
#   'Pick',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen',
#   'played',
#   'Olympics',
#   'Dubai',
#   'Fountain'],
#  ['Do', 'worry', 'child', 'Swedish', 'House', 'Mafia'],
#  ['Golo', 'Kant', 'highest', 'player', 'interception', 'Group', 'Stage', 'WC'],
#  ['What', 'lie', 'ahead', 'country', 'still', 'report', 'via'],
#  ['Please',
#   'play',
#   'Power',
#   'Exo',
#   'wa',
#   'performed',
#   'Olympic',
#   'wa',
#   'first',
#   'song',
#   'played',
#   'th'],
#  ['Power', 'EXO'],
#  ['Please', 'play'],
#  ['important', 'day', 'Leo', 'Messi'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['POWER'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['POWER',
#   'global',
#   'hit',
#   'song',
#   'ha',
#   'lyric',
#   'fitting',
#   'sport',
#   'event',
#   'giving',
#   'athlet'],
#  ['Life',
#   'achieving',
#   'goal',
#   'In',
#   'honor',
#   'check',
#   'new',
#   'track',
#   'FIFA',
#   'World',
#   'Cup',
#   'Russia',
#   'Ekaterinburg',
#   'Excursions'],
#  ['part',
#   'unfairly',
#   'treated',
#   'need',
#   'get',
#   'back',
#   'get',
#   'full',
#   'backing',
#   'fan',
#   'plz',
#   'like',
#   'retweet'],
#  ['going', 'business', 'morning'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['EXO', 'Power', 'please', 'got', 'POWER', 'POWER'],
#  ['The', 'Senegal', 'defender', 'watching', 'Colombia', 'score'],
#  ['My', 'favorite', 'song'],
#  ['Prediction', 'Noble', 'Quran', 'Modern', 'Means', 'Transport', 'Chat'],
#  ['FREE', 'BEER', 'WITH', 'EVERY', 'TEAM', 'USA', 'GOAL', 'Hey', 'cruel'],
#  ['Bone', 'Thugs', 'Harmony', 'If', 'Could', 'Teach', 'The', 'World', 'Song'],
#  ['The', 'happening', 'Twitter'],
#  ['Ranked',
#   'All',
#   'team',
#   'based',
#   'group',
#   'stage',
#   'performance',
#   'The',
#   'group',
#   'stage',
#   'side',
#   'imp'],
#  ['EXOs',
#   'energetic',
#   'song',
#   'POWER',
#   'would',
#   'suitable',
#   'played',
#   'The',
#   'song',
#   'performed',
#   'closing',
#   'ceremony',
#   'Pyeonchang',
#   'Winter',
#   'Olympics',
#   'wa',
#   'played',
#   'next',
#   'Big',
#   'artist',
#   'song',
#   'Dubai',
#   'Fountain'],
#  ['Malam', 'ni', 'match', 'v'],
#  ['power'],
#  ['Transformer', 'Please', 'play'],
#  ['Entire', 'day', 'action', 'Guess', 'watch', 'baseba', 'nooooope', 'fuck'],
#  ['Please', 'play'],
#  ['POWER', 'BY', 'EXO', 'CUZ', 'ITS', 'AMAZING'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['Please', 'play'],
#  ['The', 'feeling', 'wa', 'game'],
#  ['Please', 'play'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Because', 'WE', 'GOT', 'THAT', 'POWER', 'Power'],
#  ['Please', 'play'],
#  ['Let', 'game', 'begin'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['Please', 'play'],
#  ['Please', 'play'],
#  ['Power'],
#  ['Sleep', 'Right', 'Side', 'Chat'],
#  ['Please', 'play'],
#  ['Please', 'play'],
#  ['There', 'goal', 'scored', 'th', 'minute', 'later', 'final', 'far', 'This'],
#  ['Centurion', 'Jesus', 'Teaching', 'Temple'],
#  ['They',
#   'made',
#   'Are',
#   'going',
#   'see',
#   'unexpected',
#   'exit',
#   'round',
#   'Will',
#   'score'],
#  ['You',
#   'simply',
#   'scroll',
#   'past',
#   'without',
#   'liking',
#   'Cristiano',
#   'Ronaldo',
#   'fan'],
#  ['EXO',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'Power',
#   'EXO',
#   'It',
#   'could',
#   'played',
#   'Do',
#   'politely',
#   'Mention',
#   'abou'],
#  ['Please', 'play'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['No', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['Power', 'Please', 'play'],
#  ['My', 'favorite', 'song'],
#  ['Please', 'play'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['It',
#   'wa',
#   'team',
#   'said',
#   'farewell',
#   'Saransk',
#   'Kaliningrad',
#   'Ekaterinburg',
#   'Volgograd',
#   'also',
#   'hosted'],
#  ['You',
#   'play',
#   'wa',
#   'performed',
#   'Olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['global',
#   'festival',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['You',
#   'play',
#   'wa',
#   'performed',
#   'Olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['Trent',
#   'Alexander',
#   'Arnold',
#   'Last',
#   'Months',
#   'Liverpool',
#   'Debut',
#   'PL',
#   'Debut',
#   'First',
#   'PL',
#   'Goal',
#   'UCL',
#   'Debut',
#   'UCL',
#   'Debut',
#   'Goal',
#   'UCL'],
#  ['An',
#   'energetic',
#   'song',
#   'song',
#   'positive',
#   'vibe',
#   'successful',
#   'song',
#   'deportive',
#   'event',
#   'meaningful',
#   'song'],
#  ['These', 'kid', 'love', 'playing', 'soccer', 'Who', 'rooting'],
#  ['Luke',
#   'Be',
#   'careful',
#   'heart',
#   'weighed',
#   'carousing',
#   'drunkenness',
#   'anxiety',
#   'life'],
#  ['Qualified',
#   'group',
#   'stage',
#   'Into',
#   'knockout',
#   'Full',
#   'focus',
#   'Tuesday'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'agreement',
#   'Sampdoria',
#   'Torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['say', 'take', 'confidence', 'collective', 'experience', 'ahead', 'Round'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'agreement',
#   'Sampdoria',
#   'Torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['RT', 'Please', 'play'],
#  ['Hope',
#   'Solo',
#   'strong',
#   'word',
#   'state',
#   'soccer',
#   'United',
#   'States',
#   'failed',
#   'qualify'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['important', 'day', 'Leo', 'Messi'],
#  ['Please', 'play'],
#  ['Power', 'de', 'EXO', 'Please', 'play'],
#  ['Power', 'would', 'great', 'choice'],
#  ['Please', 'play'],
#  ['recommend', 'GO', 'HIGHER', 'Its', 'perfect', 'song', 'energize', 'player'],
#  ['The', 'original', 'countdown', 'ever', 'launch'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['You',
#   'play',
#   'wa',
#   'performed',
#   'Olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['Power', 'de'],
#  ['Its', 'taking'],
#  ['Guys',
#   'comment',
#   'post',
#   'request',
#   'EXOs',
#   'Power',
#   'played',
#   'FIFA',
#   'World',
#   'Cup',
#   'please',
#   'also',
#   'use',
#   'officia'],
#  ['Please',
#   'Play',
#   'POWER',
#   'Nations',
#   'Pick',
#   'One',
#   'Best',
#   'Kpop',
#   'Boy',
#   'Group',
#   'It',
#   'wa',
#   'already',
#   'played'],
#  ['Kindly', 'play', 'EXOs', 'Power', 'FIFA', 'world', 'cup'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Please', 'play'],
#  ['Please', 'play'],
#  ['Can',
#   'predict',
#   'result',
#   'Who',
#   'score',
#   'first',
#   'face',
#   'How',
#   'finish',
#   'Join'],
#  ['Batshuayi', 'arguably', 'funniest', 'moment'],
#  ['WE', 'GOT', 'THE', 'POOOOOWER', 'POOOOOWER'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['star', 'reached', 'knockout', 'stage', 'Marcos', 'Rojo'],
#  ['Please', 'play'],
#  ['Please', 'play'],
#  ['Researchers',
#   'world',
#   'wide',
#   'choose',
#   'LI',
#   'COR',
#   'Western',
#   'blot',
#   'champion',
#   'Will',
#   'team',
#   'World',
#   'Cup',
#   'champion',
#   'Vote'],
#  ['RT', 'Please', 'play'],
# ...
#   'kick',
#   'frie'],
#  ['Power', 'de', 'EXO', 'Please', 'play'],
#  ['Please', 'play'],
#  ['Please',
#   'play',
#   'POWER',
#   'Its',
#   'bop',
#   'plus',
#   'hope',
#   'empowerment',
#   'Thanks',
#   'much'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['please', 'play', 'THANKYOU', 'SO', 'MUCH'],
#  ['Please', 'play'],
#  ['The', 'player', 'lit', 'group', 'stage'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Didier',
#   'Deschamps',
#   'France',
#   'coach',
#   'Messi',
#   'Messi',
#   'We',
#   'like',
#   'mark',
#   'neutralize',
#   'know',
#   'well'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Nabbout', 'indebted', 'Bert'],
#  ['Please', 'play'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['My', 'favorite', 'song'],
#  ['Ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'Arsenal',
#   'hopeful',
#   'agreement',
#   'Sampdoria',
#   'Torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['Completely',
#   'unchartered',
#   'territory',
#   'English',
#   'men',
#   'woman',
#   'born',
#   'This',
#   'first'],
#  ['GOT', 'THE', 'New', 'Era', 'No', 'Billboard', 'Japan', 'boost', 'Suchmos'],
#  ['Power', 'de', 'EXO', 'Please', 'play', 'http'],
#  ['driver',
#   'arrested',
#   'trying',
#   'meet',
#   'underage',
#   'girl',
#   'All',
#   'caught',
#   'camera',
#   'Raj',
#   'Khan',
#   'age'],
#  ['It', 'ha', 'TOO', 'LONG', 'since', 'match'],
#  ['get',
#   'enough',
#   'FIFA',
#   'right',
#   'Like',
#   'Retweet',
#   'subscribe',
#   'Match',
#   'Day',
#   'Programme'],
#  ['Sleep', 'Right', 'Side', 'Chat'],
#  ['Everything', 'one', 'place'],
#  ['What',
#   'happens',
#   'football',
#   'knowledge',
#   'focus',
#   'wrong',
#   'thing',
#   'business',
#   'football'],
#  ['Based',
#   'matchup',
#   'past',
#   'performance',
#   'peak',
#   'potential',
#   'round',
#   'field',
#   'stack',
#   'road'],
#  ['Colombia', 'face', 'England', 'next', 'round'],
#  ['RT', 'comment', 'Please', 'play'],
#  ['Power', 'de', 'EXO', 'Please', 'play'],
#  ['My', 'postcard', 'Jennifer', 'Salke', 'future', 'S', 'would', 'tell'],
#  ['POWER', 'BY', 'EXO', 'CUZ', 'ITS', 'AMAZING'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Please', 'play', 'power'],
#  ['The',
#   'Last',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia',
#   'Argentina',
#   'Sweden'],
#  ['Please', 'play'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['Please', 'play'],
#  ['Keeping', 'cool', 'Brand', 'new', 'City', 'way'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['My', 'favorite', 'song'],
#  ['EXO', 'POWER', 'Please', 'play', 'ht'],
#  ['Please', 'play'],
#  ['Planning',
#   'going',
#   'watch',
#   'World',
#   'Cup',
#   'knockout',
#   'round',
#   'game',
#   'LA',
#   'This',
#   'city',
#   'wonderful',
#   'Another',
#   'shout',
#   'fun',
#   'guide'],
#  ['Just', 'another', 'day', 'Red', 'Square', 'Russia'],
#  ['An',
#   'AI',
#   'simulated',
#   'World',
#   'Cup',
#   'time',
#   'This',
#   'think',
#   'win',
#   'Full',
#   'Article',
#   'Facebook',
#   'Wrohens',
#   'Link'],
#  ['Most',
#   'take',
#   'ons',
#   'completed',
#   'group',
#   'stage',
#   'Lionel',
#   'Messi',
#   'Neymar',
#   'Oghenekaro',
#   'Etebo'],
#  ['Anime', 'Characters', 'v', 'WiFi', 'Passwords'],
#  ['Power', 'de', 'EXO', 'e', 'perfecta', 'Please', 'play'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['When',
#   'wedding',
#   'The',
#   'final',
#   'episode',
#   'crazy',
#   'fan',
#   'saga',
#   'IG',
#   'jerofreixas'],
#  ['EXO', 'POWER', 'Please', 'play', 'htt'],
#  ['As',
#   'group',
#   'stage',
#   'end',
#   'say',
#   'farewell',
#   'team',
#   'year',
#   'FIFA',
#   'Thanks',
#   'memory'],
#  ['All', 'need', 'POWER'],
#  ['When', 'realise', 'game', 'today'],
#  ['Can',
#   'predict',
#   'result',
#   'Who',
#   'score',
#   'first',
#   'face',
#   'How',
#   'finish',
#   'Join'],
#  ['TRIGGER',
#   'THE',
#   'FEVER',
#   'NCT',
#   'DREAM',
#   'Please',
#   'bcs',
#   'song',
#   'dedicated',
#   'world',
#   'cup'],
#  ['Fire', 'FAKE', 'LOVE'],
#  ['Please', 'play'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Best',
#   'goal',
#   'far',
#   'Beautiful',
#   'pas',
#   'Perfect',
#   'first',
#   'touch',
#   'Out',
#   'world',
#   'second',
#   'touch',
#   'Brilli'],
#  ['The',
#   'Group',
#   'Stages',
#   'Games',
#   'Goals',
#   'Nil',
#   'Nil',
#   'Draw',
#   'Penalties',
#   'Own',
#   'Goals'],
#  ['Please', 'play'],
#  ['EXOs',
#   'energetic',
#   'song',
#   'POWER',
#   'would',
#   'suitable',
#   'played',
#   'The',
#   'song',
#   'performed',
#   'closin'],
#  ['Please', 'play'],
#  ['Olarrrr', 'We', 'want', 'hear', 'Fake', 'Love', 'Play', 'u'],
#  ['As',
#   'group',
#   'stage',
#   'end',
#   'say',
#   'farewell',
#   'team',
#   'year',
#   'FIFA',
#   'Thanks',
#   'memory'],
#  ['After',
#   'horrendous',
#   'day',
#   'profession',
#   'began',
#   'joy',
#   'please',
#   'watch',
#   'uplifting',
#   'video'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['When', 'almost', 'made', 'whole', 'day', 'action'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['TRIGGER', 'THE', 'FEVER', 'NCT', 'DREAM'],
#  ['Please', 'play', 'power', 'EXO'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Play', 'Power', 'EXO'],
#  ['EXO', 'POWER'],
#  ['EXO', 'POWER', 'Please', 'play'],
#  ['Its', 'taking'],
#  ['RT', 'comment', 'Please', 'play'],
#  ['Trent',
#   'Alexander',
#   'Arnold',
#   'Last',
#   'Months',
#   'Liverpool',
#   'Debut',
#   'PL',
#   'Debut',
#   'First',
#   'PL',
#   'Goal',
#   'UCL',
#   'Debut',
#   'UCL',
#   'Debut',
#   'Goal',
#   'UCL'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['AIRPLANE', 'PT'],
#  ['No', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Trent',
#   'Alexander',
#   'Arnold',
#   'Last',
#   'Months',
#   'Liverpool',
#   'Debut',
#   'PL',
#   'Debut',
#   'First',
#   'PL',
#   'Goal',
#   'UCL',
#   'Debut',
#   'UCL',
#   'Debut',
#   'Goal',
#   'UCL'],
#  ['bellanaija', 'Japan', 'Poland', 'Watch', 'Highlights'],
#  ['global',
#   'festival',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['bellanaija',
#   'Senegal',
#   'Journey',
#   'come',
#   'End',
#   'loss',
#   'Colombia',
#   'Watch',
#   'Highlights'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['Power'],
#  ['NCT', 'DREAM', 'TRIGGER', 'THE', 'FEVER'],
#  ['say', 'take', 'confidence', 'collective', 'experience', 'ahead', 'Round'],
#  ['Darling', 'least', 'take', 'something', 'going', 'bed', 'Nigerian', 'men'],
#  ['Another',
#   'song',
#   'would',
#   'like',
#   'recommend',
#   'Hard',
#   'Carry',
#   'HARD',
#   'CARRY',
#   'HEY',
#   'Its',
#   'HYPE'],
#  ['Like', 'RT', 'subscribe', 'digital', 'Match', 'Day', 'Program'],
#  ['good', 'song', 'rhythm', 'burn', 'spirit'],
#  ['Coral',
#   'Sports',
#   'Sat',
#   'th',
#   'June',
#   'Uruguay',
#   'Portugal',
#   'Coral',
#   'Offer',
#   'Max',
#   'bet',
#   'Ronaldo',
#   'Score',
#   'New',
#   'Customers',
#   'Only',
#   'Cs',
#   'Apply',
#   'Gamble',
#   'Aware',
#   'Claim'],
#  ['All', 'need', 'POWER'],
#  ['Can',
#   'predict',
#   'result',
#   'Who',
#   'score',
#   'first',
#   'face',
#   'How',
#   'finish',
#   'Join'],
#  ['EXOL',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'EXO',
#   'Power',
#   'favourite',
#   'song',
#   'It',
#   'could',
#   'played',
#   'stadi'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['When', 'realise', 'game', 'today'],
#  ['The', 'energy', 'use', 'redirected', 'warming', 'TV'],
#  ['An',
#   'estimated',
#   'million',
#   'pint',
#   'poured',
#   'UK',
#   'last',
#   'night',
#   'Just',
#   'imagine',
#   'win',
#   'bloody',
#   'thing'],
#  ['O', 'E', 'P', 'W', 'R', 'O', 'E', 'EXO'],
#  ['Power',
#   'exo',
#   'song',
#   'FIFA',
#   'Its',
#   'going',
#   'turn',
#   'mood',
#   'even',
#   'Will',
#   'bring',
#   'festive',
#   'atmosphere'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Please',
#   'play',
#   'Power',
#   'Exo',
#   'wa',
#   'performed',
#   'Olympic',
#   'wa',
#   'first',
#   'song',
#   'played',
#   'th'],
#  ['Please', 'play'],
#  ['Queroooooooo', 'We', 'want', 'hear', 'Fake', 'Love', 'Play', 'u'],
#  ['Good', 'Morning'],
#  ['Retweeted',
#   'Weight',
#   'Watchers',
#   'Ready',
#   'big',
#   'game',
#   'tonight',
#   'England',
#   'VS',
#   'Belgium',
#   'In',
#   'battle',
#   'dessert',
#   'would',
#   'pick',
#   'Find',
#   'recipe'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['We',
#   'would',
#   'recommend',
#   'play',
#   'EXO',
#   'Power',
#   'It',
#   'energetic',
#   'song',
#   'suit',
#   'It',
#   'wa',
#   'chosen'],
#  ['Please', 'play'],
#  ['They',
#   'Keisuke',
#   'Honda',
#   'becomes',
#   'th',
#   'ever',
#   'Asian',
#   'player',
#   'score',
#   'World',
#   'Cup',
#   'competiti'],
#  ['Thank', 'everything', 'South', 'Korea'],
#  ['The',
#   'World',
#   'Football',
#   'Phone',
#   'back',
#   'knockout',
#   'special',
#   'Joining',
#   'Legendinho',
#   'Northern',
#   'Seoul',
#   'world',
#   'football',
#   'fan',
#   'How',
#   'cope',
#   'day',
#   'game'],
#  ['Ready',
#   'big',
#   'game',
#   'tonight',
#   'England',
#   'VS',
#   'Belgium',
#   'In',
#   'battle',
#   'dessert',
#   'would',
#   'pick',
#   'Find',
#   'reci'],
#  ['Power'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['Points',
#   'GD',
#   'Scored',
#   'Head',
#   'head',
#   'Yellow',
#   'card',
#   'For',
#   'first',
#   'time',
#   'ever',
#   'team',
#   'ha',
#   'kno'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Most',
#   'take',
#   'ons',
#   'completed',
#   'group',
#   'stage',
#   'Lionel',
#   'Messi',
#   'Neymar',
#   'Oghenekaro',
#   'Etebo'],
#  ['Mart',
#   'nez',
#   'fully',
#   'fit',
#   'He',
#   'completed',
#   'training',
#   'session',
#   'today'],
#  ['It', 'really', 'global', 'game', 'Where', 'watching'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['Did', 'someone', 'say', 'football', 'wait', 'tomorrow'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['EXOs',
#   'energetic',
#   'song',
#   'POWER',
#   'would',
#   'suitable',
#   'played',
#   'The',
#   'song',
#   'performed',
#   'closin'],
#  ['Resilience',
#   'give',
#   'strength',
#   'keep',
#   'moving',
#   'forward',
#   'caught',
#   'rain',
#   'storm',
#   'keep',
#   'continuin'],
#  ['star', 'reached', 'knockout', 'stage', 'Marcos', 'Rojo'],
#  ['The', 'Senegal', 'defender', 'watching', 'Colombia', 'score'],
#  ['BREAKING', 'Trumps', 'Epic', 'World', 'Cup', 'Speech'],
#  ['CHARGING', 'The', 'world', 'wait', 'Leo', 'Messi', 'tomorrow'],
#  ['Please', 'play'],
#  ['Retweet',
#   'country',
#   'still',
#   'Russia',
#   'Uruguay',
#   'Spain',
#   'Portugal',
#   'France',
#   'Denmark',
#   'Croatia'],
#  ['think', 'would', 'amazing', 'song', 'World', 'Cup'],
#  ['Here', 'pick', 'World', 'Cup', 'squad', 'operator', 'would', 'sub', 'http'],
#  ['As',
#   'group',
#   'stage',
#   'end',
#   'say',
#   'farewell',
#   'team',
#   'year',
#   'FIFA',
#   'Thanks',
#   'memory'],
#  ['Fake', 'love', 'BTS', 'best', 'best'],
#  ['Colombian',
#   'man',
#   'help',
#   'deaf',
#   'blind',
#   'friend',
#   'experience',
#   'joy',
#   'team',
#   'campaign',
#   'Read'],
#  ['Please', 'play'],
#  ['Fire', 'FAKE', 'LOVE'],
#  ['Top',
#   'Goalscorers',
#   'By',
#   'League',
#   'La',
#   'Liga',
#   'Premier',
#   'League',
#   'Bundesliga'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Heres', 'group', 'finished', 'meaning', 'play', 'play', 'next', 'round'],
#  ['Just',
#   'wrote',
#   'first',
#   'piece',
#   'Its',
#   'racist',
#   'slanted',
#   'eye',
#   'gesture',
#   'keep',
#   'appearing'],
#  ['No', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['global',
#   'festival',
#   'SEOUL',
#   'Russia',
#   'World',
#   'Cup',
#   'Street',
#   'Cheering',
#   'Thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['So', 'Exci'],
#  ['The',
#   'song',
#   'playing',
#   'biggest',
#   'fountain',
#   'Dubai',
#   'song',
#   'passionate',
#   'unique',
#   'We',
#   'got'],
#  ['Please', 'play'],
#  ['Please', 'play'],
#  ['Power', 'EXO'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Kylian',
#   'Mbapp',
#   'donate',
#   'everything',
#   'earns',
#   'charity',
#   'This',
#   'add',
#   'per',
#   'game'],
#  ['Please', 'play'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['Power'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['We', 'TWELVE', 'madridistas', 'involved', 'last', 'Find'],
#  ['Having',
#   'leave',
#   'World',
#   'Cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'We',
#   'good',
#   'enough',
#   'need'],
#  ['Qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['Its',
#   'time',
#   'give',
#   'superior',
#   'song',
#   'recognition',
#   'deserves',
#   'Request',
#   'NCT',
#   'Dreams',
#   'Trigger',
#   'The',
#   'Fever'],
#  ['photo', 'renaissance', 'art', 'Can', 'get', 'ruling'],
#  ['O', 'E', 'P', 'W', 'R', 'O', 'E', 'EXO'],
#  ['Got',
#   'favourite',
#   'tune',
#   'Tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['Please',
#   'play',
#   'Power',
#   'EXO',
#   'EXO',
#   'also',
#   'performed',
#   'Closing',
#   'Ceremony',
#   'Winter',
#   'Olympics',
#   'The',
#   'song'],
#  ['ESPN', 'Lionel', 'Messi', 'first', 'player', 'score', 'goal', 'teen'],
#  ['Today', 'anniversary', 'upset', 'England', 'Heres', 'retrospective', 'lat'],
#  ['Please', 'play'],
#  ['BTS',
#   'OBVIUSLY',
#   'THESE',
#   'SONGS',
#   'Fake',
#   'Love',
#   'Its',
#   'beloved',
#   'song',
#   'literally',
#   'perfect',
#   'And',
#   'co'],
#  ['Please', 'play'],
#  ['EXO', 'POWER'],
#  ['All', 'team', 'given', 'score', 'What', 'would', 'give'],
#  ['Power', 'de', 'EXO', 'Please', 'play', 'http'],
#  ['POWER',
#   'global',
#   'hit',
#   'song',
#   'ha',
#   'lyric',
#   'fitting',
#   'sport',
#   'event',
#   'giving',
#   'athlet'],
#  ['Please', 'play'],
#  ['Kylian',
#   'Mbapp',
#   'donate',
#   'everything',
#   'earns',
#   'charity',
#   'This',
#   'add',
#   'per',
#   'game'],
#  ['ICYMI',
#   'Some',
#   'musing',
#   'Day',
#   'perfect',
#   'group',
#   'stage',
#   'doe',
#   'aways',
#   'mean',
#   'championship',
#   'http'],
#  ['Messi', 'get', 'face', 'saving', 'Kazan', 'mural', 'match', 'Ronaldos'],
#  ['RT', 'comment', 'Please', 'play'],
#  ['Please', 'play', 'POWER', 'EXO', 'thanks'],
#  ...]

# %% [markdown]
# ## 2c. Convert strings to lowercase:

# %%
tweets_preproc = []
for i in tweets_no_sw:
    lower_list = [token.lower() for token in i]
    tweets_preproc.append(lower_list)
tweets_preproc
# Out:
# [['want',
#   'make',
#   'summer',
#   'football',
#   'little',
#   'bit',
#   'hotter',
#   'rt',
#   'follow'],
#  ['didier',
#   'deschamps',
#   'ha',
#   'confirmed',
#   'benjamin',
#   'mendy',
#   'miss',
#   'tomorrow',
#   'game',
#   'due',
#   'muscular',
#   'problem'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['week',
#   'team',
#   'game',
#   'goal',
#   'the',
#   'group',
#   'stage',
#   'wa',
#   'everything',
#   'hoped'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['hi',
#   'everyone',
#   'lets',
#   'get',
#   'started',
#   'round',
#   'excited',
#   'miss',
#   'every',
#   'football',
#   'league',
#   'come',
#   'world',
#   'cup',
#   'well'],
#  ['first',
#   'night',
#   'world',
#   'cup',
#   'game',
#   'chat',
#   'missus',
#   'she',
#   'seems',
#   'nice',
#   'girl',
#   'fair'],
#  ['batshuayi', 'arguably', 'funniest', 'moment'],
#  ['global',
#   'festival',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheering',
#   'thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['watch',
#   'budweiser',
#   'yerry',
#   'mina',
#   'talk',
#   'squad',
#   'dance',
#   'what',
#   'next',
#   'http'],
#  ['power', 'de', 'exo', 'please', 'play', 'http'],
#  ['the',
#   'round',
#   'confirmed',
#   'tin',
#   'jedvaj',
#   'croatia',
#   'take',
#   'denmark',
#   'sunday'],
#  ['power', 'please', 'play'],
#  ['charging', 'the', 'world', 'wait', 'leo', 'messi', 'tomorrow'],
#  ['exo',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'played',
#   'do',
#   'politely',
#   'mention',
#   'abou'],
#  ['global',
#   'festival',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheering',
#   'thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['there', 'the', 'last', 'confirmed', 'catch', 'highlight', 'ht'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['soccer', 'themed', 'nesting', 'doll', 'score', 'point', 'fan', 'see'],
#  ['recommend',
#   'lo',
#   'siento',
#   'by',
#   'super',
#   'junior',
#   'ft',
#   'leslie',
#   'grace',
#   'playnskillz',
#   'its',
#   'nice',
#   'trilingual',
#   'song',
#   'english',
#   'spanish'],
#  ['please', 'play'],
#  ['mexican',
#   'pop',
#   'fan',
#   'celebrated',
#   'south',
#   'koreas',
#   'win',
#   'way',
#   'mass',
#   'streaming',
#   'hit',
#   'single',
#   'fake'],
#  ['when', 'almost', 'made', 'whole', 'day', 'action'],
#  ['second', 'half', 'surge', 'see', 'tunisia', 'bow', 'style'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['global',
#   'festival',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheering',
#   'thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['please', 'play'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['the', 'senegal', 'defender', 'watching', 'colombia', 'score'],
#  ['please', 'play'],
#  ['cameraman', 'fc', 'ha', 'real', 'mvp', 'far'],
#  ['you',
#   'play',
#   'wa',
#   'performed',
#   'olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['exo',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'played',
#   'do',
#   'politely',
#   'mention',
#   'abou'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['you',
#   'play',
#   'wa',
#   'performed',
#   'olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['exol',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'exo',
#   'power',
#   'favourite',
#   'song',
#   'it',
#   'could',
#   'played',
#   'stadi'],
#  ['power'],
#  ['all', 'need', 'power'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['my', 'favourite', 'song', 'fake', 'love', 'thank'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['waking', 'morning', 'realizing', 'game', 'today'],
#  ['rt', 'comment', 'please', 'play'],
#  ['power',
#   'exo',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please'],
#  ['please', 'play'],
#  ['guardiola',
#   'win',
#   'league',
#   'spain',
#   'spain',
#   'win',
#   'world',
#   'cup',
#   'guardiola',
#   'win',
#   'league',
#   'germany'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['po', 'favor'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['voted',
#   'exo',
#   'power',
#   'played',
#   'stadium',
#   'the',
#   'song',
#   'amazing',
#   'lit'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['power',
#   'this',
#   'song',
#   'energetic',
#   'really',
#   'suitable',
#   'worldcup',
#   'also',
#   'performed'],
#  ['please', 'play'],
#  ['please', 'play'],
#  ['voted',
#   'exo',
#   'power',
#   'played',
#   'stadium',
#   'the',
#   'song',
#   'amazing',
#   'lit',
#   'en'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['please', 'play', 'we', 'got', 'the', 'power', 'every', 'time', 'http'],
#  ['please', 'play'],
#  ['tub',
#   'haribo',
#   'choice',
#   'simply',
#   'predict',
#   'st',
#   'goalscorer',
#   'tomorrow',
#   'night',
#   'crunch',
#   'last',
#   'tie',
#   'betwee'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['please', 'play'],
#  ['got', 'the', 'new', 'era', 'no', 'billboard', 'japan', 'boost', 'suchmos'],
#  ['when', 'two', 'meme', 'meet'],
#  ['power', 'power'],
#  ['my', 'favorite', 'song'],
#  ['proud',
#   'moment',
#   'lead',
#   'country',
#   'last',
#   'night',
#   'seen',
#   'celebration',
#   'video',
#   'back',
#   'home',
#   'love'],
#  ['po', 'favor'],
#  ['another', 'cheerful', 'colombian', 'celebration'],
#  ['so', 'exci'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['its', 'taking'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark'],
#  ['recommend',
#   'lo',
#   'siento',
#   'by',
#   'super',
#   'junior',
#   'ft',
#   'leslie',
#   'grace',
#   'playnskillz',
#   'its',
#   'nice',
#   'trilingual',
#   'song',
#   'english',
#   'spanish'],
#  ['choose'],
#  [],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'arsenal',
#   'hopeful',
#   'agreement',
#   'sampdoria',
#   'torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['your', 'mother', 'come', 'first', 'chat', 'jesus'],
#  ['exo', 'power', 'vamos', 'please', 'play'],
#  ['recommend', 'go', 'higher', 'its', 'perfect', 'song', 'energize', 'player'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['please',
#   'play',
#   'power',
#   'its',
#   'bop',
#   'plus',
#   'hope',
#   'empowerment',
#   'thanks',
#   'much'],
#  ['found', 'the', 'video', 'hahaha', 'play', 'blackpink', 'forever', 'young'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['fake', 'love'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['knockout',
#   'bracket',
#   'sadly',
#   'germany',
#   'the',
#   'joachim',
#   'w',
#   'hailing',
#   'cab',
#   'meme',
#   'going',
#   'waste',
#   'still',
#   'laughing',
#   'germany',
#   'manager',
#   'coach',
#   'always',
#   'look',
#   'like',
#   'aging',
#   'beatle',
#   'trying',
#   'hail',
#   'cab'],
#  ['mic', 'drop', 'ft'],
#  ['exo', 'power', 'everyone', 'happy', 'hear'],
#  ['you',
#   'know',
#   'ronaldo',
#   'you',
#   'know',
#   'messi',
#   'you',
#   'know',
#   'neymar',
#   'do',
#   'know',
#   'scored',
#   'goal',
#   'got',
#   'paid',
#   'much',
#   'much',
#   'le',
#   'abby',
#   'wam'],
#  ['qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['conclusion',
#   'power',
#   'fit',
#   'perfectly',
#   'energy',
#   'championship',
#   'world',
#   'cup',
#   'we',
#   'got',
#   'power'],
#  ['so',
#   'going',
#   'semi',
#   'final',
#   'brazil',
#   'belgium',
#   'sol',
#   'campbell',
#   'think',
#   'france'],
#  ['airplane', 'pt', 'bts', 'thankyou'],
#  ['female',
#   'reporter',
#   'faced',
#   'sexism',
#   'sport',
#   'decade',
#   'year',
#   'speaking'],
#  ['power', 'exo'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['as', 'say', 'football', 'anything', 'happen'],
#  ['got', 'the', 'new', 'era', 'no', 'billboard', 'japan', 'boost', 'suchmos'],
#  ['recommend',
#   'lo',
#   'siento',
#   'by',
#   'super',
#   'junior',
#   'ft',
#   'leslie',
#   'grace',
#   'playnskillz',
#   'its',
#   'nice',
#   'trilingual',
#   'song',
#   'english',
#   'spanish'],
#  ['you',
#   'still',
#   'participate',
#   'competition',
#   'what',
#   'waiting',
#   'win',
#   'valuable',
#   'electronic'],
#  ['exo', 'power', 'please', 'play'],
#  ['huge', 'day', 'group', 'team', 'news'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['just',
#   'reminder',
#   'game',
#   'today',
#   'air',
#   'bud',
#   'world',
#   'pup',
#   'netflix'],
#  ['power'],
#  ['my', 'postcard', 'jennifer', 'salke', 'future', 's', 'would', 'tell'],
#  ['because', 'we', 'got', 'that', 'power', 'power'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['last',
#   'day',
#   'round',
#   'one',
#   'make',
#   'pick',
#   'round',
#   'start',
#   'earning',
#   'mvu'],
#  ['iceland', 'head', 'coach', 'day', 'elimination', 'reddit'],
#  ['o', 'e', 'p', 'w', 'r', 'o', 'e', 'exo'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['retweet', 'think', 'cristiano', 'ronaldo', 'score', 'uruguay'],
#  ['power'],
#  ['power', 'exo', 'its', 'suitable', 'worldcup', 'think'],
#  ['no',
#   'fixture',
#   'today',
#   'gif',
#   'help',
#   'pas',
#   'time',
#   'tournament',
#   'resume'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['the', 'senegal', 'defender', 'watching', 'colombia', 'score'],
#  ['mexico', 'fan', 'going', 'security', 'russia', 'wait'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['vamos', 'exo', 'rt', 'rt', 'please', 'play'],
#  ['exo', 'olympics', 'exo', 'nations', 'pick', 'power'],
#  ['theres',
#   'smallest',
#   'nation',
#   'ever',
#   'qualify',
#   'its',
#   'also',
#   'global',
#   'lead'],
#  ['power'],
#  ['please', 'play'],
#  ['hugo',
#   'lloris',
#   'france',
#   'we',
#   'studied',
#   'argeninas',
#   'group',
#   'game',
#   'give',
#   'u',
#   'indication',
#   'know',
#   'player',
#   'like',
#   'messi',
#   'step',
#   'level',
#   'decide',
#   'fate',
#   'match',
#   'doe',
#   'argentina',
#   'barcelona'],
#  ['airplane', 'pt', 'bts', 'thankyou'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['exo',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'played',
#   'do',
#   'politely',
#   'mention',
#   'abou'],
#  ['probable', 'line'],
#  ['if',
#   'read',
#   'one',
#   'germany',
#   'world',
#   'cup',
#   'post',
#   'mortem',
#   'make',
#   'one'],
#  ['never',
#   'when',
#   'man',
#   'tried',
#   'kiss',
#   'wa',
#   'reporting',
#   'brazilian',
#   'journalist',
#   'foug'],
#  ['can',
#   'predict',
#   'result',
#   'who',
#   'score',
#   'first',
#   'face',
#   'how',
#   'finish',
#   'join'],
#  ['japanese',
#   'cartoonist',
#   'latest',
#   'cartoon',
#   'show',
#   'team',
#   'left',
#   'group',
#   'stage'],
#  ['power',
#   'exo',
#   'suitable',
#   'energetic',
#   'song',
#   'played',
#   'world',
#   'cup',
#   'believe',
#   'people'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['everything', 'point', 'win', 'tomorrow', 'mad', 'think'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['with',
#   'knockout',
#   'round',
#   'bracket',
#   'set',
#   'take',
#   'look',
#   'spi',
#   'chance',
#   'advance',
#   'round',
#   'win',
#   'fr'],
#  ['eggs',
#   'thrown',
#   'korean',
#   'national',
#   'team',
#   'defeating',
#   'germany',
#   'spurs',
#   'forward',
#   'son',
#   'heung'],
#  ['got', 'the', 'new', 'era', 'no', 'billboard', 'japan', 'boost', 'suchmos'],
#  ['when', 'almost', 'made', 'whole', 'day', 'action'],
#  ['please', 'play'],
#  ['types', 'of', 'people', 'watching', 'the', 'world', 'cup', 'full', 'vid'],
#  ['exo', 'power', 'please', 'play', 'http'],
#  ['power'],
#  ['it', 'really', 'global', 'game', 'where', 'watching'],
#  ['entrenamiento',
#   'previo',
#   'al',
#   'partido',
#   'de',
#   'octavo',
#   'de',
#   'final',
#   'v',
#   'last',
#   'training',
#   'session',
#   'next',
#   'rou'],
#  ['who',
#   'facing',
#   'last',
#   'one',
#   'side',
#   'draw',
#   'loaded',
#   'former',
#   'winner',
#   'http'],
#  ['exo', 'power', 'please', 'play', 'htt'],
#  ['fake', 'love', 'airplane', 'pt'],
#  ['please', 'play'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['airplane', 'pt', 'bts', 'thankyou'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'the',
#   'song',
#   'the',
#   'power',
#   'music',
#   'brings',
#   'people',
#   'together',
#   'together'],
#  ['please', 'play'],
#  ['power'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['power',
#   'exo',
#   'song',
#   'fifa',
#   'its',
#   'going',
#   'turn',
#   'mood',
#   'even',
#   'will',
#   'bring',
#   'festive',
#   'atmosphere'],
#  ['fake', 'love'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['matchday',
#   'round',
#   'tsn',
#   'et',
#   'international',
#   'played',
#   'juventus',
#   'international',
#   'played',
#   'juventus',
#   'good',
#   'luck'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['my', 'favorite', 'song'],
#  ['internet', 'beautiful', 'place'],
#  ['breaking',
#   'diego',
#   'maradona',
#   'longer',
#   'paid',
#   'fifa',
#   'ambassador',
#   'embarrassing',
#   'provocotive',
#   'behaviour'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['global',
#   'festival',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheering',
#   'thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['please', 'play'],
#  ['last', 'fixtures', 'saturday', 'v', 'v', 'sunday', 'v', 'v'],
#  ['these',
#   'brazil',
#   'fan',
#   'funeral',
#   'procession',
#   'street',
#   'germany',
#   'got',
#   'knocked'],
#  ['power', 'would', 'great', 'choice'],
#  ['o', 'e', 'p', 'w', 'r', 'o', 'e', 'exo'],
#  ['most',
#   'chance',
#   'created',
#   'group',
#   'stage',
#   'neymar',
#   'joshua',
#   'kimmich',
#   'mesut',
#   'zil',
#   'salman',
#   'al',
#   'faraj'],
#  ['growl', 'please', 'play'],
#  ['just',
#   'reminder',
#   'game',
#   'today',
#   'air',
#   'bud',
#   'world',
#   'pup',
#   'netflix'],
#  ['our',
#   'fashion',
#   'art',
#   'icon',
#   'week',
#   'the',
#   'tool',
#   'fest',
#   'go',
#   'curated'],
#  ['power', 'please', 'play'],
#  ['as',
#   'group',
#   'stage',
#   'end',
#   'say',
#   'farewell',
#   'team',
#   'year',
#   'fifa',
#   'thanks',
#   'memory'],
#  ['please', 'play', 'such', 'great', 'song', 'cheer', 'everyone'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['coutinho', 'training', 'brazil', 'friday', 'getty'],
#  ['iconic', 'celebration', 'far', 'who'],
#  ['power',
#   'exo',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please'],
#  ['good', 'luck'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['rt', 'comment', 'please', 'play'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['power'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'wa',
#   'performed',
#   'olympic',
#   'wa',
#   'first',
#   'song',
#   'played',
#   'th'],
#  ['new',
#   'pod',
#   'we',
#   'joined',
#   'preview',
#   'look',
#   'wildly',
#   'entertaining',
#   'round'],
#  ['zhou', 'mi', 'weibo', 'update', 'as', 'football', 'fan', 'miss', 'shirt'],
#  ['found', 'the', 'video', 'hahaha', 'play', 'blackpink', 'forever', 'young'],
#  ['the', 'lack', 'match', 'today'],
#  ['its',
#   'time',
#   'give',
#   'superior',
#   'song',
#   'recognition',
#   'deserves',
#   'request',
#   'nct',
#   'dreams',
#   'trigger',
#   'the',
#   'fever'],
#  ['voted',
#   'exo',
#   'power',
#   'played',
#   'stadium',
#   'the',
#   'song',
#   'amazing',
#   'lit',
#   'energ'],
#  ['oasis', 'champagne', 'supernova', 'kid', 'cudi'],
#  ['exos',
#   'energetic',
#   'song',
#   'power',
#   'would',
#   'suitable',
#   'played',
#   'the',
#   'song',
#   'performed',
#   'closin'],
#  ['fake', 'love'],
#  ['please', 'play'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['my', 'favorite', 'song'],
#  ['power'],
#  ['wait'],
#  ['my', 'favorite', 'song'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark'],
#  ['nigeria',
#   'most',
#   'take',
#   'ons',
#   'completed',
#   'most',
#   'foul',
#   'most',
#   'shot',
#   'joint'],
#  ['rihanna',
#   'this',
#   'is',
#   'what',
#   'you',
#   'came',
#   'for',
#   'taylor',
#   'swift',
#   'ready',
#   'for',
#   'it'],
#  ['qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['exo', 'power', 'perfect', 'song', 'plea', 'give', 'try'],
#  ['waking', 'morning', 'realizing', 'game', 'today'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['something', 'soothing', 'kit', 'image'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['cameraman', 'fc', 'ha', 'real', 'mvp', 'far'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['please', 'play', 'thankyou', 'so', 'much'],
#  ['looking',
#   'entertainment',
#   'first',
#   'rest',
#   'day',
#   'you',
#   'safe',
#   'hand',
#   'exhibition'],
#  ['voted',
#   'exo',
#   'power',
#   'played',
#   'stadium',
#   'the',
#   'song',
#   'amazing',
#   'lit',
#   'energ'],
#  ['voten', 'por', 'power', 'de', 'exo', 'please', 'play'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'arsenal',
#   'hopeful',
#   'agreement',
#   'sampdoria',
#   'torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['this',
#   'common',
#   'people',
#   'different',
#   'country',
#   'culture',
#   'bond',
#   'good'],
#  ['exo',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'played',
#   'do',
#   'politely',
#   'mention',
#   'abou'],
#  ['global',
#   'festival',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheering',
#   'thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['colombian',
#   'man',
#   'help',
#   'deaf',
#   'blind',
#   'friend',
#   'experience',
#   'joy',
#   'team',
#   'campaign'],
#  ['power', 'de', 'exo', 'please', 'play'],
#  ['i',
#   'picked',
#   'argentina',
#   'win',
#   'play',
#   'world',
#   'cup',
#   'knockout',
#   'bracket',
#   'chance',
#   'win',
#   'cash',
#   'prize'],
#  ['we', 'know', 'guy', 'rooting', 'tomorrow'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'olympics',
#   'power',
#   'coming',
#   'challenge'],
#  ['would',
#   'believe',
#   'mexico',
#   'got',
#   'top',
#   'bts',
#   'rose',
#   'spot',
#   'mexican',
#   'itunes',
#   'lmao',
#   'ya',
#   'hype',
#   'real'],
#  ['when', 'realise', 'game', 'today'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['bts',
#   'obviusly',
#   'these',
#   'songs',
#   'fake',
#   'love',
#   'its',
#   'beloved',
#   'song',
#   'literally',
#   'perfect',
#   'and',
#   'co'],
#  ['top',
#   'goalscorers',
#   'by',
#   'league',
#   'la',
#   'liga',
#   'premier',
#   'league',
#   'bundesliga',
#   'ligue'],
#  ['this', 'absolutely', 'got', 'what', 'man'],
#  ['exo', 'power', 'please', 'got', 'power', 'power'],
#  ['exol',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'exo',
#   'power',
#   'favourite',
#   'song',
#   'it',
#   'could',
#   'played',
#   'stadi'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['airplane', 'pt'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'arsenal',
#   'hopeful',
#   'agreement',
#   'sampdoria',
#   'torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['exo', 'power'],
#  ['please', 'play'],
#  ['back', 'future'],
#  ['england',
#   'vs',
#   'england',
#   'one',
#   'reflection',
#   'england',
#   'still',
#   'identity',
#   'representatives',
#   'english'],
#  ['the', 'round'],
#  ['face', 'tuesday', 'last', 'stadium', 'what', 'prediction'],
#  ['my', 'favourite'],
#  ['we', 'twelve', 'madridistas', 'involved', 'last', 'find'],
#  ['it', 'really', 'global', 'game', 'where', 'watching'],
#  ['fake', 'love', 'bts', 'airplane', 'pt', 'bts'],
#  ['fever', 'warm', 'today', 'via'],
#  ['exos',
#   'energetic',
#   'song',
#   'power',
#   'would',
#   'suitable',
#   'played',
#   'the',
#   'song',
#   'performed',
#   'closin'],
#  ['news', 'game', 'congrats', 'yoshi'],
#  ['global',
#   'festival',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheering',
#   'thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['exo', 'olympics', 'exo', 'nations', 'pick', 'power'],
#  ['here',
#   'link',
#   'performance',
#   'olympic',
#   'acc',
#   'still',
#   'loving',
#   'nation',
#   'pick'],
#  ['fake', 'love', 'amazing'],
#  ['no', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['symphonic', 'narcotix', 'artists', 'prod', 'mixed', 'mastered'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['power', 'de', 'exo', 'please', 'play'],
#  ['best',
#   'moment',
#   'you',
#   'rank',
#   'world',
#   'cup',
#   'moments',
#   'everything',
#   'matters'],
#  ['hi',
#   'favorite',
#   'song',
#   'fake',
#   'love',
#   'also',
#   'latin',
#   'inspired',
#   'one',
#   'called',
#   'airplane',
#   'pt'],
#  ['when', 'almost', 'made', 'whole', 'day', 'action'],
#  ['pre',
#   'tournament',
#   'predicted',
#   'germany',
#   'win',
#   'gone',
#   'well',
#   'so',
#   'giving',
#   'another',
#   'go'],
#  ['get',
#   'enough',
#   'fifa',
#   'right',
#   'like',
#   'retweet',
#   'subscribe',
#   'match',
#   'day',
#   'programme'],
#  ['please', 'play'],
#  ['please', 'play'],
#  ['found', 'the', 'video', 'hahaha', 'play', 'blackpink', 'forever', 'young'],
#  ['please', 'play'],
#  ['inappropriate', 'korea', 'joke'],
#  ['land',
#   'transaction',
#   'approval',
#   'transferring',
#   'responsibility',
#   'regulation',
#   'like',
#   'pause',
#   'breathing',
#   'no',
#   'wonder'],
#  ['power',
#   'exo',
#   'suitable',
#   'energetic',
#   'song',
#   'played',
#   'world',
#   'cup',
#   'believe',
#   'people'],
#  ['exo', 'power', 'best', 'song', 'sounded', 'olympics', 'game', 'dubai'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['mexican',
#   'pop',
#   'fan',
#   'celebrated',
#   'south',
#   'koreas',
#   'win',
#   'way',
#   'mass',
#   'streaming',
#   'hit',
#   'single',
#   'fake'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['fake', 'love', 'amazing'],
#  ['good', 'song', 'rhythm', 'burn', 'spirit'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['the', 'senegal', 'defender', 'watching', 'colombia', 'score'],
#  ['the', 'round'],
#  ['new', 'funny', 'fortnite', 'clip'],
#  ['airplane',
#   'pt',
#   'bts',
#   'its',
#   'great',
#   'song',
#   'dance',
#   'latin',
#   'people',
#   'would',
#   'enjoy'],
#  ['charging', 'the', 'world', 'wait', 'leo', 'messi', 'tomorrow'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['please', 'play'],
#  ['recommend', 'go', 'higher', 'its', 'perfect', 'song', 'energize', 'player'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['hi',
#   'favorite',
#   'song',
#   'fake',
#   'love',
#   'also',
#   'latin',
#   'inspired',
#   'one',
#   'called',
#   'airplane',
#   'pt'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['exo',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'played',
#   'do',
#   'politely',
#   'mention',
#   'abou'],
#  ['please', 'play'],
#  ['prediction', 'noble', 'quran', 'modern', 'means', 'transport', 'chat'],
#  ['probable', 'line'],
#  ['exol',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'exo',
#   'power',
#   'favourite',
#   'song',
#   'it',
#   'could',
#   'played',
#   'stadi'],
#  ['there', 'big', 'clash', 'look', 'forward', 'round', 'are', 'shock'],
#  ['please', 'play'],
#  ['got', 'the', 'new', 'era', 'no', 'billboard', 'japan', 'boost', 'suchmos'],
#  ['please', 'play'],
#  ['the',
#   'last',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia',
#   'argentina',
#   'sweden'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'arsenal',
#   'hopeful',
#   'agreement',
#   'sampdoria',
#   'torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['please',
#   'play',
#   'this',
#   'song',
#   'energetic',
#   'amd',
#   'powerfull',
#   'fit',
#   'perfectly',
#   'wit'],
#  ['on',
#   'june',
#   'pm',
#   'victory',
#   'museum',
#   'invite',
#   'football',
#   'fan',
#   'visit',
#   'open',
#   'air',
#   'exposition',
#   'militar'],
#  ['best', 'prom', 'table', 'plan', 'ever', 'thank', 'ms', 'cuddy'],
#  ['power', 'nations', 'pick'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['jesse',
#   'lingards',
#   'curler',
#   'one',
#   'great',
#   'goal',
#   'year',
#   'fifa',
#   'do',
#   'agree',
#   'watch',
#   'engla'],
#  ['it', 'really', 'global', 'game', 'where', 'watching'],
#  ['the', 'best', 'fan'],
#  ['my', 'favorite', 'song'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['fake', 'love'],
#  ['catch',
#   'featuring',
#   'three',
#   'current',
#   'reds',
#   'winner',
#   'former',
#   'player'],
#  ['city',
#   'country',
#   'named',
#   'airplaine',
#   'part',
#   'participating',
#   'worldcup',
#   'london',
#   'paris',
#   'tokyo',
#   'mexico',
#   'city',
#   'brazil',
#   'all',
#   'these',
#   'country'],
#  ['exol',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'exo',
#   'power',
#   'favourite',
#   'song',
#   'it',
#   'could',
#   'played',
#   'stadi'],
#  ['its', 'never', 'england'],
#  ['please', 'play'],
#  ['exo', 'power'],
#  ['as',
#   'group',
#   'stage',
#   'end',
#   'say',
#   'farewell',
#   'team',
#   'year',
#   'fifa',
#   'thanks',
#   'memory'],
#  ['the',
#   'eca',
#   'campaign',
#   'ha',
#   'launched',
#   'accelerate',
#   'mass',
#   'adoption',
#   'goi'],
#  ['who', 'going', 'win'],
#  ['fun',
#   'fact',
#   'at',
#   'least',
#   'national',
#   'team',
#   'arrived',
#   'style',
#   'fifa',
#   'check'],
#  ['diego',
#   'maradona',
#   'longer',
#   'paid',
#   'fifa',
#   'ambassador',
#   'embarrassing',
#   'provocotive',
#   'behaviour'],
#  ['fake', 'love', 'amazing'],
#  ['transformer', 'please', 'play'],
#  ['my', 'postcard', 'jennifer', 'salke', 'future', 's', 'would', 'tell'],
#  ['the',
#   'last',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia',
#   'argentina',
#   'sweden'],
#  ['anyone',
#   'else',
#   'woke',
#   'catch',
#   'match',
#   'realize',
#   'wa',
#   'one',
#   'today',
#   'even',
#   'need',
#   'alarm'],
#  ['diego',
#   'maradona',
#   'longer',
#   'paid',
#   'fifa',
#   'ambassador',
#   'embarrassing',
#   'provocotive',
#   'behaviour'],
#  ['what',
#   'amazing',
#   'setting',
#   'game',
#   'football',
#   'young',
#   'russian',
#   'footballer',
#   'took',
#   'part',
#   'exhibition',
#   'match',
#   'moscows',
#   'fo'],
#  ['ready', 'knockout'],
#  ['round', 'predictions', 'including', 'v', 'via'],
#  ['no', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['we', 'know', 'guy', 'rooting', 'tomorrow'],
#  ['please', 'play'],
#  ['the',
#   'true',
#   'story',
#   'world',
#   'greatest',
#   'ronaldo',
#   'available',
#   'itunes'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'nation',
#   'pick',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit'],
#  ['pablo',
#   'zabaleta',
#   'belief',
#   'its',
#   'last',
#   'chance',
#   'many',
#   'star',
#   'player',
#   'win'],
#  ['exo',
#   'ls',
#   'this',
#   'would',
#   'honour',
#   'exo',
#   'know',
#   'power',
#   'motivates',
#   'athlete',
#   'send',
#   'request',
#   'power',
#   'tag'],
#  ['when', 'wake', 'watch'],
#  ['power', 'ultimate', 'song', 'give', 'energy', 'soccer', 'player'],
#  ['disappointed', 'hopefully', 'beat', 'get', 'semis'],
#  ['rt', 'comment', 'please', 'play'],
#  ['france', 'vs', 'argentina', 'who', 'win'],
#  ['please', 'play'],
#  ['qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['the', 'round'],
#  ['wait'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['power', 'exo'],
#  ['tomorrow', 'nice'],
#  ['the',
#   'best',
#   'xi',
#   'group',
#   'stage',
#   'play',
#   'includes',
#   'real',
#   'madrid',
#   'teammate',
#   'modric',
#   'ronaldo',
#   'isco',
#   'along',
#   'harry',
#   'kane',
#   'no',
#   'messi'],
#  ['we',
#   'heard',
#   'feedback',
#   'improved',
#   'world',
#   'cup',
#   'squad',
#   'thanks',
#   'everyone'],
#  ['it', 'ha', 'too', 'long', 'since', 'match'],
#  ['please', 'play'],
#  ['win', 'wnrs'],
#  ['watch',
#   'root',
#   'everything',
#   'else',
#   'need',
#   'know',
#   'the',
#   'game',
#   'start',
#   'saturday',
#   'morning'],
#  ['you',
#   'play',
#   'wa',
#   'performed',
#   'olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['check', 'latest', 'talking', 'el', 'tri', 'preview', 'v'],
#  ['we',
#   'would',
#   'recomended',
#   'play',
#   'exo',
#   'power',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'choosen'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['that', 'goal', 'celebration'],
#  ['please', 'play'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['are'],
#  ['voted',
#   'exo',
#   'power',
#   'played',
#   'stadium',
#   'the',
#   'song',
#   'amazing',
#   'lit',
#   'energ'],
#  ['and', 'last', 'draw', 'full', 'th', 'june', 'pm', 'pm', 'st', 'july', 'pm'],
#  ['power'],
#  ['are', 'excited', 'match', 'later', 'we', 'adidas', 'starlancer'],
#  ['exol',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'exo',
#   'power',
#   'favourite',
#   'song',
#   'it',
#   'could',
#   'played',
#   'stadi'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['black', 'pink', 'twice'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['exo',
#   'ls',
#   'this',
#   'would',
#   'honour',
#   'exo',
#   'know',
#   'power',
#   'motivates',
#   'athlete',
#   'send',
#   'request',
#   'power',
#   'tag'],
#  ['power', 'de', 'exo', 'please', 'play', 'http'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['power', 'exo', 'please', 'like', 'much'],
#  ['want',
#   'spirit',
#   'energy',
#   'right',
#   'recomend',
#   'power',
#   'exo',
#   'song',
#   'actually',
#   'burn',
#   'spirit'],
#  ['exo',
#   'ls',
#   'this',
#   'would',
#   'honour',
#   'exo',
#   'know',
#   'power',
#   'motivates',
#   'athlete',
#   'send',
#   'request',
#   'power',
#   'tag'],
#  ['fun',
#   'fact',
#   'at',
#   'least',
#   'national',
#   'team',
#   'arrived',
#   'style',
#   'fifa',
#   'check'],
#  ['rt', 'comment', 'please', 'play'],
#  ['how', 'far', 'go'],
#  ['would', 'perfect', 'put', 'power'],
#  ['power'],
#  ['bts',
#   'obviusly',
#   'these',
#   'songs',
#   'fake',
#   'love',
#   'its',
#   'beloved',
#   'song',
#   'literally',
#   'perfect',
#   'and',
#   'co'],
#  ['qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['rt', 'please', 'play'],
#  ['wonder',
#   'much',
#   'time',
#   'spends',
#   'day',
#   'perfecting',
#   'hit',
#   'rolling',
#   'back',
#   'brazil',
#   'roll'],
#  ['power',
#   'perfect',
#   'song',
#   'wa',
#   'played',
#   'winter',
#   'olympic',
#   'closing',
#   'ceremony'],
#  ['breaking',
#   'diego',
#   'maradona',
#   'longer',
#   'paid',
#   'fifa',
#   'ambassador',
#   'embarrassing',
#   'provocotive',
#   'behaviour'],
#  ['airplane', 'pt', 'bts', 'thankyou'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen',
#   'played',
#   'olym'],
#  ['france',
#   'round',
#   'won',
#   'nigeria',
#   'lost',
#   'spain',
#   'won',
#   'paraguay',
#   'aet',
#   'won',
#   'italy',
#   'lost',
#   'austria',
#   'aet'],
#  ['supporting',
#   'my',
#   'french',
#   'team',
#   'tomorrow',
#   'we',
#   'are',
#   'not',
#   'scared',
#   'nut',
#   'fans',
#   'and',
#   'you'],
#  ['power',
#   'exo',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please',
#   'please'],
#  ['please', 'play'],
#  ['de', 'please', 'play'],
#  ['please', 'play'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen',
#   'played',
#   'olym'],
#  ['we',
#   'removing',
#   'german',
#   'category',
#   'pornhub',
#   'following',
#   'humiliating',
#   'elimination'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['power'],
#  ['please', 'play'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'nation',
#   'pick',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit'],
#  ['when',
#   'son',
#   'heungmin',
#   'capped',
#   'famous',
#   'win',
#   'korea',
#   'republic',
#   'reigning',
#   'champion',
#   'german'],
#  ['mexican',
#   'pop',
#   'fan',
#   'celebrated',
#   'south',
#   'koreas',
#   'win',
#   'way',
#   'mass',
#   'streaming',
#   'hit',
#   'single',
#   'fake'],
#  ['qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['our',
#   'thought',
#   'iran',
#   'striker',
#   'sardar',
#   'azmoun',
#   'ha',
#   'retired',
#   'international',
#   'football',
#   'age',
#   'he'],
#  ['exo', 'olympics', 'exo', 'nations', 'pick', 'power'],
#  ['power', 'power'],
#  ['the',
#   'best',
#   'xi',
#   'group',
#   'stage',
#   'play',
#   'includes',
#   'real',
#   'madrid',
#   'teammate',
#   'modric',
#   'ronaldo',
#   'isco',
#   'along',
#   'harry',
#   'kane',
#   'no',
#   'messi',
#   'more'],
#  ['please', 'play'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['please', 'play'],
#  ['so',
#   'please',
#   'play',
#   'power',
#   'stadium',
#   'power',
#   'song',
#   'make',
#   'anyone',
#   'hears',
#   'becomes',
#   'spirit',
#   'exo',
#   'channeled',
#   'passion',
#   'many',
#   'people',
#   'song',
#   'well',
#   'thankyou',
#   'much'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['power'],
#  ['this',
#   'world',
#   'cup',
#   'rest',
#   'day',
#   'causing',
#   'acute',
#   'withdrawal',
#   'symptom'],
#  ['for',
#   'everyone',
#   'missed',
#   'england',
#   'vs',
#   'belgium',
#   'game',
#   'highlight'],
#  ['found', 'the', 'video', 'hahaha', 'play', 'blackpink', 'forever', 'young'],
#  ['the', 'best', 'goal', 'celebration', 'ever'],
#  ['power', 'ultimate', 'song', 'give', 'energy', 'soccer', 'player'],
#  ['the', 'senegal', 'defender', 'watching', 'colombia', 'score'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'nation',
#   'pick',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen',
#   'played',
#   'olympics',
#   'dubai',
#   'fountain'],
#  ['do', 'worry', 'child', 'swedish', 'house', 'mafia'],
#  ['golo', 'kant', 'highest', 'player', 'interception', 'group', 'stage', 'wc'],
#  ['what', 'lie', 'ahead', 'country', 'still', 'report', 'via'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'wa',
#   'performed',
#   'olympic',
#   'wa',
#   'first',
#   'song',
#   'played',
#   'th'],
#  ['power', 'exo'],
#  ['please', 'play'],
#  ['important', 'day', 'leo', 'messi'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['power'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['power',
#   'global',
#   'hit',
#   'song',
#   'ha',
#   'lyric',
#   'fitting',
#   'sport',
#   'event',
#   'giving',
#   'athlet'],
#  ['life',
#   'achieving',
#   'goal',
#   'in',
#   'honor',
#   'check',
#   'new',
#   'track',
#   'fifa',
#   'world',
#   'cup',
#   'russia',
#   'ekaterinburg',
#   'excursions'],
#  ['part',
#   'unfairly',
#   'treated',
#   'need',
#   'get',
#   'back',
#   'get',
#   'full',
#   'backing',
#   'fan',
#   'plz',
#   'like',
#   'retweet'],
#  ['going', 'business', 'morning'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['exo', 'power', 'please', 'got', 'power', 'power'],
#  ['the', 'senegal', 'defender', 'watching', 'colombia', 'score'],
#  ['my', 'favorite', 'song'],
#  ['prediction', 'noble', 'quran', 'modern', 'means', 'transport', 'chat'],
#  ['free', 'beer', 'with', 'every', 'team', 'usa', 'goal', 'hey', 'cruel'],
#  ['bone', 'thugs', 'harmony', 'if', 'could', 'teach', 'the', 'world', 'song'],
#  ['the', 'happening', 'twitter'],
#  ['ranked',
#   'all',
#   'team',
#   'based',
#   'group',
#   'stage',
#   'performance',
#   'the',
#   'group',
#   'stage',
#   'side',
#   'imp'],
#  ['exos',
#   'energetic',
#   'song',
#   'power',
#   'would',
#   'suitable',
#   'played',
#   'the',
#   'song',
#   'performed',
#   'closing',
#   'ceremony',
#   'pyeonchang',
#   'winter',
#   'olympics',
#   'wa',
#   'played',
#   'next',
#   'big',
#   'artist',
#   'song',
#   'dubai',
#   'fountain'],
#  ['malam', 'ni', 'match', 'v'],
#  ['power'],
#  ['transformer', 'please', 'play'],
#  ['entire', 'day', 'action', 'guess', 'watch', 'baseba', 'nooooope', 'fuck'],
#  ['please', 'play'],
#  ['power', 'by', 'exo', 'cuz', 'its', 'amazing'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['please', 'play'],
#  ['the', 'feeling', 'wa', 'game'],
#  ['please', 'play'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['because', 'we', 'got', 'that', 'power', 'power'],
#  ['please', 'play'],
#  ['let', 'game', 'begin'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['please', 'play'],
#  ['please', 'play'],
#  ['power'],
#  ['sleep', 'right', 'side', 'chat'],
#  ['please', 'play'],
#  ['please', 'play'],
#  ['there', 'goal', 'scored', 'th', 'minute', 'later', 'final', 'far', 'this'],
#  ['centurion', 'jesus', 'teaching', 'temple'],
#  ['they',
#   'made',
#   'are',
#   'going',
#   'see',
#   'unexpected',
#   'exit',
#   'round',
#   'will',
#   'score'],
#  ['you',
#   'simply',
#   'scroll',
#   'past',
#   'without',
#   'liking',
#   'cristiano',
#   'ronaldo',
#   'fan'],
#  ['exo',
#   'let',
#   'reply',
#   'tweet',
#   'recommend',
#   'power',
#   'exo',
#   'it',
#   'could',
#   'played',
#   'do',
#   'politely',
#   'mention',
#   'abou'],
#  ['please', 'play'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['no', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['power', 'please', 'play'],
#  ['my', 'favorite', 'song'],
#  ['please', 'play'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['it',
#   'wa',
#   'team',
#   'said',
#   'farewell',
#   'saransk',
#   'kaliningrad',
#   'ekaterinburg',
#   'volgograd',
#   'also',
#   'hosted'],
#  ['you',
#   'play',
#   'wa',
#   'performed',
#   'olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['global',
#   'festival',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheering',
#   'thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['you',
#   'play',
#   'wa',
#   'performed',
#   'olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['trent',
#   'alexander',
#   'arnold',
#   'last',
#   'months',
#   'liverpool',
#   'debut',
#   'pl',
#   'debut',
#   'first',
#   'pl',
#   'goal',
#   'ucl',
#   'debut',
#   'ucl',
#   'debut',
#   'goal',
#   'ucl'],
#  ['an',
#   'energetic',
#   'song',
#   'song',
#   'positive',
#   'vibe',
#   'successful',
#   'song',
#   'deportive',
#   'event',
#   'meaningful',
#   'song'],
#  ['these', 'kid', 'love', 'playing', 'soccer', 'who', 'rooting'],
#  ['luke',
#   'be',
#   'careful',
#   'heart',
#   'weighed',
#   'carousing',
#   'drunkenness',
#   'anxiety',
#   'life'],
#  ['qualified',
#   'group',
#   'stage',
#   'into',
#   'knockout',
#   'full',
#   'focus',
#   'tuesday'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'arsenal',
#   'hopeful',
#   'agreement',
#   'sampdoria',
#   'torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['say', 'take', 'confidence', 'collective', 'experience', 'ahead', 'round'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'arsenal',
#   'hopeful',
#   'agreement',
#   'sampdoria',
#   'torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['rt', 'please', 'play'],
#  ['hope',
#   'solo',
#   'strong',
#   'word',
#   'state',
#   'soccer',
#   'united',
#   'states',
#   'failed',
#   'qualify'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['important', 'day', 'leo', 'messi'],
#  ['please', 'play'],
#  ['power', 'de', 'exo', 'please', 'play'],
#  ['power', 'would', 'great', 'choice'],
#  ['please', 'play'],
#  ['recommend', 'go', 'higher', 'its', 'perfect', 'song', 'energize', 'player'],
#  ['the', 'original', 'countdown', 'ever', 'launch'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['you',
#   'play',
#   'wa',
#   'performed',
#   'olympics',
#   'played',
#   'dubai',
#   'fountain',
#   'show',
#   'well'],
#  ['power', 'de'],
#  ['its', 'taking'],
#  ['guys',
#   'comment',
#   'post',
#   'request',
#   'exos',
#   'power',
#   'played',
#   'fifa',
#   'world',
#   'cup',
#   'please',
#   'also',
#   'use',
#   'officia'],
#  ['please',
#   'play',
#   'power',
#   'nations',
#   'pick',
#   'one',
#   'best',
#   'kpop',
#   'boy',
#   'group',
#   'it',
#   'wa',
#   'already',
#   'played'],
#  ['kindly', 'play', 'exos', 'power', 'fifa', 'world', 'cup'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['please', 'play'],
#  ['please', 'play'],
#  ['can',
#   'predict',
#   'result',
#   'who',
#   'score',
#   'first',
#   'face',
#   'how',
#   'finish',
#   'join'],
#  ['batshuayi', 'arguably', 'funniest', 'moment'],
#  ['we', 'got', 'the', 'pooooower', 'pooooower'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['star', 'reached', 'knockout', 'stage', 'marcos', 'rojo'],
#  ['please', 'play'],
#  ['please', 'play'],
#  ['researchers',
#   'world',
#   'wide',
#   'choose',
#   'li',
#   'cor',
#   'western',
#   'blot',
#   'champion',
#   'will',
#   'team',
#   'world',
#   'cup',
#   'champion',
#   'vote'],
#  ['rt', 'please', 'play'],
# ...
#   'kick',
#   'frie'],
#  ['power', 'de', 'exo', 'please', 'play'],
#  ['please', 'play'],
#  ['please',
#   'play',
#   'power',
#   'its',
#   'bop',
#   'plus',
#   'hope',
#   'empowerment',
#   'thanks',
#   'much'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['please', 'play', 'thankyou', 'so', 'much'],
#  ['please', 'play'],
#  ['the', 'player', 'lit', 'group', 'stage'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['didier',
#   'deschamps',
#   'france',
#   'coach',
#   'messi',
#   'messi',
#   'we',
#   'like',
#   'mark',
#   'neutralize',
#   'know',
#   'well'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['nabbout', 'indebted', 'bert'],
#  ['please', 'play'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['my', 'favorite', 'song'],
#  ['ramsey',
#   'contract',
#   'talk',
#   'ongoing',
#   'arsenal',
#   'hopeful',
#   'agreement',
#   'sampdoria',
#   'torreira',
#   'nothing',
#   'signed',
#   'player'],
#  ['completely',
#   'unchartered',
#   'territory',
#   'english',
#   'men',
#   'woman',
#   'born',
#   'this',
#   'first'],
#  ['got', 'the', 'new', 'era', 'no', 'billboard', 'japan', 'boost', 'suchmos'],
#  ['power', 'de', 'exo', 'please', 'play', 'http'],
#  ['driver',
#   'arrested',
#   'trying',
#   'meet',
#   'underage',
#   'girl',
#   'all',
#   'caught',
#   'camera',
#   'raj',
#   'khan',
#   'age'],
#  ['it', 'ha', 'too', 'long', 'since', 'match'],
#  ['get',
#   'enough',
#   'fifa',
#   'right',
#   'like',
#   'retweet',
#   'subscribe',
#   'match',
#   'day',
#   'programme'],
#  ['sleep', 'right', 'side', 'chat'],
#  ['everything', 'one', 'place'],
#  ['what',
#   'happens',
#   'football',
#   'knowledge',
#   'focus',
#   'wrong',
#   'thing',
#   'business',
#   'football'],
#  ['based',
#   'matchup',
#   'past',
#   'performance',
#   'peak',
#   'potential',
#   'round',
#   'field',
#   'stack',
#   'road'],
#  ['colombia', 'face', 'england', 'next', 'round'],
#  ['rt', 'comment', 'please', 'play'],
#  ['power', 'de', 'exo', 'please', 'play'],
#  ['my', 'postcard', 'jennifer', 'salke', 'future', 's', 'would', 'tell'],
#  ['power', 'by', 'exo', 'cuz', 'its', 'amazing'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['please', 'play', 'power'],
#  ['the',
#   'last',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia',
#   'argentina',
#   'sweden'],
#  ['please', 'play'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['please', 'play'],
#  ['keeping', 'cool', 'brand', 'new', 'city', 'way'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['my', 'favorite', 'song'],
#  ['exo', 'power', 'please', 'play', 'ht'],
#  ['please', 'play'],
#  ['planning',
#   'going',
#   'watch',
#   'world',
#   'cup',
#   'knockout',
#   'round',
#   'game',
#   'la',
#   'this',
#   'city',
#   'wonderful',
#   'another',
#   'shout',
#   'fun',
#   'guide'],
#  ['just', 'another', 'day', 'red', 'square', 'russia'],
#  ['an',
#   'ai',
#   'simulated',
#   'world',
#   'cup',
#   'time',
#   'this',
#   'think',
#   'win',
#   'full',
#   'article',
#   'facebook',
#   'wrohens',
#   'link'],
#  ['most',
#   'take',
#   'ons',
#   'completed',
#   'group',
#   'stage',
#   'lionel',
#   'messi',
#   'neymar',
#   'oghenekaro',
#   'etebo'],
#  ['anime', 'characters', 'v', 'wifi', 'passwords'],
#  ['power', 'de', 'exo', 'e', 'perfecta', 'please', 'play'],
#  ['qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['when',
#   'wedding',
#   'the',
#   'final',
#   'episode',
#   'crazy',
#   'fan',
#   'saga',
#   'ig',
#   'jerofreixas'],
#  ['exo', 'power', 'please', 'play', 'htt'],
#  ['as',
#   'group',
#   'stage',
#   'end',
#   'say',
#   'farewell',
#   'team',
#   'year',
#   'fifa',
#   'thanks',
#   'memory'],
#  ['all', 'need', 'power'],
#  ['when', 'realise', 'game', 'today'],
#  ['can',
#   'predict',
#   'result',
#   'who',
#   'score',
#   'first',
#   'face',
#   'how',
#   'finish',
#   'join'],
#  ['trigger',
#   'the',
#   'fever',
#   'nct',
#   'dream',
#   'please',
#   'bcs',
#   'song',
#   'dedicated',
#   'world',
#   'cup'],
#  ['fire', 'fake', 'love'],
#  ['please', 'play'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['best',
#   'goal',
#   'far',
#   'beautiful',
#   'pas',
#   'perfect',
#   'first',
#   'touch',
#   'out',
#   'world',
#   'second',
#   'touch',
#   'brilli'],
#  ['the',
#   'group',
#   'stages',
#   'games',
#   'goals',
#   'nil',
#   'nil',
#   'draw',
#   'penalties',
#   'own',
#   'goals'],
#  ['please', 'play'],
#  ['exos',
#   'energetic',
#   'song',
#   'power',
#   'would',
#   'suitable',
#   'played',
#   'the',
#   'song',
#   'performed',
#   'closin'],
#  ['please', 'play'],
#  ['olarrrr', 'we', 'want', 'hear', 'fake', 'love', 'play', 'u'],
#  ['as',
#   'group',
#   'stage',
#   'end',
#   'say',
#   'farewell',
#   'team',
#   'year',
#   'fifa',
#   'thanks',
#   'memory'],
#  ['after',
#   'horrendous',
#   'day',
#   'profession',
#   'began',
#   'joy',
#   'please',
#   'watch',
#   'uplifting',
#   'video'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['when', 'almost', 'made', 'whole', 'day', 'action'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['trigger', 'the', 'fever', 'nct', 'dream'],
#  ['please', 'play', 'power', 'exo'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['play', 'power', 'exo'],
#  ['exo', 'power'],
#  ['exo', 'power', 'please', 'play'],
#  ['its', 'taking'],
#  ['rt', 'comment', 'please', 'play'],
#  ['trent',
#   'alexander',
#   'arnold',
#   'last',
#   'months',
#   'liverpool',
#   'debut',
#   'pl',
#   'debut',
#   'first',
#   'pl',
#   'goal',
#   'ucl',
#   'debut',
#   'ucl',
#   'debut',
#   'goal',
#   'ucl'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['airplane', 'pt'],
#  ['no', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['trent',
#   'alexander',
#   'arnold',
#   'last',
#   'months',
#   'liverpool',
#   'debut',
#   'pl',
#   'debut',
#   'first',
#   'pl',
#   'goal',
#   'ucl',
#   'debut',
#   'ucl',
#   'debut',
#   'goal',
#   'ucl'],
#  ['bellanaija', 'japan', 'poland', 'watch', 'highlights'],
#  ['global',
#   'festival',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheering',
#   'thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['bellanaija',
#   'senegal',
#   'journey',
#   'come',
#   'end',
#   'loss',
#   'colombia',
#   'watch',
#   'highlights'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['power'],
#  ['nct', 'dream', 'trigger', 'the', 'fever'],
#  ['say', 'take', 'confidence', 'collective', 'experience', 'ahead', 'round'],
#  ['darling', 'least', 'take', 'something', 'going', 'bed', 'nigerian', 'men'],
#  ['another',
#   'song',
#   'would',
#   'like',
#   'recommend',
#   'hard',
#   'carry',
#   'hard',
#   'carry',
#   'hey',
#   'its',
#   'hype'],
#  ['like', 'rt', 'subscribe', 'digital', 'match', 'day', 'program'],
#  ['good', 'song', 'rhythm', 'burn', 'spirit'],
#  ['coral',
#   'sports',
#   'sat',
#   'th',
#   'june',
#   'uruguay',
#   'portugal',
#   'coral',
#   'offer',
#   'max',
#   'bet',
#   'ronaldo',
#   'score',
#   'new',
#   'customers',
#   'only',
#   'cs',
#   'apply',
#   'gamble',
#   'aware',
#   'claim'],
#  ['all', 'need', 'power'],
#  ['can',
#   'predict',
#   'result',
#   'who',
#   'score',
#   'first',
#   'face',
#   'how',
#   'finish',
#   'join'],
#  ['exol',
#   'please',
#   'reply',
#   'quoted',
#   'tweet',
#   'requesting',
#   'exo',
#   'power',
#   'favourite',
#   'song',
#   'it',
#   'could',
#   'played',
#   'stadi'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['when', 'realise', 'game', 'today'],
#  ['the', 'energy', 'use', 'redirected', 'warming', 'tv'],
#  ['an',
#   'estimated',
#   'million',
#   'pint',
#   'poured',
#   'uk',
#   'last',
#   'night',
#   'just',
#   'imagine',
#   'win',
#   'bloody',
#   'thing'],
#  ['o', 'e', 'p', 'w', 'r', 'o', 'e', 'exo'],
#  ['power',
#   'exo',
#   'song',
#   'fifa',
#   'its',
#   'going',
#   'turn',
#   'mood',
#   'even',
#   'will',
#   'bring',
#   'festive',
#   'atmosphere'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'wa',
#   'performed',
#   'olympic',
#   'wa',
#   'first',
#   'song',
#   'played',
#   'th'],
#  ['please', 'play'],
#  ['queroooooooo', 'we', 'want', 'hear', 'fake', 'love', 'play', 'u'],
#  ['good', 'morning'],
#  ['retweeted',
#   'weight',
#   'watchers',
#   'ready',
#   'big',
#   'game',
#   'tonight',
#   'england',
#   'vs',
#   'belgium',
#   'in',
#   'battle',
#   'dessert',
#   'would',
#   'pick',
#   'find',
#   'recipe'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['we',
#   'would',
#   'recommend',
#   'play',
#   'exo',
#   'power',
#   'it',
#   'energetic',
#   'song',
#   'suit',
#   'it',
#   'wa',
#   'chosen'],
#  ['please', 'play'],
#  ['they',
#   'keisuke',
#   'honda',
#   'becomes',
#   'th',
#   'ever',
#   'asian',
#   'player',
#   'score',
#   'world',
#   'cup',
#   'competiti'],
#  ['thank', 'everything', 'south', 'korea'],
#  ['the',
#   'world',
#   'football',
#   'phone',
#   'back',
#   'knockout',
#   'special',
#   'joining',
#   'legendinho',
#   'northern',
#   'seoul',
#   'world',
#   'football',
#   'fan',
#   'how',
#   'cope',
#   'day',
#   'game'],
#  ['ready',
#   'big',
#   'game',
#   'tonight',
#   'england',
#   'vs',
#   'belgium',
#   'in',
#   'battle',
#   'dessert',
#   'would',
#   'pick',
#   'find',
#   'reci'],
#  ['power'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['points',
#   'gd',
#   'scored',
#   'head',
#   'head',
#   'yellow',
#   'card',
#   'for',
#   'first',
#   'time',
#   'ever',
#   'team',
#   'ha',
#   'kno'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['most',
#   'take',
#   'ons',
#   'completed',
#   'group',
#   'stage',
#   'lionel',
#   'messi',
#   'neymar',
#   'oghenekaro',
#   'etebo'],
#  ['mart',
#   'nez',
#   'fully',
#   'fit',
#   'he',
#   'completed',
#   'training',
#   'session',
#   'today'],
#  ['it', 'really', 'global', 'game', 'where', 'watching'],
#  ['qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['did', 'someone', 'say', 'football', 'wait', 'tomorrow'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['exos',
#   'energetic',
#   'song',
#   'power',
#   'would',
#   'suitable',
#   'played',
#   'the',
#   'song',
#   'performed',
#   'closin'],
#  ['resilience',
#   'give',
#   'strength',
#   'keep',
#   'moving',
#   'forward',
#   'caught',
#   'rain',
#   'storm',
#   'keep',
#   'continuin'],
#  ['star', 'reached', 'knockout', 'stage', 'marcos', 'rojo'],
#  ['the', 'senegal', 'defender', 'watching', 'colombia', 'score'],
#  ['breaking', 'trumps', 'epic', 'world', 'cup', 'speech'],
#  ['charging', 'the', 'world', 'wait', 'leo', 'messi', 'tomorrow'],
#  ['please', 'play'],
#  ['retweet',
#   'country',
#   'still',
#   'russia',
#   'uruguay',
#   'spain',
#   'portugal',
#   'france',
#   'denmark',
#   'croatia'],
#  ['think', 'would', 'amazing', 'song', 'world', 'cup'],
#  ['here', 'pick', 'world', 'cup', 'squad', 'operator', 'would', 'sub', 'http'],
#  ['as',
#   'group',
#   'stage',
#   'end',
#   'say',
#   'farewell',
#   'team',
#   'year',
#   'fifa',
#   'thanks',
#   'memory'],
#  ['fake', 'love', 'bts', 'best', 'best'],
#  ['colombian',
#   'man',
#   'help',
#   'deaf',
#   'blind',
#   'friend',
#   'experience',
#   'joy',
#   'team',
#   'campaign',
#   'read'],
#  ['please', 'play'],
#  ['fire', 'fake', 'love'],
#  ['top',
#   'goalscorers',
#   'by',
#   'league',
#   'la',
#   'liga',
#   'premier',
#   'league',
#   'bundesliga'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['heres', 'group', 'finished', 'meaning', 'play', 'play', 'next', 'round'],
#  ['just',
#   'wrote',
#   'first',
#   'piece',
#   'its',
#   'racist',
#   'slanted',
#   'eye',
#   'gesture',
#   'keep',
#   'appearing'],
#  ['no', 'game', 'today', 'got', 'u', 'feeling', 'like'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['global',
#   'festival',
#   'seoul',
#   'russia',
#   'world',
#   'cup',
#   'street',
#   'cheering',
#   'thanks',
#   'foreign',
#   'supporter',
#   'different',
#   'co'],
#  ['so', 'exci'],
#  ['the',
#   'song',
#   'playing',
#   'biggest',
#   'fountain',
#   'dubai',
#   'song',
#   'passionate',
#   'unique',
#   'we',
#   'got'],
#  ['please', 'play'],
#  ['please', 'play'],
#  ['power', 'exo'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['kylian',
#   'mbapp',
#   'donate',
#   'everything',
#   'earns',
#   'charity',
#   'this',
#   'add',
#   'per',
#   'game'],
#  ['please', 'play'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['power'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['we', 'twelve', 'madridistas', 'involved', 'last', 'find'],
#  ['having',
#   'leave',
#   'world',
#   'cup',
#   'already',
#   'group',
#   'stage',
#   'hurt',
#   'much',
#   'we',
#   'good',
#   'enough',
#   'need'],
#  ['qatars',
#   'lawyer',
#   'tried',
#   'desperation',
#   'move',
#   'keep',
#   'secret',
#   'communication',
#   'fe'],
#  ['its',
#   'time',
#   'give',
#   'superior',
#   'song',
#   'recognition',
#   'deserves',
#   'request',
#   'nct',
#   'dreams',
#   'trigger',
#   'the',
#   'fever'],
#  ['photo', 'renaissance', 'art', 'can', 'get', 'ruling'],
#  ['o', 'e', 'p', 'w', 'r', 'o', 'e', 'exo'],
#  ['got',
#   'favourite',
#   'tune',
#   'tell',
#   'u',
#   'choice',
#   'could',
#   'played',
#   'stadium'],
#  ['please',
#   'play',
#   'power',
#   'exo',
#   'exo',
#   'also',
#   'performed',
#   'closing',
#   'ceremony',
#   'winter',
#   'olympics',
#   'the',
#   'song'],
#  ['espn', 'lionel', 'messi', 'first', 'player', 'score', 'goal', 'teen'],
#  ['today', 'anniversary', 'upset', 'england', 'heres', 'retrospective', 'lat'],
#  ['please', 'play'],
#  ['bts',
#   'obviusly',
#   'these',
#   'songs',
#   'fake',
#   'love',
#   'its',
#   'beloved',
#   'song',
#   'literally',
#   'perfect',
#   'and',
#   'co'],
#  ['please', 'play'],
#  ['exo', 'power'],
#  ['all', 'team', 'given', 'score', 'what', 'would', 'give'],
#  ['power', 'de', 'exo', 'please', 'play', 'http'],
#  ['power',
#   'global',
#   'hit',
#   'song',
#   'ha',
#   'lyric',
#   'fitting',
#   'sport',
#   'event',
#   'giving',
#   'athlet'],
#  ['please', 'play'],
#  ['kylian',
#   'mbapp',
#   'donate',
#   'everything',
#   'earns',
#   'charity',
#   'this',
#   'add',
#   'per',
#   'game'],
#  ['icymi',
#   'some',
#   'musing',
#   'day',
#   'perfect',
#   'group',
#   'stage',
#   'doe',
#   'aways',
#   'mean',
#   'championship',
#   'http'],
#  ['messi', 'get', 'face', 'saving', 'kazan', 'mural', 'match', 'ronaldos'],
#  ['rt', 'comment', 'please', 'play'],
#  ['please', 'play', 'power', 'exo', 'thanks'],
#  ...]

# %%
df['Tweet_Proc'] = tweets_preproc
df
# Out:
#                                                     Tweet  weight  \
# 0       Want to make this summer football that little ...     543
# 1       Didier Deschamps has confirmed Benjamin Mendy ...      23
# 2       Please play Power by EXO EXO also performed du...    1300
# 3       weeks teams games goals The group stage was ev...    1259
# 4       Please play Power by EXO EXO also performed du...    1300
# ...                                                   ...     ...
# 529995  Please guys please please help me ouuttt Pleas...      87
# 529996  Dear France Congratulations on winning the of ...   96217
# 529997                 France have won the FIFA in Moscow   63116
# 529998  Islamophobia Xenophobia and racism are global ...       1
# 529999          The first player to find the net in final    3228
#
#                                                    HTs  \
# 0                                  ['Win', 'WorldCup']
# 1                                       ['FRA', 'ARG']
# 2                                                 ['']
# 3                                         ['WorldCup']
# 4                                                 ['']
# ...                                                ...
# 529995                                            ['']
# 529996                                    ['WorldCup']
# 529997  ['FRA', 'WorldCup', 'FRACRO', 'WorldCupFinal']
# 529998                                            ['']
# 529999                            ['MUFC', 'WorldCup']
#
#                                                       UMN  \
# 0                                       ['Bargain Booze']
# 1                                          ['City Watch']
# 2                       ['Aeri Days', 'FIFA World Cup ?']
# 3                                        ['B/R Football']
# 4                       ['Aeri Days', 'FIFA World Cup ?']
# ...                                                   ...
# 529995  ['ShakaZuluOnTheBeats', '#RecognizeMeEp - 10 A...
# 529996                                 ['Khaled Beydoun']
# 529997                                 ['FIFA World Cup']
# 529998                                   ['Alex Florack']
# 529999                              ['Manchester United']
#
#                                 UMID  \
# 0                   ['BargainBooze']
# 1                     ['City_Watch']
# 2       ['aeridays', 'FIFAWorldCup']
# 3                     ['brfootball']
# 4       ['aeridays', 'FIFAWorldCup']
# ...                              ...
# 529995    ['K_SUPREME_ZA', 'TBanSA']
# 529996             ['KhaledBeydoun']
# 529997              ['FIFAWorldCup']
# 529998            ['crimsonsith720']
# 529999                    ['ManUtd']
#
#                                               Tweet_Extra  Day  Mon  Hr  Mnt  \
# 0       ['win', 'worldcup', 'bargain booze', 'bargainb...   30    6   2   56
# 1              ['fra', 'arg', 'city watch', 'city_watch']   30    6   2   56
# 2       ['', 'aeri days', 'fifa world cup ?', 'aeriday...   30    6   2   56
# 3              ['worldcup', 'b/r football', 'brfootball']   30    6   2   56
# 4       ['', 'aeri days', 'fifa world cup ?', 'aeriday...   30    6   2   56
# ...                                                   ...  ...  ...  ..  ...
# 529995  ['', 'shakazuluonthebeats', '#recognizemeep - ...   16    7   2   14
# 529996    ['worldcup', 'khaled beydoun', 'khaledbeydoun']   16    7   2   14
# 529997  ['fra', 'worldcup', 'fracro', 'worldcupfinal',...   16    7   2   14
# 529998             ['', 'alex florack', 'crimsonsith720']   16    7   2   14
# 529999  ['mufc', 'worldcup', 'manchester united', 'man...   16    7   2   14
#
#                                                Tweet_Proc
# 0       [want, make, summer, football, little, bit, ho...
# 1       [didier, deschamps, ha, confirmed, benjamin, m...
# 2       [please, play, power, exo, exo, also, performe...
# 3       [week, team, game, goal, the, group, stage, wa...
# 4       [please, play, power, exo, exo, also, performe...
# ...                                                   ...
# 529995  [please, guy, please, please, help, ouuttt, pl...
# 529996  [dear, france, congratulations, winning, team,...
# 529997                             [france, fifa, moscow]
# 529998  [islamophobia, xenophobia, racism, global, phi...
# 529999             [the, first, player, find, net, final]
#
# [530000 rows x 11 columns]

# %%
df0 = df.loc[df['Day'] == 30]
df1 = df.loc[df['Day'] == 1]
df2 = df.loc[df['Day'] == 2]
df3 = df.loc[df['Day'] == 3]
df4 = df.loc[df['Day'] == 4]
df5 = df.loc[df['Day'] == 5]
df6 = df.loc[df['Day'] == 6]
df7 = df.loc[df['Day'] == 7]
df8 = df.loc[df['Day'] == 8]
df9 = df.loc[df['Day'] == 9]
df10 = df.loc[df['Day'] == 10]
df11 = df.loc[df['Day'] == 11]
df12 = df.loc[df['Day'] == 12]
df13 = df.loc[df['Day'] == 13]
df14 = df.loc[df['Day'] == 14]
df15 = df.loc[df['Day'] == 15]
df16 = df.loc[df['Day'] == 16]

# %%
df0.to_csv('tweet_3006.csv')
df1.to_csv('tweet_0107.csv')
df2.to_csv('tweet_0207.csv')
df3.to_csv('tweet_0307.csv')
df4.to_csv('tweet_0407.csv')
df5.to_csv('tweet_0507.csv')
df6.to_csv('tweet_0607.csv')
df7.to_csv('tweet_0707.csv')
df8.to_csv('tweet_0807.csv')
df9.to_csv('tweet_0907.csv')
df10.to_csv('tweet_1007.csv')
df11.to_csv('tweet_1107.csv')
df12.to_csv('tweet_1207.csv')
df13.to_csv('tweet_1307.csv')
df14.to_csv('tweet_1407.csv')
df15.to_csv('tweet_1507.csv')
df16.to_csv('tweet_1607.csv')
